# %% [markdown]
# # Mongabay Fire Tool
#
# In this notebook we will perform all the data processing required for the [Fire tool](https://docs.google.com/document/d/1zpwxTejaSbb7tq3uFnwVx_fzysTMBZJvnJEhuDW4vAE/edit#).
#
# For the fire alerts we will use the VIIRS alerts coming from GFW.
# [Here](https://www.globalforestwatch.org/dashboards/country/BRA/?category=fires&dashboardPrompts=...%3D&fireAlertStats=eyJzdGFydEluZGV4IjowLCJlbmRJbmRleCI6NTEsInN0YXJ0RGF0ZUFic29sdXRlIjoiMjAyMC0xMS0zMCIsImVuZERhdGVBYnNvbHV0ZSI6IjIwMjEtMTEtMjIifQ%3D%3D&location=WyJjb3VudHJ5IiwiQlJBIl0%3D&map=...%3D&scrollTo=fireAlertStats&showMap=false&widget=fireAlertStats) an example of a chart with that data.
#
# And here the endpoin to retrieve the data with a query example:
#
# ```
# https://data-api.globalforestwatch.org/dataset/gadm__viirs__iso_weekly_alerts/v202105/query/json?sql=SELECT iso, alert__year, alert__week, SUM(alert__count) AS alert__count, confidence__cat FROM data WHERE iso = 'BRA' AND confidence__cat = 'h' and alert__year = 2021 GROUP BY iso, alert__year, alert__week, confidence__cat
#
# ```
#
# For the precipitation data we will use the [CHIRPS Daily dataset from  GEE](https://developers.google.com/earth-engine/datasets/catalog/UCSB-CHG_CHIRPS_DAILY#description). Notice that this dataset doesn’t cover the whole world.
#
#
# The chart will include the following elements:
# - moving average of weekly precipitation.
# - long-term average of weekly precipitation.
# - Cumulative fire alerts
# - long-term average of cumulative fire alerts.
#
# The scope of the geographical data should be national (iso) or regional (adm1).
#
#
# # Setup
# ## Library import
# We import all the required Python libraries

# %%
import os
import ee
import wxee
import geemap
import numpy as np
import pandas as pd
import geopandas as gpd
import shapely.wkb
import cartopy.crs as ccrs
import matplotlib.pyplot as plt
import xarray_leaflet
import ipyleaflet as ipyl
import json
import requests
import math
from datetime import timedelta

ee.Initialize()

# %% [markdown]
# # Data import
# ## [CHIRPS Daily dataset from  GEE](https://developers.google.com/earth-engine/datasets/catalog/UCSB-CHG_CHIRPS_DAILY#description)
# **Automated conversion from Earth Engine JavaScripts to Python scripts**

# %%
js_dir = (
    "/home/iker/Vizzuality/Proiektuak/sci_team_data_bank/Projects/mongabay/processing"
)
geemap.conversion.js_to_python_dir(in_dir=js_dir, out_dir=js_dir, use_qgis=True)
print("Python scripts saved at: {}".format(js_dir))

# %% [markdown]
# ### Read data from GEE

# %% [markdown]
# **Get list of countries that entirely fall inside the `CHIRPS` dataset**

# %%
query = f"SELECT iso, name_0 FROM gadm36_countries"
left = -180
bottom = -50.5
query = f"SELECT iso, name_0 FROM gadm36_countries WHERE ST_Contains(ST_MakeEnvelope('-180', '-50.5', 180, 50.5, 4326), the_geom)"

url = f"https://api.resourcewatch.org/v1/query/Political-boundaries-GADM-36"

sql = {"sql": query}
r = requests.get(url, params=sql)

data = r.json().get("data")

df_country = pd.DataFrame.from_dict(pd.json_normalize(data))

df_country
# Out:
#      iso           name_0
# 0    NFK   Norfolk Island
# 1    JEY           Jersey
# 2    KWT           Kuwait
# 3    BFA     Burkina Faso
# 4    BGD       Bangladesh
# ..   ...              ...
# 211  XNC  Northern Cyprus
# 212  YEM            Yemen
# 213  ZAF     South Africa
# 214  ZMB           Zambia
# 215  ZWE         Zimbabwe
#
# [216 rows x 2 columns]

# %%
# !curl -X GET "https://api.resourcewatch.org/v1/query/Political-boundaries-GADM-36?sql=SELECT+iso%2C+name_0+FROM+gadm36_countries+WHERE+ST_Contains%28ST_MakeEnvelope%28%27-180%27%2C+%27-50.5%27%2C+180%2C+50.5%2C+4326%29%2C+the_geom%29" -H "Content-Type:application/json"
# Out:
# {"data":[{"iso":"NFK","name_0":"Norfolk Island"},{"iso":"JEY","name_0":"Jersey"},{"iso":"KWT","name_0":"Kuwait"},{"iso":"BFA","name_0":"Burkina Faso"},{"iso":"BGD","name_0":"Bangladesh"},{"iso":"BGR","name_0":"Bulgaria"},{"iso":"MCO","name_0":"Monaco"},{"iso":"MDA","name_0":"Moldova"},{"iso":"MDG","name_0":"Madagascar"},{"iso":"MHL","name_0":"Marshall Islands"},{"iso":"MKD","name_0":"Macedonia"},{"iso":"MLI","name_0":"Mali"},{"iso":"MLT","name_0":"Malta"},{"iso":"MMR","name_0":"Myanmar"},{"iso":"MNE","name_0":"Montenegro"},{"iso":"ALB","name_0":"Albania"},{"iso":"ATG","name_0":"Antigua and Barbuda"},{"iso":"AUT","name_0":"Austria"},{"iso":"AZE","name_0":"Azerbaijan"},{"iso":"BDI","name_0":"Burundi"},{"iso":"BEN","name_0":"Benin"},{"iso":"BES","name_0":"Bonaire, Sint Eustatius and Saba"},{"iso":"BHR","name_0":"Bahrain"},{"iso":"BHS","name_0":"Bahamas"},{"iso":"BIH","name_0":"Bosnia and Herzegovina"},{"iso":"BRA","name_0":"Brazil"},{"iso":"ABW","name_0":"Aruba"},{"iso":"BRB","name_0":"Barbados"},{"iso":"CHE","name_0":"Switzerland"},{"iso":"CIV","name_0":"Côte d'Ivoire"},{"iso":"CMR","name_0":"Cameroon"},{"iso":"COD","name_0":"Democratic Republic of the Congo"},{"iso":"COG","name_0":"Republic of Congo"},{"iso":"COK","name_0":"Cook Islands"},{"iso":"COL","name_0":"Colombia"},{"iso":"COM","name_0":"Comoros"},{"iso":"CPV","name_0":"Cape Verde"},{"iso":"CRI","name_0":"Costa Rica"},{"iso":"CUB","name_0":"Cuba"},{"iso":"CUW","name_0":"Curaçao"},{"iso":"DJI","name_0":"Djibouti"},{"iso":"BLM","name_0":"Saint-Barthélemy"},{"iso":"BLZ","name_0":"Belize"},{"iso":"BMU","name_0":"Bermuda"},{"iso":"AND","name_0":"Andorra"},{"iso":"ARE","name_0":"United Arab Emirates"},{"iso":"ARM","name_0":"Armenia"},{"iso":"ASM","name_0":"American Samoa"},{"iso":"ATF","name_0":"French Southern Territories"},{"iso":"BOL","name_0":"Bolivia"},{"iso":"BWA","name_0":"Botswana"},{"iso":"ERI","name_0":"Eritrea"},{"iso":"ESH","name_0":"Western Sahara"},{"iso":"ETH","name_0":"Ethiopia"},{"iso":"FJI","name_0":"Fiji"},{"iso":"MYS","name_0":"Malaysia"},{"iso":"NAM","name_0":"Namibia"},{"iso":"NCL","name_0":"New Caledonia"},{"iso":"NRU","name_0":"Nauru"},{"iso":"NGA","name_0":"Nigeria"},{"iso":"IDN","name_0":"Indonesia"},{"iso":"IND","name_0":"India"},{"iso":"IOT","name_0":"British Indian Ocean Territory"},{"iso":"HUN","name_0":"Hungary"},{"iso":"OMN","name_0":"Oman"},{"iso":"PAK","name_0":"Pakistan"},{"iso":"GLP","name_0":"Guadeloupe"},{"iso":"ESP","name_0":"Spain"},{"iso":"IRN","name_0":"Iran"},{"iso":"CYP","name_0":"Cyprus"},{"iso":"NER","name_0":"Niger"},{"iso":"SDN","name_0":"Sudan"},{"iso":"RWA","name_0":"Rwanda"},{"iso":"GAB","name_0":"Gabon"},{"iso":"GEO","name_0":"Georgia"},{"iso":"GGY","name_0":"Guernsey"},{"iso":"GHA","name_0":"Ghana"},{"iso":"HRV","name_0":"Croatia"},{"iso":"PAN","name_0":"Panama"},{"iso":"PRY","name_0":"Paraguay"},{"iso":"PSE","name_0":"Palestina"},{"iso":"PYF","name_0":"French Polynesia"},{"iso":"QAT","name_0":"Qatar"},{"iso":"REU","name_0":"Reunion"},{"iso":"ROU","name_0":"Romania"},{"iso":"SEN","name_0":"Senegal"},{"iso":"PHL","name_0":"Philippines"},{"iso":"CXR","name_0":"Christmas Island"},{"iso":"CYM","name_0":"Cayman Islands"},{"iso":"SGP","name_0":"Singapore"},{"iso":"SHN","name_0":"Saint Helena"},{"iso":"SLB","name_0":"Solomon Islands"},{"iso":"SLE","name_0":"Sierra Leone"},{"iso":"SLV","name_0":"El Salvador"},{"iso":"IRQ","name_0":"Iraq"},{"iso":"ISR","name_0":"Israel"},{"iso":"ITA","name_0":"Italy"},{"iso":"JAM","name_0":"Jamaica"},{"iso":"KNA","name_0":"Saint Kitts and Nevis"},{"iso":"GIB","name_0":"Gibraltar"},{"iso":"GIN","name_0":"Guinea"},{"iso":"GMB","name_0":"Gambia"},{"iso":"GNB","name_0":"Guinea-Bissau"},{"iso":"GNQ","name_0":"Equatorial Guinea"},{"iso":"GRC","name_0":"Greece"},{"iso":"GRD","name_0":"Grenada"},{"iso":"GTM","name_0":"Guatemala"},{"iso":"GUF","name_0":"French Guiana"},{"iso":"GUM","name_0":"Guam"},{"iso":"GUY","name_0":"Guyana"},{"iso":"HKG","name_0":"Hong Kong"},{"iso":"KOR","name_0":"South Korea"},{"iso":" ...

# %% [markdown]
# **Get list of admin1 regions for a given country**

# %%
iso = "BRA"

query = f"SELECT iso, name_1, gid_1 FROM gadm36_adm1 WHERE iso='{iso}'"

url = (
    f"https://api.resourcewatch.org/v1/query/Political-boundaries-Admin-1-level-GADM-36"
)

sql = {"sql": query}
r = requests.get(url, params=sql)

data = r.json().get("data")
df_region = pd.DataFrame.from_dict(pd.json_normalize(data))
df_region["code"] = df_region["gid_1"].apply(lambda x: x.split(".")[1].split("_")[0])
df_region
# Out:
#     iso               name_1     gid_1 code
# 0   BRA                 Acre   BRA.1_1    1
# 1   BRA   Mato Grosso do Sul  BRA.11_1   11
# 2   BRA          Mato Grosso  BRA.12_1   12
# 3   BRA  Rio Grande do Norte  BRA.20_1   20
# 4   BRA         Minas Gerais  BRA.13_1   13
# 5   BRA                 Pará  BRA.14_1   14
# 6   BRA             Maranhão  BRA.10_1   10
# 7   BRA              Paraíba  BRA.15_1   15
# 8   BRA            Tocantins  BRA.27_1   27
# 9   BRA              Roraima  BRA.23_1   23
# 10  BRA             Rondônia  BRA.22_1   22
# 11  BRA       Santa Catarina  BRA.24_1   24
# 12  BRA              Alagoas   BRA.2_1    2
# 13  BRA           Pernambuco  BRA.17_1   17
# 14  BRA    Rio Grande do Sul  BRA.21_1   21
# 15  BRA                Goiás   BRA.9_1    9
# 16  BRA            São Paulo  BRA.25_1   25
# 17  BRA              Sergipe  BRA.26_1   26
# 18  BRA       Rio de Janeiro  BRA.19_1   19
# 19  BRA       Espírito Santo   BRA.8_1    8
# 20  BRA                Bahia   BRA.5_1    5
# 21  BRA               Paraná  BRA.16_1   16
# 22  BRA                Amapá   BRA.3_1    3
# 23  BRA                Piauí  BRA.18_1   18
# 24  BRA             Amazonas   BRA.4_1    4
# 25  BRA                Ceará   BRA.6_1    6
# 26  BRA     Distrito Federal   BRA.7_1    7

# %%
# !curl -X GET "https://api.resourcewatch.org/v1/query/Political-boundaries-Admin-1-level-GADM-36?sql=SELECT+iso%2C+name_1%2C+gid_1+FROM+gadm36_adm1+WHERE+iso%3D%27BRA%27" -H "Content-Type:application/json"
# Out:
# {"data":[{"iso":"BRA","name_1":"Acre","gid_1":"BRA.1_1"},{"iso":"BRA","name_1":"Mato Grosso do Sul","gid_1":"BRA.11_1"},{"iso":"BRA","name_1":"Mato Grosso","gid_1":"BRA.12_1"},{"iso":"BRA","name_1":"Rio Grande do Norte","gid_1":"BRA.20_1"},{"iso":"BRA","name_1":"Minas Gerais","gid_1":"BRA.13_1"},{"iso":"BRA","name_1":"Pará","gid_1":"BRA.14_1"},{"iso":"BRA","name_1":"Maranhão","gid_1":"BRA.10_1"},{"iso":"BRA","name_1":"Paraíba","gid_1":"BRA.15_1"},{"iso":"BRA","name_1":"Tocantins","gid_1":"BRA.27_1"},{"iso":"BRA","name_1":"Roraima","gid_1":"BRA.23_1"},{"iso":"BRA","name_1":"Rondônia","gid_1":"BRA.22_1"},{"iso":"BRA","name_1":"Santa Catarina","gid_1":"BRA.24_1"},{"iso":"BRA","name_1":"Alagoas","gid_1":"BRA.2_1"},{"iso":"BRA","name_1":"Pernambuco","gid_1":"BRA.17_1"},{"iso":"BRA","name_1":"Rio Grande do Sul","gid_1":"BRA.21_1"},{"iso":"BRA","name_1":"Goiás","gid_1":"BRA.9_1"},{"iso":"BRA","name_1":"São Paulo","gid_1":"BRA.25_1"},{"iso":"BRA","name_1":"Sergipe","gid_1":"BRA.26_1"},{"iso":"BRA","name_1":"Rio de Janeiro","gid_1":"BRA.19_1"},{"iso":"BRA","name_1":"Espírito Santo","gid_1":"BRA.8_1"},{"iso":"BRA","name_1":"Bahia","gid_1":"BRA.5_1"},{"iso":"BRA","name_1":"Paraná","gid_1":"BRA.16_1"},{"iso":"BRA","name_1":"Amapá","gid_1":"BRA.3_1"},{"iso":"BRA","name_1":"Piauí","gid_1":"BRA.18_1"},{"iso":"BRA","name_1":"Amazonas","gid_1":"BRA.4_1"},{"iso":"BRA","name_1":"Ceará","gid_1":"BRA.6_1"},{"iso":"BRA","name_1":"Distrito Federal","gid_1":"BRA.7_1"}], "meta": {"cloneUrl":{"http_method":"POST","url":"/dataset/8f22dec5-2aea-49d6-8a7b-c494dbb8095c/clone","body":{"dataset":{"datasetUrl":"/query/8f22dec5-2aea-49d6-8a7b-c494dbb8095c?sql=SELECT+iso,+name_1,+gid_1+FROM+gadm36_adm1+WHERE+iso+%3D+'BRA'","application":["your","apps"]}}}} }

# %% [markdown]
# **Get geometries from gadm36_1**

# %%
gadm36_1 = gpd.read_file("../data/gadm36/gadm36_1.shp")

# %%
gadm36_1_GeoJson = json.loads(gadm36_1[gadm36_1["NAME_0"] == "Brazil"].to_json())

# %% [markdown]
# **Get geometry from geostore**

# %%
iso = "BRA"
code = ""  # 22

url = f"https://api.resourcewatch.org/v2/geostore/admin/{iso}/{code}"

r = requests.get(url)
geometry = r.json().get("data").get("attributes").get("geojson")

aoi = ee.Geometry(geometry.get("features")[0].get("geometry"))

# %% [markdown]
# **Define dates**

# %%
date = pd.to_datetime("2020/10/10")
today = pd.to_datetime("today").normalize()

# date = None

if date:
    date = date
else:
    date = today

# nDays_year = pd.Period(today, freq='D').day_of_year
nDays_year = len(
    pd.date_range(
        date.replace(month=1, day=1), date.replace(month=12, day=31), freq="D"
    )
)
start_year_date = date - timedelta(days=nDays_year)
start_date = date - timedelta(days=nDays_year + 61)
end_date = date + timedelta(days=61)
dates = pd.date_range(start_date, end_date, freq="D").astype(str)
dates = dates[(dates <= today.strftime("%Y-%m-%d"))]

# %% [markdown]
# **Breaks geometry into a grid**

# %%
# Script takes an arbitrary feature and breaks it into and n by n equal-area grid.
# The grid is then clipped against the original geometry.

# Returns a featureCollection of Grids

# 'Based on code from':

# '- https':#gis.stackexchange.com/questions/231959/draw-a-grid-of-polygons-in-google-earth-engine
# '- https':#gis.stackexchange.com/questions/318959/get-lon-lat-of-a-top-left-corner-for-geometry-in-google-earth-engine/318983

#


# Function takes a feature and a grid dimension, n
def getClippedGrid(feat, n):

    # Get features bounds
    bounds = feat.bounds().geometry().bounds()

    # Get a list of coordinates
    listCoords = ee.Array.cat(bounds.coordinates(), 1)
    # print('Coords: ', listCoords)

    # get the x and y-coordinates as lists
    xCoords = listCoords.slice(1, 0, 1)
    yCoords = listCoords.slice(1, 1, 2)

    # reduce the arrays to find the max (or min) value (edges of grid)
    lon_start = xCoords.reduce("min", [0]).get([0, 0]).getInfo()
    print("xMin", lon_start)
    lon_end = xCoords.reduce("max", [0]).get([0, 0]).getInfo()
    print("xMax", lon_end)
    lat_start = yCoords.reduce("min", [0]).get([0, 0]).getInfo()
    print("yMin", lat_start)
    lat_end = yCoords.reduce("max", [0]).get([0, 0]).getInfo()
    print("yMax", lat_end)

    # and hence the number of grid cells
    num_cells = n * n
    lon_edge = (lon_end - lon_start) / math.sqrt(num_cells)
    lat_edge = (lat_end - lat_start) / math.sqrt(num_cells)
    # print('lon_edge',lon_edge)
    # print('lat_edge',lat_edge)

    # Create the grid bu adding each cell as a feature to a list
    polys = []
    cell_id = 0
    for lon in np.arange(lon_start, lon_end, lon_edge):
        x1 = lon
        x2 = lon + lon_edge
        for lat in np.arange(lat_start, lat_end, lat_edge):
            cell_id = cell_id + 1
            y1 = lat
            y2 = lat + lat_edge

            # label each grid for reference
            polys.append(
                ee.Feature(ee.Geometry.Rectangle(x1, y1, x2, y2), {"label": cell_id})
            )

    grid = ee.FeatureCollection(polys)

    # Crop the grid to orignial shape
    def func_woo(feature):

        feature = ee.Feature(feature)

        intersection = feature.intersection(feat, ee.ErrorMargin(1))
        return ee.Feature(intersection).set(
            {"area": intersection.area().divide(1000 * 1000)}
        )

    polyIntersect = grid.map(func_woo)
    return polyIntersect

# %%
# Create or Import a geometry (called geometry) and cast as a ee.Feature
feature = ee.Feature(aoi, {})

# Decide no. of (in this case: equally sized) cells across
n = 20

# Get grid
clipped_grid = getClippedGrid(feature, n)

Map = geemap.Map(center=(-20, -45), zoom=4)
Map.addLayer(feature, {"color": "red"}, "Original shape")
Map.addLayer(clipped_grid, {"color": "blue", "strokeWidth": 1}, "Clipped grid", False)
Map
# Out:
# xMin -66.80650000000001
# xMax -59.774300000000004
# yMin -13.557600000000026
# yMax -7.969299999999976
# Map(center=[-20, -45], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=HBox(children=(T…

# %%
feature = ee.Feature(aoi, {})

# Decide no. of (in this case: equally sized) cells across
n = 20

# Get grid
# clipped_grid = getClippedGrid(feature, n)

# %%
feat = feature

# Get features bounds
bounds = feat.bounds().geometry().bounds()

# Get a list of coordinates
listCoords = ee.Array.cat(bounds.coordinates(), 1)
# print('Coords: ', listCoords)

# get the x and y-coordinates as lists
xCoords = listCoords.slice(1, 0, 1)
yCoords = listCoords.slice(1, 1, 2)

# reduce the arrays to find the max (or min) value (edges of grid)
lon_start = xCoords.reduce("min", [0]).get([0, 0]).getInfo()
print("xMin", lon_start)
lon_end = xCoords.reduce("max", [0]).get([0, 0]).getInfo()
print("xMax", lon_end)
lat_start = yCoords.reduce("min", [0]).get([0, 0]).getInfo()
print("yMin", lat_start)
lat_end = yCoords.reduce("max", [0]).get([0, 0]).getInfo()
print("yMax", lat_end)

# and hence the number of grid cells
num_cells = n * n
lon_edge = (lon_end - lon_start) / math.sqrt(num_cells)
lat_edge = (lat_end - lat_start) / math.sqrt(num_cells)
# print('lon_edge',lon_edge)
# print('lat_edge',lat_edge)

# Create the grid bu adding each cell as a feature to a list
polys = []
cell_id = 0
for lon in np.arange(lon_start, lon_end, lon_edge):
    x1 = lon
    x2 = lon + lon_edge
    for lat in np.arange(lat_start, lat_end, lat_edge):
        cell_id = cell_id + 1
        y1 = lat
        y2 = lat + lat_edge

        # label each grid for reference
        polys.append(
            ee.Feature(ee.Geometry.Rectangle(x1, y1, x2, y2), {"label": cell_id})
        )


grid = ee.FeatureCollection(polys)

# Crop the grid to orignial shape
def func_woo(feature):

    feature = ee.Feature(feature)

    intersection = feature.intersection(feat, ee.ErrorMargin(1))
    return ee.Feature(intersection).set(
        {"area": intersection.area().divide(1000 * 1000)}
    )


polyIntersect = grid.map(func_woo)
# Out:
# xMin -66.80650000000001
# xMax -59.774300000000004
# yMin -13.557600000000026
# yMax -7.969299999999976

# %%
grid.getInfo()
# Out:
# {'type': 'FeatureCollection',
#  'columns': {'label': 'Integer', 'system:index': 'String'},
#  'features': [{'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-66.80650000000001, -13.557600000000026],
#       [-66.45489000000002, -13.557600000000026],
#       [-66.45489000000002, -13.278185000000024],
#       [-66.80650000000001, -13.278185000000024],
#       [-66.80650000000001, -13.557600000000026]]]},
#    'id': '0',
#    'properties': {'label': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-66.80650000000001, -13.278185000000024],
#       [-66.45489000000002, -13.278185000000024],
#       [-66.45489000000002, -12.998770000000022],
#       [-66.80650000000001, -12.998770000000022],
#       [-66.80650000000001, -13.278185000000024]]]},
#    'id': '1',
#    'properties': {'label': 2}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-66.80650000000001, -12.998770000000022],
#       [-66.45489000000002, -12.998770000000022],
#       [-66.45489000000002, -12.71935500000002],
#       [-66.80650000000001, -12.71935500000002],
#       [-66.80650000000001, -12.998770000000022]]]},
#    'id': '2',
#    'properties': {'label': 3}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-66.80650000000001, -12.71935500000002],
#       [-66.45489000000002, -12.71935500000002],
#       [-66.45489000000002, -12.439940000000018],
#       [-66.80650000000001, -12.439940000000018],
#       [-66.80650000000001, -12.71935500000002]]]},
#    'id': '3',
#    'properties': {'label': 4}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-66.80650000000001, -12.439940000000018],
#       [-66.45489000000002, -12.439940000000018],
#       [-66.45489000000002, -12.160525000000016],
#       [-66.80650000000001, -12.160525000000016],
#       [-66.80650000000001, -12.439940000000018]]]},
#    'id': '4',
#    'properties': {'label': 5}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-66.80650000000001, -12.160525000000016],
#       [-66.45489000000002, -12.160525000000016],
#       [-66.45489000000002, -11.881110000000014],
#       [-66.80650000000001, -11.881110000000014],
#       [-66.80650000000001, -12.160525000000016]]]},
#    'id': '5',
#    'properties': {'label': 6}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-66.80650000000001, -11.881110000000014],
#       [-66.45489000000002, -11.881110000000014],
#       [-66.45489000000002, -11.601695000000012],
#       [-66.80650000000001, -11.601695000000012],
#       [-66.80650000000001, -11.881110000000014]]]},
#    'id': '6',
#    'properties': {'label': 7}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-66.80650000000001, -11.601695000000012],
#       [-66.45489000000002, -11.601695000000012],
#       [-66.45489000000002, -11.32228000000001],
#       [-66.80650000000001, -11.32228000000001],
#       [-66.80650000000001, -11.601695000000012]]]},
#    'id': '7',
#    'properties': {'label': 8}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-66.80650000000001, -11.32228000000001],
#       [-66.45489000000002, -11.32228000000001],
#       [-66.45489000000002, -11.042865000000008],
#       [-66.80650000000001, -11.042865000000008],
#       [-66.80650000000001, -11.32228000000001]]]},
#    'id': '8',
#    'properties': {'label': 9}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-66.80650000000001, -11.042865000000008],
#       [-66.45489000000002, -11.042865000000008],
#       [-66.45489000000002, -10.763450000000006],
#       [-66.80650000000001, -10.763450000000006],
#       [-66.80650000000001, -11.042865000000008]]]},
#    'id': '9',
#    'properties': {'label': 10}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-66.80650000000001,
#       [-66.5092, -9.8781],
#       [-66.5061, -9.878399999999997],
#       [-66.5032, -9.8833],
#       [-66.4986, -9.884100000000002],
#       [-66.4977, -9.8835],
#       [-66.4949, -9.884299999999996],
#       [-66.4913, -9.882499999999999],
#       [-66.4907, -9.879099999999998],
#       [-66.4817, -9.873500000000002],
#       [-66.472, -9.872300000000001],
#       [-66.4663, -9.8723],
#       [-66.4564, -9.8799],
#       [-66.45489000000002, -9.877679414073656]]]},
#    'id': '13',
#    'properties': {'area': 726.3733183235378, 'label': 14}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-66.53937911839095, -9.645822533864141],
#       [-66.45489000000002, -9.645789999999998],
#       [-66.45489000000002, -9.569834022128143],
#       [-66.4676, -9.582199999999998],
#       [-66.4878, -9.5965],
#       [-66.495, -9.601599999999998],
#       [-66.4961, -9.6142],
#       [-66.4972, -9.6264],
#       [-66.5007, -9.6336],
#       [-66.5182, -9.6384],
#       [-66.537, -9.6435],
#       [-66.53937911839095, -9.645822533864141]]]},
#    'id': '14',
#    'properties': {'area': 33.58394493723543, 'label': 15}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint', 'coordinates': []},
#    'id': '15',
#    'properties': {'area': 0, 'label': 16}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint', 'coordinates': []},
#    'id': '16',
#    'properties': {'area': 0, 'label': 17}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint', 'coordinates': []},
#    'id': '17',
#    'properties': {'area': 0, 'label': 18}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint', 'coordinates': []},
#    'id': '18',
#    'properties': {'area': 0, 'label': 19}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint', 'coordinates': []},
#    'id': '19',
#    'properties': {'area': 0, 'label': 20}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint', 'coordinates': []},
#    'id': '20',
#    'properties': {'area': 0, 'label': 21}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint', 'coordinates': []},
#    'id': '21',
#    'properties': {'area': 0, 'label': 22}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint', 'coordinates': []},
#    'id': '22',
#    'properties': {'area': 0, 'label': 23}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint', 'coordinates': []},
#    'id': '23',
#    'properties': {'area': 0, 'label': 24}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint', 'coordinates': []},
#    'id': '24',
#    'properties': {'area': 0, 'label': 25}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint', 'coordinates': []},
#    'id': '25',
#    'properties': {'area': 0, 'label': 26}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint', 'coordinates': []},
#    'id': '26',
#    'properties': {'area': 0, 'label': 27}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint', 'coordinates': []},
#    'id': '27',
#    'properties': {'area': 0, 'label': 28}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint', 'coordinates': []},
#    'id': '28',
#    'properties': {'area': 0, 'label': 29}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint', 'coordinates': []},
#    'id': '29',
#    'properties': {'area': 0, 'label': 30}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint', 'coordinates': []},
#    'id': '30',
#    'properties': {'area': 0, 'label': 31}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint', 'coordinates': []},
#    'id': '31',
#    'properties': {'area': 0, 'label': 32}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint', 'coordinates': []},
#    'id': '32',
#    'properties': {'area': 0, 'label': 33}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-66.45489000000002, -9.877286002591362],
#        [-66.45489000000002, -9.877679414073656],
#        [-66.4547, -9.8774],
#        [-66.45489000000002, -9.877286002591362]]],
#      [[[-66.10328000000003, -9.794476400609398],
#        [-66.10328000000003, -9.645789999999998],
#        [-66.45489000000002, -9.645789999999998],
#        [-66.45489000000002, -9.8731520314689],
#        [-66.4453, -9.871399999999998],
#        [-66.443, -9.8701],
#        [-66.4416, -9.8701],
#        [-66.4324, -9.874000000000002],
#        [-66.4309, -9.879500000000002],
#        [-66.431, -9.884],
#        [-66.4312, -9.889400000000004],
#        [-66.432, -9.891200000000001],
#        [-66.4323, -9.892],
#        [-66.4309, -9.8937],
#        [-66.4308, -9.893899999999999],
#        [-66.42630000000001, -9.8996],
#        [-66.4189, -9.897099999999998],
#        [-66.4189, -9.8951],
#        [-66.4217, -9.895100000000001],
#        [-66.4218, -9.8949],
#        [-66.419, -9.891700000000002],
#        [-66.419, -9.8912],
#        [-66.4188, -9.8896],
#        [-66.4185, -9.8874],
#        [-66.4181, -9.8837],
#        [-66.4179, -9.883399999999998],
},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint', 'coordinates': []},
#    'id': '399',
#    'properties': {'area': 0, 'label': 400}}]}

# %% [markdown]
# **Read ImageCollection**

# %%
dataset = (
    ee.ImageCollection("UCSB-CHG/CHIRPS/DAILY")
    .filter(
        ee.Filter.date(
            start_date.strftime("%Y-%m-%d"),
            (end_date + timedelta(days=1)).strftime("%Y-%m-%d"),
        )
    )
    .filterBounds(aoi)
)

chirps = dataset.select("precipitation")

# Clip images with AoI
def func_vee(image):
    return image.clip(aoi)


# chirps = chirps.map(func_vee)

chirpsVis = {
    "min": 1.0,
    "max": 100.0,
    "palette": ["001137", "0aab1e", "e7eb05", "ff4a2d", "e90000"],
}

# image = chirps.limit(1, 'system:time_start', False).first()

Map = geemap.Map(center=(-20, -45), zoom=4)
Map.addLayer(chirps, chirpsVis, "Precipitation")
Map.addLayer(ee.Feature(aoi, {}), {"color": "red"}, "Original shape")
Map
# Out:
# Map(center=[-20, -45], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=HBox(children=(T…

# %% [markdown]
# ### Data analysis with `xarray`
# **Convert the `ee.ImageCollection` to `xarray.DataArray` with [wxee](https://github.com/aazuspan/wxee)**

# %%
da = chirps.wx.to_xarray(scale=5566)
da

# %% [markdown]
# **Display data with `matplotlib`**

# %%
fig, ax = plt.subplots(figsize=(15, 7.5))

ax = plt.axes(projection=ccrs.PlateCarree())

ax.set_global()

da["precipitation"].isel(time=-1).plot.pcolormesh(
    ax=ax, cmap="magma", transform=ccrs.PlateCarree(), x="x", y="y", add_colorbar=True
)
ax.coastlines()

lon_min, lat_min, lon_max, lat_max = (-74, -34, -34, 5)
ax.set_ylim([lat_min - 1, lat_max + 1])
ax.set_xlim([lon_min - 1, lon_max + 1]);

# %% [markdown]
# **Display data with `ipyleafle`**

# %%
import rioxarray

m = ipyl.Map()
l = da["precipitation"].isel(time=-1).leaflet.plot(m)
m.add_layer(l)
m

# %% [markdown]
# **Compute mean value over time**

# %%
mean_values = da["precipitation"].sum(["x", "y"]).values

# %%
fig, ax = plt.subplots(figsize=(10, 6))
da["precipitation"].sum(["x", "y"]).plot(ax=ax)

# %% [markdown]
# ### Data analysis with `GEE`
# **Get mean values over time**
#
# Calling reduceRegions() with a very large or complex FeatureCollection as input may result in the dreaded "Computed value is too large" error. To prevent this issue here we will map reduceRegion() over the FeatureCollection instead as is suggested [here](https://developers.google.com/earth-engine/guides/best_practices#reduceregion-vs.-reduceregions-vs.-for-loop).

# %%
def nestedMappedReducer(featureCol, imageCol):
    def mapReducerOverImgCol(feature):
        def imgReducer(image):
            return (
                ee.Feature(
                    feature.geometry().centroid(100),
                    image.reduceRegion(
                        geometry=feature.geometry(),
                        reducer=ee.Reducer.mean(),
                        tileScale=10,
                        maxPixels=1e13,
                        bestEffort=True,
                    ),
                )
                .set({"date": image.date().format("YYYY-MM-dd")})
                .copyProperties(feature)
            )

        return imageCol.map(imgReducer)

    return featureCol.map(mapReducerOverImgCol).flatten()

# %% [markdown]
# **For all admin1 regions**

# %%
count = chirps.size()
data = (
    nestedMappedReducer(ee.FeatureCollection(gadm36_1_GeoJson.get("features")), chirps)
    .toList(count.getInfo() * len(gadm36_1_GeoJson.get("features")))
    .getInfo()
)
df_pre_provinces = pd.DataFrame(map(lambda x: x.get("properties"), data))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_13881/94967075.py in <module>
#       1 count = chirps.size()
# ----> 2 data = nestedMappedReducer(ee.FeatureCollection(gadm36_1_GeoJson.get('features')), chirps).toList(count.getInfo()*len(gadm36_1_GeoJson.get('features'))).getInfo()
#       3 df_pre_provinces = pd.DataFrame(map(lambda x: x.get('properties'), data))
#
# NameError: name 'gadm36_1_GeoJson' is not defined

# %%
df_pre_provinces
# Out:
#      ENGTYPE_1 GID_0     GID_1 HASC_1  NAME_0     NAME_1  TYPE_1        date  \
# 0        State   BRA   BRA.1_1  BR.AC  Brazil       Acre  Estado  2020-10-31
# 1        State   BRA   BRA.1_1  BR.AC  Brazil       Acre  Estado  2020-11-01
# 2        State   BRA   BRA.1_1  BR.AC  Brazil       Acre  Estado  2020-11-02
# 3        State   BRA   BRA.1_1  BR.AC  Brazil       Acre  Estado  2020-11-03
# 4        State   BRA   BRA.1_1  BR.AC  Brazil       Acre  Estado  2020-11-04
# ...        ...   ...       ...    ...     ...        ...     ...         ...
# 9877     State   BRA  BRA.27_1  BR.TO  Brazil  Tocantins  Estado  2021-10-27
# 9878     State   BRA  BRA.27_1  BR.TO  Brazil  Tocantins  Estado  2021-10-28
# 9879     State   BRA  BRA.27_1  BR.TO  Brazil  Tocantins  Estado  2021-10-29
# 9880     State   BRA  BRA.27_1  BR.TO  Brazil  Tocantins  Estado  2021-10-30
# 9881     State   BRA  BRA.27_1  BR.TO  Brazil  Tocantins  Estado  2021-10-31
#
#       precipitation VARNAME_1
# 0         11.288073       NaN
# 1          0.077326       NaN
# 2          0.004394       NaN
# 3          0.003099       NaN
# 4          0.104544       NaN
# ...             ...       ...
# 9877       4.088928       NaN
# 9878       1.726734       NaN
# 9879       1.899471       NaN
# 9880       7.989234       NaN
# 9881       4.892012       NaN
#
# [9882 rows x 10 columns]

# %% [markdown]
# **For a single region**

# %%
count = chirps.size()
data = (
    nestedMappedReducer(ee.FeatureCollection(geometry.get("features")), chirps)
    .toList(count)
    .getInfo()
)

# %%
df_pre = pd.DataFrame(map(lambda x: x.get("properties"), data))
df_pre
# Out:
#            date  precipitation
# 0    2020-11-19       9.980904
# 1    2020-11-20       6.727954
# 2    2020-11-21       6.165005
# 3    2020-11-22       6.352452
# 4    2020-11-23       3.925955
# ..          ...            ...
# 372  2021-11-26       7.081710
# 373  2021-11-27       5.462520
# 374  2021-11-28       6.743738
# 375  2021-11-29       7.362099
# 376  2021-11-30       7.017890
#
# [377 rows x 2 columns]

# %% [markdown]
# **Moving averages**

# %%
# 1 week moving average
df_pre["precipitation_w"] = (
    df_pre[["date", "precipitation"]].rolling(window=7, center=True).mean()
)
# 2 month moving average
df_pre["precipitation_2m"] = (
    df_pre[["date", "precipitation"]].rolling(window=61, center=True).mean()
)
# take current year days
df_pre = df_pre[
    (df_pre["date"] >= start_year_date.strftime("%Y-%m-%d"))
    & (df_pre["date"] <= date.strftime("%Y-%m-%d"))
]

# %%
fig, ax = plt.subplots(figsize=(10, 6))
df_pre.plot(ax=ax, x="date", y="precipitation", label="Daily precipitations")
df_pre.plot(ax=ax, x="date", y="precipitation_w", label="1-Week moving average")
df_pre.plot(ax=ax, x="date", y="precipitation_2m", label="2-Month moving average")
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# ##  VIIRS fire alerts

# %% [markdown]
# ### **Daily alerts**

# %% [markdown]
# ### National (iso)

# %%
iso = "BRA"
confidence = "h"  #'n', 'l'

query = f"SELECT alert__date, SUM(alert__count) AS alert__count \
        FROM data WHERE iso = '{iso}' AND confidence__cat = '{confidence}' AND alert__date >= '{start_date}' AND alert__date <= '{end_date}' \
        GROUP BY iso, alert__date, confidence__cat \
        ORDER BY alert__date"

url = f"https://data-api.globalforestwatch.org/dataset/gadm__viirs__adm2_daily_alerts/latest/query/json"

sql = {"sql": query}
r = requests.get(url, params=sql)

data = r.json().get("data")
df_fire = pd.DataFrame.from_dict(pd.json_normalize(data))
## Fill missing dates with 0
df_fire = (
    df_fire.set_index("alert__date")
    .reindex(dates, fill_value=0)
    .reset_index()
    .rename(columns={"index": "alert__date"})
)
df_fire.head()
# Out:
#   alert__date  alert__count
# 0  2019-08-10             0
# 1  2019-08-11          1585
# 2  2019-08-12          1404
# 3  2019-08-13          1424
# 4  2019-08-14          1152

# %%
r.url
# Out:
# 'https://data-api.globalforestwatch.org/dataset/gadm__viirs__iso_daily_alerts/latest/query/json?sql=SELECT+alert__date%2C+SUM%28alert__count%29+AS+alert__count+++++++++FROM+data+WHERE+iso+%3D+%27BRA%27+AND+confidence__cat+%3D+%27h%27+AND+alert__date+%3E%3D+%272020-08-10+00%3A00%3A00%27+AND+alert__date+%3C%3D+%272021-10-10+00%3A00%3A00%27+++++++++GROUP+BY+iso%2C+alert__date%2C+confidence__cat+++++++++ORDER+BY+alert__date'

# %% [markdown]
# **Moving averages**

# %%
# 1 week moving average
df_fire["alert__count_w"] = (
    df_fire[["alert__date", "alert__count"]].rolling(window=7, center=True).mean()
)
# 2 month moving average
df_fire["alert__count_2m"] = (
    df_fire[["alert__date", "alert__count"]].rolling(window=61, center=True).mean()
)
# take current year days
df_fire = df_fire[
    (df_fire["alert__date"] >= start_year_date.strftime("%Y-%m-%d"))
    & (df_fire["alert__date"] <= date.strftime("%Y-%m-%d"))
]

# %%
df_fire
# Out:
#     alert__date  alert__count  alert__count_w  alert__count_2m
# 61   2019-10-10           470      602.857143       714.360656
# 62   2019-10-11           729      615.000000       692.655738
# 63   2019-10-12          1027      638.428571       674.737705
# 64   2019-10-13          1003      665.857143       664.278689
# 65   2019-10-14           434      701.714286       636.524590
# ..          ...           ...             ...              ...
# 423  2020-10-06          1388     1944.142857      1156.114754
# 424  2020-10-07          1834     1829.142857      1128.360656
# 425  2020-10-08          2671     1635.285714      1105.819672
# 426  2020-10-09          2241     1470.285714      1074.459016
# 427  2020-10-10          1471     1351.714286      1037.934426
#
# [367 rows x 4 columns]

# %%
fig, ax = plt.subplots(figsize=(10, 6))
df_fire.plot(ax=ax, x="alert__date", y="alert__count", label="Daily fire alerts")
df_fire.plot(ax=ax, x="alert__date", y="alert__count_w", label="1-Week moving average")
df_fire.plot(
    ax=ax, x="alert__date", y="alert__count_2m", label="2-Month moving average"
)
# Out:
# <AxesSubplot:xlabel='alert__date'>

# %% [markdown]
# **Cumulative fire alerts**

# %%
df_fire["alert__count_cumsum"] = df_fire[["alert__count"]].cumsum()
df_fire["alert__count_cumsum_w"] = df_fire[["alert__count_w"]].cumsum()
df_fire["alert__count_cumsum_2m"] = df_fire[["alert__count_2m"]].cumsum()

# %%
fig, ax = plt.subplots(figsize=(10, 6))
df_fire.plot(ax=ax, x="alert__date", y="alert__count_cumsum", label="Daily fire alerts")
df_fire.plot(
    ax=ax, x="alert__date", y="alert__count_cumsum_w", label="1-Week moving average"
)
df_fire.plot(
    ax=ax, x="alert__date", y="alert__count_cumsum_2m", label="2-Month moving average"
)

# %% [markdown]
# ### Regional (admin1)

# %%
iso = "BRA"
adm1 = 22
confidence = "h"  #'n', 'l'

query = f"SELECT alert__date, SUM(alert__count) AS alert__count \
        FROM data WHERE iso = '{iso}' AND adm1::integer = {adm1} AND confidence__cat = '{confidence}' AND alert__date >= '{start_date}' AND alert__date <= '{end_date}' \
        GROUP BY iso, adm1, alert__date, confidence__cat \
        ORDER BY alert__date"

url = f"https://data-api.globalforestwatch.org/dataset/gadm__viirs__adm2_daily_alerts/latest/query/json"

sql = {"sql": query}
r = requests.get(url, params=sql)

data = r.json().get("data")
df_fire = pd.DataFrame.from_dict(pd.json_normalize(data))
# Fill missing dates with 0
df_fire = (
    df_fire.set_index("alert__date")
    .reindex(dates, fill_value=0)
    .reset_index()
    .rename(columns={"index": "alert__date"})
)
df_fire.head()
# Out:
#   alert__date  alert__count
# 0  2020-10-15             0
# 1  2020-10-16            41
# 2  2020-10-17            18
# 3  2020-10-18            19
# 4  2020-10-19             1

# %% [markdown]
# **Moving averages**

# %%
# 1 week moving average
df_fire["alert__count_w"] = (
    df_fire[["alert__date", "alert__count"]].rolling(window=7, center=True).mean()
)
# 2 month moving average
df_fire["alert__count_2m"] = (
    df_fire[["alert__date", "alert__count"]].rolling(window=61, center=True).mean()
)
# take current year days
df_fire = df_fire[
    (df_fire["alert__date"] >= start_year_date.strftime("%Y-%m-%d"))
    & (df_fire["alert__date"] <= date.strftime("%Y-%m-%d"))
]

# %%
fig, ax = plt.subplots(figsize=(10, 6))
df_fire.plot(ax=ax, x="alert__date", y="alert__count", label="Daily fire alerts")
df_fire.plot(ax=ax, x="alert__date", y="alert__count_w", label="1-Week moving average")
df_fire.plot(
    ax=ax, x="alert__date", y="alert__count_2m", label="2-Month moving average"
)
# Out:
# <AxesSubplot:xlabel='alert__date'>

# %% [markdown]
# ### Regional (admin2)

# %%
iso = "BRA"
adm1 = 22
adm2 = 6
confidence = "h"  #'n', 'l'

query = f"SELECT alert__date, SUM(alert__count) AS alert__count \
        FROM data WHERE iso = '{iso}' AND adm1::integer = {adm1} AND adm2::integer = {adm2} AND confidence__cat = '{confidence}' AND alert__date >= '{start_date}' AND alert__date <= '{end_date}' \
        GROUP BY iso, adm1, adm2, alert__date, confidence__cat \
        ORDER BY alert__date"

url = f"https://data-api.globalforestwatch.org/dataset/gadm__viirs__adm2_daily_alerts/latest/query/json"

sql = {"sql": query}
r = requests.get(url, params=sql)

data = r.json().get("data")
df_fire = pd.DataFrame.from_dict(pd.json_normalize(data))
# Fill missing dates with 0
df_fire = (
    df_fire.set_index("alert__date")
    .reindex(dates, fill_value=0)
    .reset_index()
    .rename(columns={"index": "alert__date"})
)
df_fire.head()

# %% [markdown]
# **Moving averages**

# %%
# 1 week moving average
df_fire["alert__count_w"] = (
    df_fire[["alert__date", "alert__count"]].rolling(window=7, center=True).mean()
)
# 2 month moving average
df_fire["alert__count_2m"] = (
    df_fire[["alert__date", "alert__count"]].rolling(window=61, center=True).mean()
)
# take current year days
df_fire = df_fire[
    (df_fire["alert__date"] >= start_year_date.strftime("%Y-%m-%d"))
    & (df_fire["alert__date"] <= today.strftime("%Y-%m-%d"))
]

# %%
fig, ax = plt.subplots(figsize=(10, 6))
df_fire.plot(ax=ax, x="alert__date", y="alert__count", label="Daily fire alerts")
df_fire.plot(ax=ax, x="alert__date", y="alert__count_w", label="1-Week moving average")
df_fire.plot(
    ax=ax, x="alert__date", y="alert__count_2m", label="2-Month moving average"
)

# %% [markdown]
# ##  Final widget examples

# %%
fig, ax = plt.subplots(figsize=(10, 6))

ax2 = ax.twinx()
df_pre.plot(
    ax=ax,
    x="date",
    y="precipitation",
    color="b",
    label="Daily recipitation",
    legend=True,
)
df_fire.plot(
    ax=ax2,
    x="alert__date",
    y="alert__count",
    color="r",
    label="Daily Fire alerts",
    legend=True,
)

ax.legend(loc="upper left")
ax2.legend(loc="upper right")
ax.set_ylabel("Precipitation [mm/day]", color="b")
ax2.set_ylabel("Fire alerts", color="r")

plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 6))

ax2 = ax.twinx()
df_pre.plot(
    ax=ax,
    x="date",
    y="precipitation_w",
    color="b",
    label="Precipitation (1-Week moving average)",
    legend=True,
)
df_fire.plot(
    ax=ax2,
    x="alert__date",
    y="alert__count_w",
    color="r",
    label="Fire alerts (1-Week moving average)",
    legend=True,
)

ax.legend(loc="upper left")
ax2.legend(loc="upper right")
ax.set_ylabel("Precipitation [mm/day]", color="b")
ax2.set_ylabel("Fire alerts", color="r")

plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 6))

ax2 = ax.twinx()
df_pre.plot(
    ax=ax,
    x="date",
    y="precipitation_2m",
    color="b",
    label="Precipitation (2-Month moving average)",
    legend=True,
)
df_fire.plot(
    ax=ax2,
    x="alert__date",
    y="alert__count_2m",
    color="r",
    label="Fire alerts (2-Month moving average)",
    legend=True,
)

ax.legend(loc="upper left")
ax2.legend(loc="upper right")
ax.set_ylabel("Precipitation [mm/day]", color="b")
ax2.set_ylabel("Fire alerts", color="r")

plt.show()

# %% [markdown]
# **Organize data**

# %%
json.loads(
    pd.merge(
        df_fire.rename(columns={"alert__date": "date"}), df_pre, how="left", on="date"
    ).to_json(orient="records")
)
# Out:
# [{'date': '2020-12-15',
#   'alert__count': 0,
#   'alert__count_w': 0.8571428571,
#   'alert__count_2m': 1.3770491803,
#   'precipitation': 10.1866959083,
#   'precipitation_w': 5.4375543381,
#   'precipitation_2m': 7.6856272875},
#  {'date': '2020-12-16',
#   'alert__count': 0,
#   'alert__count_w': 1.5714285714,
#   'alert__count_2m': 1.2950819672,
#   'precipitation': 2.415980535,
#   'precipitation_w': 5.8327093163,
#   'precipitation_2m': 7.7424542715},
#  {'date': '2020-12-17',
#   'alert__count': 5,
#   'alert__count_w': 1.7142857143,
#   'alert__count_2m': 1.2950819672,
#   'precipitation': 0.5291816012,
#   'precipitation_w': 5.9314319574,
#   'precipitation_2m': 7.9776032275},
#  {'date': '2020-12-18',
#   'alert__count': 0,
#   'alert__count_w': 1.7142857143,
#   'alert__count_2m': 1.2786885246,
#   'precipitation': 11.6948741472,
#   'precipitation_w': 5.9733591108,
#   'precipitation_2m': 8.0255773907},
#  {'date': '2020-12-19',
#   'alert__count': 6,
#   'alert__count_w': 1.7142857143,
#   'alert__count_2m': 1.262295082,
#   'precipitation': 4.1944660847,
#   'precipitation_w': 7.0375454452,
#   'precipitation_2m': 8.1849348565},
#  {'date': '2020-12-20',
#   'alert__count': 1,
#   'alert__count_w': 1.7142857143,
#   'alert__count_2m': 1.2459016393,
#   'precipitation': 1.9501238674,
#   'precipitation_w': 8.9247771862,
#   'precipitation_2m': 8.1398229961},
#  {'date': '2020-12-21',
#   'alert__count': 0,
#   'alert__count_w': 1.0,
#   'alert__count_2m': 1.2295081967,
#   'precipitation': 10.842191632,
#   'precipitation_w': 10.5069172155,
#   'precipitation_2m': 8.1426506641},
#  {'date': '2020-12-22',
#   'alert__count': 0,
#   'alert__count_w': 1.0,
#   'alert__count_2m': 1.1639344262,
#   'precipitation': 17.6360002488,
#   'precipitation_w': 11.1045036126,
#   'precipitation_2m': 8.340729766},
#  {'date': '2020-12-23',
#   'alert__count': 0,
#   'alert__count_w': 0.1428571429,
#   'alert__count_2m': 0.9016393443,
#   'precipitation': 15.6266027222,
#   'precipitation_w': 15.7707785105,
#   'precipitation_2m': 8.4420588724},
#  {'date': '2020-12-24',
#   'alert__count': 0,
#   'alert__count_w': 0.0,
#   'alert__count_2m': 0.8032786885,
#   'precipitation': 11.604161806,
#   'precipitation_w': 18.3285880288,
#   'precipitation_2m': 8.4946974045},
#  {'date': '2020-12-25',
#   'alert__count': 0,
#   'alert__count_w': 0.0,
#   'alert__count_2m': 0.7868852459,
#   'precipitation': 15.8779789271,
#   'precipitation_w': 18.0864951284,
#   'precipitation_2m': 8.7313707275},
#  {'date': '2020-12-26',
#   'alert__count': 0,
#   'alert__count_w': 0.0,
#   'alert__count_2m': 0.7049180328,
#   'precipitation': 36.8583903696,
#   'precipitation_w': 15.8332639234,
#   'precipitation_2m': 8.7971811608},
#  {'date': '2020-12-27',
#   'alert__count': 0,
#   'alert__count_w': 0.0,
#   'alert__count_2m': 0.6885245902,
#   'precipitation': 19.8547904955,
#   'precipitation_w': 14.7359509339,
#   'precipitation_2m': 8.8460320918},
#  {'date': '2020-12-28',
#   'alert__count': 0,
#   'alert__count_w': 0.0,
#   'alert__count_2m': 0.6885245902,
#   'precipitation': 9.1475413295,
#   'precipitation_w': 13.3107450617,
#   'precipitation_2m': 9.1415963383},
#  {'date': '2020-12-29',
#   'alert__count': 0,
#   'alert__count_w': 0.0,
#   'alert__count_2m': 0.6229508197,
#   'precipitation': 1.863381814,
#   'precipitation_w': 12.1939991109,
#   'precipitation_2m': 9.145007109},
#  {'date': '2020-12-30',
#   'alert__count': 0,
#   'alert__count_w': 0.0,
#   'alert__count_2m': 0.606557377,
#   'precipitation': 7.9454117958,
#   'precipitation_w': 7.7821593098,
#   'precipitation_2m': 9.2989709446},
#  {'date': '2020-12-31',
#   'alert__count': 0,
#   'alert__count_w': 0.0,
#   'alert__count_2m': 0.606557377,
#   'precipitation': 1.6277207003,
#   'precipitation_w': 6.6708721252,
#   'precipitation_2m': 9.3279148061},
#  {'date': '2021-01-01',
#   'alert__count': 0,
#   'alert__count_w': 0.0,
#   'alert__count_2m': 0.606557377,
#   'precipitation': 8.0607572718,
#   'precipitation_w': 6.8778307596,
#   'precipitation_2m': 9.3678610666},
#  {'date': '2021-01-02',
#   'alert__count': 0,
#   'alert__count_w': 0.0,
#   'alert__count_2m': 0.5901639344,
#   'precipitation': 5.9755117613,
#   'precipitation_w': 7.3792307252,
#   'precipitation_2m': 9.4311860378},
#  {'date': '2021-01-03',
#   'alert__count': 0,
#   'alert__count_w': 0.0,
#   'alert__count_2m': 0.5901639344,
#   'precipitation': 12.0757802039,
#   'precipitation_w': 8.6064852393,
#   'precipitation_2m': 9.6075997047},
#  {'date': '2021-01-04',
#   'alert__count': 0,
#   'alert__count_w': 0.0,
#   'alert__count_2m': 0.5245901639,
#   'precipitation': 10.5962517701,
#   'precipitation_w': 9.969635855,
#   'precipitation_2m': 9.6476061384},
#  {'date': '2021-01-05',
#   'alert__count': 0,
#   'alert__count_w': 0.5714285714,
#   'alert__count_2m': 0.3606557377,
#   'precipitation': 5.3731815729,
#   'precipitation_w': 9.4711344365,
#   'precipitation_2m': 9.7348484575},
#  {'date': '2021-01-06',
#   'alert__count': 0,
#   'alert__count_w': 0.7142857143,
#   'alert__count_2m': 0.3606557377,
#   'precipitation': 16.536193395,
#   'precipitation_w': 9.2095337918,
#   'precipitation_2m': 9.8113521771},
#  {'date': '2021-01-07',
#   'alert__count': 0,
#   'alert__count_w': 0.7142857143,
#   'alert__count_2m': 0.3606557377,
#   'precipitation': 11.1697750098,
#   'precipitation_w': 9.4840657999,
#   'precipitation_2m': 9.9429863728},
#  {'date': '2021-01-08',
#   'alert__count': 4,
#   'alert__count_w': 0.8571428571,
#   'alert__count_2m': 0.3442622951,
#   'precipitation': 4.5712473423,
#   'precipitation_w': 8.5063536973,
#   'precipitation_2m': 9.9611429457},
#  {'date': '2021-01-09',
#   'alert__count': 1,
#   'alert__count_w': 0.8571428571,
#   'alert__count_2m': 0.3114754098,
#   'precipitation': 4.1443072483,
#   'precipitation_w': 7.9099812914,
#   'precipitation_2m': 9.9567964042},
#  {'date': '2021-01-10',
#   'alert__count': 0,
#   'alert__count_w': 0.8571428571,
#   'alert__count_2m': 0.3114754098,
#   'precipitation': 13.9975042606,
#   'precipitation_w': 7.7857349122,
#   'precipitation_2m': 9.7074990567},
#  {'date': '2021-01-11',
#   'alert__count': 1,
#   'alert__count_w': 0.8571428571,
#   'alert__count_2m': 0.3114754098,
#   'precipitation': 3.7522670521,
#   'precipitation_w': 7.4977715553,
#   'precipitation_2m': 10.2355930784},
#  {'date': '2021-01-12',
#   'alert__count': 0,
#   'alert__count_w': 0.2857142857,
#   'alert__count_2m': 0.2950819672,
#   'precipitation': 1.1985747317,
#   'precipitation_w': 8.1172183961,
#   'precipitation_2m': 10.2867660295},
#  {'date': '2021-01-13',
#   'alert__count': 0,
#   'alert__count_w': 0.1428571429,
#   'alert__count_2m': 0.2950819672,
#   'precipitation': 15.6664687403,
#   'precipitation_w': 10.3064278984,
#   'precipitation_2m': 10.4194362319},
#  {'date': '2021-01-14',
#   'alert__count': 0,
#   'alert__count_w': 0.1428571429,
#   'alert__count_2m': 0.2950819672,
#   'precipitation': 9.1540315117,
#   'precipitation_w': 9.6974178216,
#   'precipitation_2m': 10.4675955061},
#  {'date': '2021-01-15',
#   'alert__count': 0,
#   'alert__count_w': 0.0,
#   'alert__count_2m': 0.2950819672,
#   'precipitation': 8.9073752283,
#   'precipitation_w': 11.7508360966,
#   'precipitation_2m': 10.6611359408},
#  {'date': '2021-01-16',
#   'alert__count': 0,
#   'alert__count_w': 0.0,
#   'alert__count_2m': 0.2950819672,
#   'precipitation': 19.4687737639,
#   'precipitation_w': 12.6134549143,
#   'precipitation_2m': 10.8427318203},
#  {'date': '2021-01-17',
#   'alert__count': 0,
#   'alert__count_w': 0.0,
#   'alert__count_2m': 0.2131147541,
#   'precipitation': 9.7344337233,
#   'precipitation_w': 11.0368227221,
#   'precipitation_2m': 10.9968963501},
#  {'date': '2021-01-18',
#   'alert__count': 0,
#   'alert__count_w': 0.0,
#   'alert__count_2m': 0.2131147541,
#   'precipitation': 18.1261949769,
#   'precipitation_w': 11.5020571638,
#   'precipitation_2m': 11.0279166877},
#  {'date': '2021-01-19',
#   'alert__count': 0,
#   'alert__count_w': 0.0,
#   'alert__count_2m': 0.1147540984,
#   'precipitation': 7.2369064558,
#   'precipitation_w': 11.2103894946,
#   'precipitation_2m': 10.9867558058},
#  {'date': '2021-01-20',
#   'alert__count': 0,
#   'alert__count_w': 0.0,
#   'alert__count_2m': 0.0983606557,
#   'precipitation': 4.6300433946,
#   'precipitation_w': 9.3140915392,
#   'precipitation_2m': 11.1778346695},
#  {'date': '2021-01-21',
#   'alert__count': 0,
#   'alert__count_w': 0.0,
#   'alert__count_2m': 0.0983606557,
#   'precipitation':

#   'alert__count_w': 0.2857142857,
#   'alert__count_2m': 0.1967213115,
#   'precipitation': 0.1477415574,
#   'precipitation_w': 4.0900980212,
#   'precipitation_2m': 5.0639066279},
#  {'date': '2021-04-23',
#   'alert__count': 1,
#   'alert__count_w': 0.2857142857,
#   'alert__count_2m': 0.1967213115,
#   'precipitation': 1.1507744961,
#   'precipitation_w': 4.6038384337,
#   'precipitation_2m': 5.0592555258},
#  {'date': '2021-04-24',
#   'alert__count': 0,
#   'alert__count_w': 0.2857142857,
#   'alert__count_2m': 0.1967213115,
#   'precipitation': 7.3362227703,
#   'precipitation_w': 3.9944545925,
#   'precipitation_2m': 5.0679830671},
#  {'date': '2021-04-25',
#   'alert__count': 0,
#   'alert__count_w': 0.2857142857,
#   'alert__count_2m': 0.1967213115,
#   'precipitation': 10.7781577367,
#   'precipitation_w': 3.7519420465,
#   'precipitation_2m': 4.9523693333},
#  {'date': '2021-04-26',
#   'alert__count': 0,
#   'alert__count_w': 0.1428571429,
#   'alert__count_2m': 0.2131147541,
#   'precipitation': 6.0376594454,
#   'precipitation_w': 5.400253282,
#   'precipitation_2m': 4.9269659707},
#  {'date': '2021-04-27',
#   'alert__count': 0,
#   'alert__count_w': 0.1428571429,
#   'alert__count_2m': 0.3114754098,
#   'precipitation': 0.5743776527,
#   'precipitation_w': 5.2842739481,
#   'precipitation_2m': 4.8936401934},
#  {'date': '2021-04-28',
#   'alert__count': 0,
#   'alert__count_w': 0.1428571429,
#   'alert__count_2m': 0.3278688525,
#   'precipitation': 0.2386606667,
#   'precipitation_w': 4.2652784679,
#   'precipitation_2m': 4.6833738594},
#  {'date': '2021-04-29',
#   'alert__count': 0,
#   'alert__count_w': 0.1428571429,
#   'alert__count_2m': 0.3278688525,
#   'precipitation': 11.685920206,
#   'precipitation_w': 3.129259572,
#   'precipitation_2m': 4.5373736721},
#  {'date': '2021-04-30',
#   'alert__count': 1,
#   'alert__count_w': 0.1428571429,
#   'alert__count_2m': 0.3278688525,
#   'precipitation': 0.3389191589,
#   'precipitation_w': 2.5344765133,
#   'precipitation_2m': 4.406095281},
#  {'date': '2021-05-01',
#   'alert__count': 0,
#   'alert__count_w': 0.1428571429,
#   'alert__count_2m': 0.3278688525,
#   'precipitation': 0.203254409,
#   'precipitation_w': 2.5063038355,
#   'precipitation_2m': 4.0793578977},
#  {'date': '2021-05-02',
#   'alert__count': 0,
#   'alert__count_w': 0.1428571429,
#   'alert__count_2m': 0.3278688525,
#   'precipitation': 2.8260254655,
#   'precipitation_w': 2.7053841822,
#   'precipitation_2m': 3.9425048697},
#  {'date': '2021-05-03',
#   'alert__count': 0,
#   'alert__count_w': 0.1428571429,
#   'alert__count_2m': 0.393442623,
#   'precipitation': 1.874178034,
#   'precipitation_w': 1.2906077119,
#   'precipitation_2m': 3.8852024636},
#  {'date': '2021-05-04',
#   'alert__count': 0,
#   'alert__count_w': 0.2857142857,
#   'alert__count_2m': 0.393442623,
#   'precipitation': 0.3771689082,
#   'precipitation_w': 1.2999696962,
#   'precipitation_2m': 3.5709743463},
#  {'date': '2021-05-05',
#   'alert__count': 0,
#   'alert__count_w': 0.2857142857,
#   'alert__count_2m': 0.393442623,
#   'precipitation': 1.632223094,
#   'precipitation_w': 1.2738141676,
#   'precipitation_2m': 3.3583399558},
#  {'date': '2021-05-06',
#   'alert__count': 0,
#   'alert__count_w': 0.2857142857,
#   'alert__count_2m': 0.393442623,
#   'precipitation': 1.7824849135,
#   'precipitation_w': 0.8729383997,
#   'precipitation_2m': 3.3837603731},
#  {'date': '2021-05-07',
#   'alert__count': 2,
#   'alert__count_w': 0.2857142857,
#   'alert__count_2m': 0.4262295082,
#   'precipitation': 0.404453049,
#   'precipitation_w': 1.0557227379,
#   'precipitation_2m': 3.3637077008},
#  {'date': '2021-05-08',
#   'alert__count': 0,
#   'alert__count_w': 0.5714285714,
#   'alert__count_2m': 0.4262295082,
#   'precipitation': 0.0201657092,
#   'precipitation_w': 1.0880468164,
#   'precipitation_2m': 3.2756820025},
#  {'date': '2021-05-09',
#   'alert__count': 0,
#   'alert__count_w': 0.8571428571,
#   'alert__count_2m': 0.4426229508,
#   'precipitation': 0.0198950898,
#   'precipitation_w': 0.878802252,
#   'precipitation_2m': 3.1886957528},
#  {'date': '2021-05-10',
#   'alert__count': 0,
#   'alert__count_w': 0.8571428571,
#   'alert__count_2m': 0.4426229508,
#   'precipitation': 3.1536684014,
#   'precipitation_w': 2.0623734177,
#   'precipitation_2m': 3.1046995592},
#  {'date': '2021-05-11',
#   'alert__count': 2,
#   'alert__count_w': 0.5714285714,
#   'alert__count_2m': 0.4426229508,
#   'precipitation': 0.6034374576,
#   'precipitation_w': 3.1374860566,
#   'precipitation_2m': 3.0206601717},
#  {'date': '2021-05-12',
#   'alert__count': 2,
#   'alert__count_w': 0.5714285714,
#   'alert__count_2m': 0.4426229508,
#   'precipitation': 0.1675111435,
#   'precipitation_w': 3.220107821,
#   'precipitation_2m': 3.0131006295},
#  {'date': '2021-05-13',
#   'alert__count': 0,
#   'alert__count_w': 0.5714285714,
#   'alert__count_2m': 0.4426229508,
#   'precipitation': 10.0674830733,
#   'precipitation_w': 4.1190579201,
#   'precipitation_2m': 2.8688599692},
#  {'date': '2021-05-14',
#   'alert__count': 0,
#   'alert__count_w': 0.5714285714,
#   'alert__count_2m': 0.4426229508,
#   'precipitation': 7.9302415214,
#   'precipitation_w': 4.4536449324,
#   'precipitation_2m': 2.8273541905},
#  {'date': '2021-05-15',
#   'alert__count': 0,
#   'alert__count_w': 0.5714285714,
#   'alert__count_2m': 0.4426229508,
#   'precipitation': 0.5985180599,
#   'precipitation_w': 4.5405690396,
#   'precipitation_2m': 2.7738532689},
#  {'date': '2021-05-16',
#   'alert__count': 0,
#   'alert__count_w': 0.2857142857,
#   'alert__count_2m': 0.4426229508,
#   'precipitation': 6.3125457839,
#   'precipitation_w': 4.5203350732,
#   'precipitation_2m': 2.6558634962},
#  {'date': '2021-05-17',
#   'alert__count': 0,
#   'alert__count_w': 0.2857142857,
#   'alert__count_2m': 0.4426229508,
#   'precipitation': 5.495777487,
#   'precipitation_w': 3.112590557,
#   'precipitation_2m': 2.5588752553},
#  {'date': '2021-05-18',
#   'alert__count': 2,
#   'alert__count_w': 0.2857142857,
#   'alert__count_2m': 0.4426229508,
#   'precipitation': 1.2119062085,
#   'precipitation_w': 2.1044831148,
#   'precipitation_2m': 2.5287079874},
#  {'date': '2021-05-19',
#   'alert__count': 0,
#   'alert__count_w': 0.2857142857,
#   'alert__count_2m': 0.4754098361,
#   'precipitation': 0.0258733784,
#   'precipitation_w': 2.7418600197,
#   'precipitation_2m': 2.3759116234},
#  {'date': '2021-05-20',
#   'alert__count': 0,
#   'alert__count_w': 0.2857142857,
#   'alert__count_2m': 0.4754098361,
#   'precipitation': 0.2132714602,
#   'precipitation_w': 3.3575770886,
#   'precipitation_2m': 2.3426715748},
#  {'date': '2021-05-21',
#   'alert__count': 0,
#   'alert__count_w': 0.2857142857,
#   'alert__count_2m': 0.4754098361,
#   'precipitation': 0.8734894259,
#   'precipitation_w': 4.1029372107,
#   'precipitation_2m': 2.2727848004},
#  {'date': '2021-05-22',
#   'alert__count': 0,
#   'alert__count_w': 0.0,
#   'alert__count_2m': 0.4754098361,
#   'precipitation': 5.0601563939,
#   'precipitation_w': 3.938373497,
#   'precipitation_2m': 2.2412600489},
#  {'date': '2021-05-23',
#   'alert__count': 0,
#   'alert__count_w': 0.1428571429,
#   'alert__count_2m': 0.4590163934,
#   'precipitation': 10.622565266,
#   'precipitation_w': 3.9347167213,
#   'precipitation_2m': 2.2404326102},
#  {'date': '2021-05-24',
#   'alert__count': 0,
#   'alert__count_w': 1.1428571429,
#   'alert__count_2m': 0.5081967213,
#   'precipitation': 10.7132983421,
#   'precipitation_w': 3.9042493699,
#   'precipitation_2m': 2.2216613508},
#  {'date': '2021-05-25',
#   'alert__count': 0,
#   'alert__count_w': 1.2857142857,
#   'alert__count_2m': 0.5081967213,
#   'precipitation': 0.0599602128,
#   'precipitation_w': 3.7794651662,
#   'precipitation_2m': 2.1013956079},
#  {'date': '2021-05-26',
#   'alert__count': 1,
#   'alert__count_w': 1.2857142857,
#   'alert__count_2m': 0.5081967213,
#   'precipitation': 0.0002759486,
#   'precipitation_w': 3.0606773294,
#   'precipitation_2m': 1.9247044975},
#  {'date': '2021-05-27',
#   'alert__count': 7,
#   'alert__count_w': 1.2857142857,
#   'alert__count_2m': 0.5081967213,
#   'precipitation': 0.0,
#   'precipitation_w': 1.6438768672,
#   'precipitation_2m': 1.8257763993},
#  {'date': '2021-05-28',
#   'alert__count': 1,
#   'alert__count_w': 1.2857142857,
#   'alert__count_2m': 0.5245901639,
#   'precipitation': 0.0,
#   'precipitation_w': 0.2098610148,
#   'precipitation_2m': 1.8577117822},
#  {'date': '2021-05-29',
#   'alert__count': 0,
#   'alert__count_w': 1.2857142857,
#   'alert__count_2m': 0.5245901639,
#   'precipitation': 0.0286415364,
#   'precipitation_w': 0.2057466714,
#   'precipitation_2m': 1.8950386225},
#  {'date': '2021-05-30',
#   'alert__count': 0,
#   'alert__count_w': 1.7142857143,
#   'alert__count_2m': 0.5245901639,
#   'precipitation': 0.7049620306,
#   'precipitation_w': 0.2063441259,
#   'precipitation_2m': 1.7074399365},
#  {'date': '2021-05-31',
#   'alert__count': 0,
#   'alert__count_w': 0.7142857143,
#   'alert__count_2m': 0.5081967213,
#   'precipitation': 0.6751873752,
#   'precipitation_w': 0.2634901371,
#   'precipitation_2m': 1.7018838847},
#  {'date': '2021-06-01',
#   'alert__count': 0,
#   'alert__count_w': 0.5714285714,
#   'alert__count_2m': 0.5081967213,
#   'precipitation': 0.0311598093,
#   'precipitation_w': 0.437375517,
#   'precipitation_2m': 1.698722123},
#  {'date': '2021-06-02',
#   'alert__count': 4,
#   'alert__count_w': 0.5714285714,
#   'alert__count_2m': 0.5081967213,
#   'precipitation': 0.0044581296,
#   'precipitation_w': 1.4350307528,
#   'precipitation_2m': 1.6530044249},
#  {'date': '2021-06-03',
#   'alert__count': 0,
#   'alert__count_w': 0.8571428571,
#   'alert__count_2m': 0.7540983607,
#   'precipitation': 0.4000220787,
#   'precipitation_w': 1.6877205737,
#   'precipitation_2m': 1.6229644658},
#  {'date': '2021-06-04',
#   'alert__count': 0,
#   'alert__count_w': 0.8571428571,
#   'alert__count_2m': 0.8852459016,
#   'precipitation': 1.2171976592,
#   'precipitation_w': 2.0238360033,
#   'precipitation_2m': 1.6170826934},
#  {'date': '2021-06-05',
#   'alert__count': 0,
#   'alert__count_w': 1.0,
#   'alert__count_2m': 0.9180327869,
#   'precipitation': 7.0122281871,
#   'precipitation_w': 2.223996332,
#   'precipitation_2m': 1.5903436414},
#  {'date': '2021-06-06',
#   'alert__count': 2,
#   'alert__count_w': 0.4285714286,
#   'alert__count_2m': 0.9836065574,
#   'precipitation': 2.4737907765,
#   'precipitation_w': 2.3137387566,
#   'precipitation_2m': 1.5613269372},
#  {'date': '2021-06-07',
#   'alert__count': 0,
#   'alert__count_w': 0.4285714286,
#   'alert__count_2m': 0.9672131148,
#   'precipitation': 3.0279953827,
#   'precipitation_w': 2.2676462177,
#   'precipitation_2m': 1.5547128604},
#  {'date': '2021-06-08',
#   'alert__count': 1,
#   'alert__count_w': 0.4285714286,
#   'alert__count_2m': 1.0163934426,
#   'precipitation': 1.4322821103,
#   'precipitation_w': 2.3044712244,
#   'precipitation_2m': 1.5578389716},
#  {'date': '2021-06-09',
#   'alert__count': 0,
#   'alert__count_w': 0.4285714286,
#   'alert__count_2m': 1.2131147541,
#   'precipitation': 0.632655102,
#   'precipitation_w': 1.3174292211,
#   'precipitation_2m': 1.5575464169},
#  {'date': '2021-06-10',
#   'alert__count': 0,
#   'alert__count_w': 0.1428571429,
#   'alert__count_2m': 1.3442622951,
#   'precipitation': 0.0773743061,
#   'precipitation_w': 0.9649698848,
#   'precipitation_2m': 1.507520496},
#  {'date': '2021-06-11',
#   'alert__count': 0,
#   'alert__count_w': 0.1428571429,
#   'alert__count_2m': 1.3770491803,
#   'precipitation': 1.4749727063,
#   'precipitation_w': 0.5323991159,
#   'precipitation_2m': 1.4980503794},
#  {'date': '2021-06-12',
#   'alert__count': 0,
#   'alert__count_w': 0.0,
#   'alert__count_2m': 1.3442622951,
#   'precipitation': 0.1029341641,
#   'precipitation_w': 0.328271966,
#   'precipitation_2m': 1.4953337215},
#  {'date': '2021-06-13',
#   'alert__count': 0,
#   'alert__count_w': 0.0,
#   'alert__count_2m': 1.3770491803,
#   'precipitation': 0.0065754223,
#   'precipitation_w': 0.2727817368,
#   'precipitation_2m': 1.33037145},
#  {'date': '2021-06-14',
#   'alert__count': 0,
#   'alert__count_w': 0.0,
#   'alert__count_2m': 1.5737704918,
#   'precipitation': 0.0,
#   'precipitation_w': 0.8096176782,
#   'precipitation_2m': 1.2003674906},
#  {'date': '2021-06-15',
#   'alert__count': 0,
#   'alert__count_w': 0.2857142857,
#   'alert__count_2m': 1.6721311475,
#   'precipitation': 0.0033920616,
#   'precipitation_w': 0.8545186172,
#   'precipitation_2m': 1.1905557191},
#  {'date': '2021-06-16',
#   'alert__count': 0,
#   'alert__count_w': 0.2857142857,
#   'alert__count_2m': 1.6721311475,
#   'precipitation': 0.2442234976,
#   'precipitation_w': 0.8989328214,
#   'precipitation_2m': 1.087071362},
#  {'date': '2021-06-17',
#   'alert__count': 0,
#   'alert__count_w': 0.2857142857,
#   'alert__count_2m': 1.7049180328,
#   'precipitation': 3.8352258952,
#   'precipitation_w': 0.9804179475,
#   'precipitation_2m': 0.9969766491},
#  {'date': '2021-06-18',
#   'alert__count': 2,
#   'alert__count_w': 0.2857142857,
#   'alert__count_2m': 1.737704918,
#   'precipitation': 1.7892792799,
#   'precipitation_w': 0.9823091832,
#   'precipitation_2m': 0.9793510954},
#  {'date': '2021-06-19',
#   'alert__count': 0,
#   'alert__count_w': 0.2857142857,
#   'alert__count_2m': 1.8524590164,
#   'precipitation': 0.4138335932,
#   'precipitation_w': 0.9957200021,
#   'precipitation_2m': 0.9805891135},
#  {'date': '2021-06-20',
#   'alert__count': 0,
#   'alert__count_w': 0.8571428571,
#   'alert__count_2m': 1.9836065574,
#   'precipitation': 0.5769713053,
#   'precipitation_w': 0.9616491703,
#   'precipitation_2m': 0.97709286},
#  {'date': '2021-06-21',
#   'alert__count': 0,
#   'alert__count_w': 0.8571428571,
#   'alert__count_2m': 2.0491803279,
#   'precipitation': 0.0132386497,
#   'precipitation_w': 0.4137615355,
#   'precipitation_2m': 0.9629306868},
#  {'date': '2021-06-22',
#   'alert__count': 0,
#   'alert__count_w': 0.5714285714,
#   'alert__count_2m': 2.0655737705,
#   'precipitation': 0.0972677938,
#   'precipitation_w': 0.1581502098,
#   'precipitation_2m': 0.8800096301},
#  {'date': '2021-06-23',
#   'alert__count': 4,
#   'alert__count_w': 0.5714285714,
#   'alert__count_2m': 2.131147541,
#   'precipitation': 0.005727675,
#   'precipitation_w': 0.0994661901,
#   'precipitation_2m': 0.7065545391},
#  {'date': '2021-06-24',
#   'alert__count': 0,
#   'alert__count_w': 0.7142857143,
#   'alert__count_2m': 2.2459016393,
#   'precipitation': 1.24516e-05,
#   'precipitation_w': 0.3773897192,
#   'precipitation_2m': 0.5309266974},
#  {'date': '2021-06-25',
#   'alert__count': 0,
#   'alert__count_w': 0.7142857143,
#   'alert__count_2m': 2.6393442623,
#   'precipitation': 0.0,
#   'precipitation_w': 0.7348696162,
#   'precipitation_2m': 0.5304347367},
#  {'date': '2021-06-26',
#   'alert__count': 0,
#   'alert__count_w': 0.7142857143,
#   'alert__count_2m': 2.737704918,
#   'precipitation': 0.0030454555,
#   'precipitation_w': 0.7556028401,
#   'precipitation_2m': 0.5306659708},
#  {'date': '2021-06-27',
#   'alert__count': 1,
#   'alert__count_w': 0.1428571429,
#   'alert__count_2m': 2.6229508197,
#   'precipitation': 2.522436009,
#   'precipitation_w': 0.7547846008,
#   'precipitation_2m': 0.5346832503},
#  {'date': '2021-06-28',
#   'alert__count': 0,
#   'alert__count_w': 0.1428571429,
#   'alert__count_2m': 2.606557377,
#   'precipitation': 2.5155979284,
#   'precipitation_w': 0.7562666713,
#   'precipitation_2m': 0.54889832},
#  {'date': '2021-06-29',
#   'alert__count': 0,
#   'alert__count_w': 0.1428571429,
#   'alert__count_2m': 3.3278688525,
#   'precipitation': 0.2424003609,
#   'precipitation_w': 0.7615875111,
#   'precipitation_2m': 0.5488473536},
#  {'date': '2021-06-30',
#   'alert__count': 0,
#   'alert__count_w': 2.2857142857,
#   'alert__count_2m': 4.3770491803,
#   'precipitation': 0.0,
#   'precipitation_w': 0.7671153784,
#   'precipitation_2m': 0.537290599},
#  {'date': '2021-07-01',
#   'alert__count': 0,
#   'alert__count_w': 3.2857142857,
#   'alert__count_2m': 5.2295081967,
#   'precipitation': 0.0103869456,
#   'precipitation_w': 0.4093932052,
#   'precipitation_2m': 0.5262219535},
#  {'date': '2021-07-02',
#   'alert__count': 0,
#   'alert__count_w': 3.5714285714,
#   'alert__count_2m': 5.5573770492,
#   'precipitation': 0.0372458786,
#   'precipitation_w': 0.0501850609,
#   'precipitation_2m': 0.5268581694},
#  {'date': '2021-07-03',
#   'alert__count': 15,
#   'alert__count_w': 4.1428571429,
#   'alert__count_2m': 6.3442622951,
#   'precipitation': 0.0417405264,
#   'precipitation_w': 0.0173372893,
#   'precipitation_2m': 0.5268126973},
#  {'date': '2021-07-04',
#   'alert__count': 8,
#   'alert__count_w': 4.2857142857,
#   'alert__count_2m': 6.4098360656,
#   'precipitation': 0.0183807966,
#   'precipitation_w': 0.017479341,
#   'precipitation_2m': 0.5203434904},
#  {'date': '2021-07-05',
#   'alert__count': 2,
#   'alert__count_w': 4.7142857143,
#   'alert__count_2m': 6.7213114754,
#   'precipitation': 0.0011409181,
#   'precipitation_w': 0.0461181333,
#   'precipitation_2m': 0.5007392607},
#  {'date': '2021-07-06',
#   'alert__count': 4,
#   'alert__count_w': 6.4285714286,
#   'alert__count_2m': 9.0655737705,
#   'precipitation': 0.0124659594,
#   'precipitation_w': 0.0410900444,
#   'precipitation_2m': 0.3858065261},
#  {'date': '2021-07-07',
#   'alert__count': 1,
#   'alert__count_w': 5.4285714286,
#   'alert__count_2m': 9.3442622951,
#   'precipitation': 0.0009943623,
#   'precipitation_w': 0.0497110012,
#   'precipitation_2m': 0.3463207712},
#  {'date': '2021-07-08',
#   'alert__count': 3,
#   'alert__count_w': 4.8571428571,
#   'alert__count_2m': 9.5573770492,
#   'precipitation': 0.2108584917,
#   'precipitation_w': 0.0507652224,
#   'precipitation_2m': 0.2966815026},
#  {'date': '2021-07-09',
#   'alert__count': 12,
#   'alert__count_w': 4.5714285714,
#   'alert__count_2m': 10.1803278689,
#   'precipitation': 0.0020492559,
#   'precipitation_w': 0.0508586644,
#   'precipitation_2m': 0.2761548282},
#  {'date': '2021-07-10',
#   'alert__count': 8,
#   'alert__count_w': 4.2857142857,
#   'alert__count_2m': 11.3606557377,
#   'precipitation': 0.102087224,
#   'precipitation_w': 0.0497613145,
#   'precipitation_2m': 0.2658128738},
#  {'date': '2021-07-11',
#   'alert__count': 4,
#   'alert__count_w': 5.8571428571,
#   'alert__count_2m': 14.2459016393,
#   'precipitation': 0.0257603451,
#   'precipitation_w': 0.0496192627,
#   'precipitation_2m': 0.2658029722},
#  {'date': '2021-07-12',
#   'alert__count': 0,
#   'alert__count_w': 6.2857142857,
#   'alert__count_2m': 15.0327868852,
#   'precipitation': 0.0017950121,
#   'precipitation_w': 0.019496621,
#   'precipitation_2m': 0.2423370065},
#  {'date': '2021-07-13',
#   'alert__count': 2,
#   'alert__count_w': 4.5714285714,
#   'alert__count_2m': 15.8032786885,
#   'precipitation': 0.0047845102,
#   'precipitation_w': 0.0192038702,
#   'precipitation_2m': 0.2417214555},
#  {'date': '2021-07-14',
#   'alert__count': 12,
#   'alert__count_w': 3.7142857143,
#   'alert__count_2m': 16.8524590164,
#   'precipitation': 0.0,
#   'precipitation_w': 0.0046199811,
#   'precipitation_2m': 0.2416136617},
#  {'date': '2021-07-15',
#   'alert__count': 6,
#   'alert__count_w': 3.7142857143,
#   'alert__count_2m': 17.4590163934,
#   'precipitation': 0.0,
#   'precipitation_w': 0.0204752792,
#   'precipitation_2m': 0.2559236689},
#  {'date': '2021-07-16',
#   'alert__count': 0,
#   'alert__count_w': 4.7142857143,
#   'alert__count_2m': 19.4754098361,
#   'precipitation': 0.0,
#   'precipitation_w': 0.034703489,
#   'precipitation_2m': 0.2617809355},
#  {'date': '2021-07-17',
#   'alert__count': 2,
#   'alert__count_w': 5.5714285714,
#   'alert__count_2m': 20.4918032787,
#   'precipitation': 0.0,
#   'precipitation_w': 0.0340199875,
#   'precipitation_2m': 0.2597584203},
#  {'date': '2021-07-18',
#   'alert__count': 4,
#   'alert__count_w': 4.4285714286,
#   'alert__count_2m': 20.7868852459,
#   'precipitation': 0.1367474319,
#   'precipitation_w': 0.0353909679,
#   'precipitation_2m': 0.2009778042},
#  {'date': '2021-07-19',
#   'alert__count': 7,
#   'alert__count_w': 3.7142857143,
#   'alert__count_2m': 21.8852459016,
#   'precipitation': 0.1013924808,
#   'precipitation_w': 0.0356726728,
#   'precipitation_2m': 0.1758651659},
#  {'date': '2021-07-20',
#   'alert__count': 8,
#   'alert__count_w': 4.2857142857,
#   'alert__count_2m': 22.9672131148,
#   'precipitation': 0.0,
#   'precipitation_w': 0.0416447744,
#   'precipitation_2m': 0.1699535033},
#  {'date': '2021-07-21',
#   'alert__count': 4,
#   'alert__count_w': 5.0,
#   'alert__count_2m': 25.4426229508,
#   'precipitation': 0.0095968624,
#   'precipitation_w': 0.0416447744,
#   'precipitation_2m': 0.1619498055},
#  {'date': '2021-07-22',
#   'alert__count': 1,
#   'alert__count_w': 7.8571428571,
#   'alert__count_2m': 27.0491803279,
#   'precipitation': 0.0019719343,
#   'precipitation_w': 0.0263880859,
#   'precipitation_2m': 0.1636362984},
#  {'date': '2021-07-23',
#   'alert__count': 4,
#   'alert__count_w': 7.8571428571,
#   'alert__count_2m': 28.0327868852,
#   'precipitation': 0.0418047114,
#   'precipitation_w': 0.0139579067,
#   'precipitation_2m': 0.1620905565},
#  {'date': '2021-07-24',
#   'alert__count': 7,
#   'alert__count_w': 6.7142857143,
#   'alert__count_2m': 29.2295081967,
#   'precipitation': 0.0,
#   'precipitation_w': 0.0489656285,
#   'precipitation_2m': 0.162916653},
#  {'date': '2021-07-25',
#   'alert__count': 24,
#   'alert__count_w': 6.1428571429,
#   'alert__count_2m': 30.2295081967,
#   'precipitation': 0.0299506125,
#   'precipitation_w': 0.1714688264,
#   'precipitation_2m': 0.1632766782},
#  {'date': '2021-07-26',
#   'alert__count': 7,
#   'alert__count_w': 12.2857142857,
#   'alert__count_2m': 32.6885245902,
#   'precipitation': 0.0143812261,
#   'precipitation_w': 0.1748346336,
#   'precipitation_2m': 0.1657610082},
# ...
#   'precipitation': 0.2905420349,
#   'precipitation_w': 2.2987686156,
#   'precipitation_2m': 3.1967295688},
#  {'date': '2021-09-27',
#   'alert__count': 71,
#   'alert__count_w': 25.8571428571,
#   'alert__count_2m': 26.7540983607,
#   'precipitation': 4.2162823315,
#   'precipitation_w': 2.0201811171,
#   'precipitation_2m': 3.1663315329},
#  {'date': '2021-09-28',
#   'alert__count': 18,
#   'alert__count_w': 32.7142857143,
#   'alert__count_2m': 26.6557377049,
#   'precipitation': 0.8453466325,
#   'precipitation_w': 1.373309015,
#   'precipitation_2m': 3.2603385078},
#  {'date': '2021-09-29',
#   'alert__count': 13,
#   'alert__count_w': 39.8571428571,
#   'alert__count_2m': 26.9180327869,
#   'precipitation': 0.2010997529,
#   'precipitation_w': 1.7605246664,
#   'precipitation_2m': 3.2704909413},
#  {'date': '2021-09-30',
#   'alert__count': 19,
#   'alert__count_w': 47.4285714286,
#   'alert__count_2m': 27.0491803279,
#   'precipitation': 1.5799318032,
#   'precipitation_w': 1.8547272204,
#   'precipitation_2m': 3.2395940116},
#  {'date': '2021-10-01',
#   'alert__count': 52,
#   'alert__count_w': 41.0,
#   'alert__count_2m': 26.8032786885,
#   'precipitation': 2.359664061,
#   'precipitation_w': 1.6201221546,
#   'precipitation_2m': 3.2844420779},
#  {'date': '2021-10-02',
#   'alert__count': 54,
#   'alert__count_w': 38.4285714286,
#   'alert__count_2m': 26.6885245902,
#   'precipitation': 2.8308060486,
#   'precipitation_w': 4.6709499849,
#   'precipitation_2m': None},
#  {'date': '2021-10-03',
#   'alert__count': 105,
#   'alert__count_w': 36.5714285714,
#   'alert__count_2m': 26.7049180328,
#   'precipitation': 0.9499599134,
#   'precipitation_w': 5.3053235457,
#   'precipitation_2m': None},
#  {'date': '2021-10-04',
#   'alert__count': 26,
#   'alert__count_w': 36.0,
#   'alert__count_2m': 26.5573770492,
#   'precipitation': 2.574046871,
#   'precipitation_w': 5.2412276115,
#   'precipitation_2m': None},
#  {'date': '2021-10-05',
#   'alert__count': 0,
#   'alert__count_w': 29.4285714286,
#   'alert__count_2m': 26.0983606557,
#   'precipitation': 22.2011414445,
#   'precipitation_w': 6.0064600094,
#   'precipitation_2m': None},
#  {'date': '2021-10-06',
#   'alert__count': 0,
#   'alert__count_w': 23.7142857143,
#   'alert__count_2m': 25.5573770492,
#   'precipitation': 4.641714678,
#   'precipitation_w': 5.930578384,
#   'precipitation_2m': None},
#  {'date': '2021-10-07',
#   'alert__count': 15,
#   'alert__count_w': 12.1428571429,
#   'alert__count_2m': 25.4590163934,
#   'precipitation': 1.1312602644,
#   'precipitation_w': 5.813013555,
#   'precipitation_2m': None},
#  {'date': '2021-10-08',
#   'alert__count': 6,
#   'alert__count_w': 13.0,
#   'alert__count_2m': 25.0163934426,
#   'precipitation': 7.7162908459,
#   'precipitation_w': 5.4476770221,
#   'precipitation_2m': None},
#  {'date': '2021-10-09',
#   'alert__count': 14,
#   'alert__count_w': 25.2857142857,
#   'alert__count_2m': 24.0,
#   'precipitation': 2.2996346705,
#   'precipitation_w': 2.5197522461,
#   'precipitation_2m': None},
#  {'date': '2021-10-10',
#   'alert__count': 24,
#   'alert__count_w': 28.8571428571,
#   'alert__count_2m': 23.7868852459,
#   'precipitation': 0.1270061109,
#   'precipitation_w': 2.2848069849,
#   'precipitation_2m': None},
#  {'date': '2021-10-11',
#   'alert__count': 32,
#   'alert__count_w': 35.1428571429,
#   'alert__count_2m': 23.737704918,
#   'precipitation': 0.0166911407,
#   'precipitation_w': 2.1339109436,
#   'precipitation_2m': None},
#  {'date': '2021-10-12',
#   'alert__count': 86,
#   'alert__count_w': 35.5714285714,
#   'alert__count_2m': 23.5573770492,
#   'precipitation': 1.7056680123,
#   'precipitation_w': 1.4802178859,
#   'precipitation_2m': None},
#  {'date': '2021-10-13',
#   'alert__count': 25,
#   'alert__count_w': 35.0,
#   'alert__count_2m': 23.131147541,
#   'precipitation': 2.9970978494,
#   'precipitation_w': 2.1681734316,
#   'precipitation_2m': None},
#  {'date': '2021-10-14',
#   'alert__count': 59,
#   'alert__count_w': 32.0,
#   'alert__count_2m': 22.9180327869,
#   'precipitation': 0.0749879757,
#   'precipitation_w': 3.6047934848,
#   'precipitation_2m': None},
#  {'date': '2021-10-15',
#   'alert__count': 9,
#   'alert__count_w': 27.4285714286,
#   'alert__count_2m': 22.262295082,
#   'precipitation': 3.140439442,
#   'precipitation_w': 4.7181650963,
#   'precipitation_2m': None},
#  {'date': '2021-10-16',
#   'alert__count': 10,
#   'alert__count_w': 15.5714285714,
#   'alert__count_2m': 21.6393442623,
#   'precipitation': 7.1153234905,
#   'precipitation_w': 4.9717041785,
#   'precipitation_2m': None},
#  {'date': '2021-10-17',
#   'alert__count': 3,
#   'alert__count_w': 13.2857142857,
#   'alert__count_2m': 20.5081967213,
#   'precipitation': 10.1833464832,
#   'precipitation_w': 4.9390523247,
#   'precipitation_2m': None},
#  {'date': '2021-10-18',
#   'alert__count': 0,
#   'alert__count_w': 5.8571428571,
#   'alert__count_2m': 18.8852459016,
#   'precipitation': 7.8102924212,
#   'precipitation_w': 5.0998901833,
#   'precipitation_2m': None},
#  {'date': '2021-10-19',
#   'alert__count': 3,
#   'alert__count_w': 6.5714285714,
#   'alert__count_2m': 18.7213114754,
#   'precipitation': 3.4804415876,
#   'precipitation_w': 4.9759848561,
#   'precipitation_2m': None},
#  {'date': '2021-10-20',
#   'alert__count': 9,
#   'alert__count_w': 8.8571428571,
#   'alert__count_2m': 18.5901639344,
#   'precipitation': 2.7685348724,
#   'precipitation_w': 4.1146369769,
#   'precipitation_2m': None},
#  {'date': '2021-10-21',
#   'alert__count': 7,
#   'alert__count_w': 13.4285714286,
#   'alert__count_2m': 18.1475409836,
#   'precipitation': 1.2008529861,
#   'precipitation_w': 3.0675471018,
#   'precipitation_2m': None},
#  {'date': '2021-10-22',
#   'alert__count': 14,
#   'alert__count_w': 13.4285714286,
#   'alert__count_2m': 16.7049180328,
#   'precipitation': 2.2731021515,
#   'precipitation_w': 3.6526511253,
#   'precipitation_2m': None},
#  {'date': '2021-10-23',
#   'alert__count': 26,
#   'alert__count_w': 13.0,
#   'alert__count_2m': 14.5901639344,
#   'precipitation': 1.0858883363,
#   'precipitation_w': 3.3250546587,
#   'precipitation_2m': None},
#  {'date': '2021-10-24',
#   'alert__count': 35,
#   'alert__count_w': 11.7142857143,
#   'alert__count_2m': 14.5901639344,
#   'precipitation': 2.8537173576,
#   'precipitation_w': 3.3816214461,
#   'precipitation_2m': None},
#  {'date': '2021-10-25',
#   'alert__count': 0,
#   'alert__count_w': 10.8571428571,
#   'alert__count_2m': 14.5245901639,
#   'precipitation': 11.9060205855,
#   'precipitation_w': 4.076753947,
#   'precipitation_2m': None},
#  {'date': '2021-10-26',
#   'alert__count': 0,
#   'alert__count_w': 13.1428571429,
#   'alert__count_2m': 14.4918032787,
#   'precipitation': 1.1872663216,
#   'precipitation_w': 4.095239109,
#   'precipitation_2m': None},
#  {'date': '2021-10-27',
#   'alert__count': 0,
#   'alert__count_w': 13.1428571429,
#   'alert__count_2m': 13.6557377049,
#   'precipitation': 3.1645023841,
#   'precipitation_w': 4.028347,
#   'precipitation_2m': None},
#  {'date': '2021-10-28',
#   'alert__count': 1,
#   'alert__count_w': 9.5714285714,
#   'alert__count_2m': 12.4918032787,
#   'precipitation': 6.0667804924,
#   'precipitation_w': 4.3223214513,
#   'precipitation_2m': None},
#  {'date': '2021-10-29',
#   'alert__count': 30,
#   'alert__count_w': 10.0,
#   'alert__count_2m': 12.1967213115,
#   'precipitation': 2.4024982856,
#   'precipitation_w': None,
#   'precipitation_2m': None},
#  {'date': '2021-10-30',
#   'alert__count': 26,
#   'alert__count_w': 10.7142857143,
#   'alert__count_2m': 11.9836065574,
#   'precipitation': 0.6176435735,
#   'precipitation_w': None,
#   'precipitation_2m': None},
#  {'date': '2021-10-31',
#   'alert__count': 10,
#   'alert__count_w': 10.7142857143,
#   'alert__count_2m': 11.6885245902,
#   'precipitation': 4.9115385166,
#   'precipitation_w': None,
#   'precipitation_2m': None},
#  {'date': '2021-11-01',
#   'alert__count': 3,
#   'alert__count_w': 12.4285714286,
#   'alert__count_2m': 10.8360655738,
#   'precipitation': None,
#   'precipitation_w': None,
#   'precipitation_2m': None},
#  {'date': '2021-11-02',
#   'alert__count': 5,
#   'alert__count_w': 8.1428571429,
#   'alert__count_2m': 9.9672131148,
#   'precipitation': None,
#   'precipitation_w': None,
#   'precipitation_2m': None},
#  {'date': '2021-11-03',
#   'alert__count': 0,
#   'alert__count_w': 4.4285714286,
#   'alert__count_2m': 8.2459016393,
#   'precipitation': None,
#   'precipitation_w': None,
#   'precipitation_2m': None},
#  {'date': '2021-11-04',
#   'alert__count': 13,
#   'alert__count_w': 3.0,
#   'alert__count_2m': 7.8196721311,
#   'precipitation': None,
#   'precipitation_w': None,
#   'precipitation_2m': None},
#  {'date': '2021-11-05',
#   'alert__count': 0,
#   'alert__count_w': 2.5714285714,
#   'alert__count_2m': 7.8196721311,
#   'precipitation': None,
#   'precipitation_w': None,
#   'precipitation_2m': None},
#  {'date': '2021-11-06',
#   'alert__count': 0,
#   'alert__count_w': 2.2857142857,
#   'alert__count_2m': 7.8196721311,
#   'precipitation': None,
#   'precipitation_w': None,
#   'precipitation_2m': None},
#  {'date': '2021-11-07',
#   'alert__count': 0,
#   'alert__count_w': 2.2857142857,
#   'alert__count_2m': 7.5737704918,
#   'precipitation': None,
#   'precipitation_w': None,
#   'precipitation_2m': None},
#  {'date': '2021-11-08',
#   'alert__count': 0,
#   'alert__count_w': 0.5714285714,
#   'alert__count_2m': 7.4754098361,
#   'precipitation': None,
#   'precipitation_w': None,
#   'precipitation_2m': None},
#  {'date': '2021-11-09',
#   'alert__count': 3,
#   'alert__count_w': 0.5714285714,
#   'alert__count_2m': 7.2459016393,
#   'precipitation': None,
#   'precipitation_w': None,
#   'precipitation_2m': None},
#  {'date': '2021-11-10',
#   'alert__count': 0,
#   'alert__count_w': 0.5714285714,
#   'alert__count_2m': 6.868852459,
#   'precipitation': None,
#   'precipitation_w': None,
#   'precipitation_2m': None},
#  {'date': '2021-11-11',
#   'alert__count': 1,
#   'alert__count_w': 0.5714285714,
#   'alert__count_2m': 6.3442622951,
#   'precipitation': None,
#   'precipitation_w': None,
#   'precipitation_2m': None},
#  {'date': '2021-11-12',
#   'alert__count': 0,
#   'alert__count_w': 0.5714285714,
#   'alert__count_2m': 4.9344262295,
#   'precipitation': None,
#   'precipitation_w': None,
#   'precipitation_2m': None},
#  {'date': '2021-11-13',
#   'alert__count': 0,
#   'alert__count_w': 0.1428571429,
#   'alert__count_2m': 4.5245901639,
#   'precipitation': None,
#   'precipitation_w': None,
#   'precipitation_2m': None},
#  {'date': '2021-11-14',
#   'alert__count': 0,
#   'alert__count_w': 0.1428571429,
#   'alert__count_2m': 3.5573770492,
#   'precipitation': None,
#   'precipitation_w': None,
#   'precipitation_2m': None},
#  {'date': '2021-11-15',
#   'alert__count': 0,
#   'alert__count_w': 0.0,
#   'alert__count_2m': 3.4098360656,
#   'precipitation': None,
#   'precipitation_w': None,
#   'precipitation_2m': None},
#  {'date': '2021-11-16',
#   'alert__count': 0,
#   'alert__count_w': 0.0,
#   'alert__count_2m': None,
#   'precipitation': None,
#   'precipitation_w': None,
#   'precipitation_2m': None},
#  {'date': '2021-11-17',
#   'alert__count': 0,
#   'alert__count_w': 0.0,
#   'alert__count_2m': None,
#   'precipitation': None,
#   'precipitation_w': None,
#   'precipitation_2m': None},
#  {'date': '2021-11-18',
#   'alert__count': 0,
#   'alert__count_w': 0.2857142857,
#   'alert__count_2m': None,
#   'precipitation': None,
#   'precipitation_w': None,
#   'precipitation_2m': None},
#  {'date': '2021-11-19',
#   'alert__count': 0,
#   'alert__count_w': 0.2857142857,
#   'alert__count_2m': None,
#   'precipitation': None,
#   'precipitation_w': None,
#   'precipitation_2m': None},
#  {'date': '2021-11-20',
#   'alert__count': 0,
#   'alert__count_w': 0.4285714286,
#   'alert__count_2m': None,
#   'precipitation': None,
#   'precipitation_w': None,
#   'precipitation_2m': None},
#  {'date': '2021-11-21',
#   'alert__count': 2,
#   'alert__count_w': 0.4285714286,
#   'alert__count_2m': None,
#   'precipitation': None,
#   'precipitation_w': None,
#   'precipitation_2m': None},
#  {'date': '2021-11-22',
#   'alert__count': 0,
#   'alert__count_w': 0.7142857143,
#   'alert__count_2m': None,
#   'precipitation': None,
#   'precipitation_w': None,
#   'precipitation_2m': None},
#  {'date': '2021-11-23',
#   'alert__count': 1,
#   'alert__count_w': 0.8571428571,
#   'alert__count_2m': None,
#   'precipitation': None,
#   'precipitation_w': None,
#   'precipitation_2m': None},
#  {'date': '2021-11-24',
#   'alert__count': 0,
#   'alert__count_w': 0.8571428571,
#   'alert__count_2m': None,
#   'precipitation': None,
#   'precipitation_w': None,
#   'precipitation_2m': None},
#  {'date': '2021-11-25',
#   'alert__count': 2,
#   'alert__count_w': 0.5714285714,
#   'alert__count_2m': None,
#   'precipitation': None,
#   'precipitation_w': None,
#   'precipitation_2m': None},
#  {'date': '2021-11-26',
#   'alert__count': 1,
#   'alert__count_w': 0.5714285714,
#   'alert__count_2m': None,
#   'precipitation': None,
#   'precipitation_w': None,
#   'precipitation_2m': None},
#  {'date': '2021-11-27',
#   'alert__count': 0,
#   'alert__count_w': 0.5714285714,
#   'alert__count_2m': None,
#   'precipitation': None,
#   'precipitation_w': None,
#   'precipitation_2m': None},
#  {'date': '2021-11-28',
#   'alert__count': 0,
#   'alert__count_w': 0.5714285714,
#   'alert__count_2m': None,
#   'precipitation': None,
#   'precipitation_w': None,
#   'precipitation_2m': None},
#  {'date': '2021-11-29',
#   'alert__count': 0,
#   'alert__count_w': 0.4285714286,
#   'alert__count_2m': None,
#   'precipitation': None,
#   'precipitation_w': None,
#   'precipitation_2m': None},
#  {'date': '2021-11-30',
#   'alert__count': 1,
#   'alert__count_w': 0.2857142857,
#   'alert__count_2m': None,
#   'precipitation': None,
#   'precipitation_w': None,
#   'precipitation_2m': None},
#  {'date': '2021-12-01',
#   'alert__count': 0,
#   'alert__count_w': 0.2857142857,
#   'alert__count_2m': None,
#   'precipitation': None,
#   'precipitation_w': None,
#   'precipitation_2m': None},
#  {'date': '2021-12-02',
#   'alert__count': 1,
#   'alert__count_w': 0.2857142857,
#   'alert__count_2m': None,
#   'precipitation': None,
#   'precipitation_w': None,
#   'precipitation_2m': None},
#  {'date': '2021-12-03',
#   'alert__count': 0,
#   'alert__count_w': 0.2857142857,
#   'alert__count_2m': None,
#   'precipitation': None,
#   'precipitation_w': None,
#   'precipitation_2m': None},
#  {'date': '2021-12-04',
#   'alert__count': 0,
#   'alert__count_w': 0.1428571429,
#   'alert__count_2m': None,
#   'precipitation': None,
#   'precipitation_w': None,
#   'precipitation_2m': None},
#  {'date': '2021-12-05',
#   'alert__count': 0,
#   'alert__count_w': 0.1428571429,
#   'alert__count_2m': None,
#   'precipitation': None,
#   'precipitation_w': None,
#   'precipitation_2m': None},
#  {'date': '2021-12-06',
#   'alert__count': 0,
#   'alert__count_w': 0.0,
#   'alert__count_2m': None,
#   'precipitation': None,
#   'precipitation_w': None,
#   'precipitation_2m': None},
#  {'date': '2021-12-07',
#   'alert__count': 0,
#   'alert__count_w': 0.1428571429,
#   'alert__count_2m': None,
#   'precipitation': None,
#   'precipitation_w': None,
#   'precipitation_2m': None},
#  {'date': '2021-12-08',
#   'alert__count': 0,
#   'alert__count_w': 0.1428571429,
#   'alert__count_2m': None,
#   'precipitation': None,
#   'precipitation_w': None,
#   'precipitation_2m': None},
#  {'date': '2021-12-09',
#   'alert__count': 0,
#   'alert__count_w': 0.1428571429,
#   'alert__count_2m': None,
#   'precipitation': None,
#   'precipitation_w': None,
#   'precipitation_2m': None},
#  {'date': '2021-12-10',
#   'alert__count': 1,
#   'alert__count_w': 0.1428571429,
#   'alert__count_2m': None,
#   'precipitation': None,
#   'precipitation_w': None,
#   'precipitation_2m': None},
#  {'date': '2021-12-11',
#   'alert__count': 0,
#   'alert__count_w': 0.1428571429,
#   'alert__count_2m': None,
#   'precipitation': None,
#   'precipitation_w': None,
#   'precipitation_2m': None},
#  {'date': '2021-12-12',
#   'alert__count': 0,
#   'alert__count_w': 0.1428571429,
#   'alert__count_2m': None,
#   'precipitation': None,
#   'precipitation_w': None,
#   'precipitation_2m': None},
#  {'date': '2021-12-13',
#   'alert__count': 0,
#   'alert__count_w': None,
#   'alert__count_2m': None,
#   'precipitation': None,
#   'precipitation_w': None,
#   'precipitation_2m': None},
#  {'date': '2021-12-14',
#   'alert__count': 0,
#   'alert__count_w': None,
#   'alert__count_2m': None,
#   'precipitation': None,
#   'precipitation_w': None,
#   'precipitation_2m': None},
#  {'date': '2021-12-15',
#   'alert__count': 0,
#   'alert__count_w': None,
#   'alert__count_2m': None,
#   'precipitation': None,
#   'precipitation_w': None,
#   'precipitation_2m': None}]

# %% [markdown]
# ## **Historical data**

# %%
years = np.repeat(np.arange(2012, 2022, 1), 52)
weeks = np.tile(np.arange(1, 53, 1), 10)
hist_dates = years * 100 + weeks
hist_days = pd.to_datetime(
    pd.DataFrame({"date": hist_dates})["date"].astype(str) + "1", format="%Y%W%w"
)

# %% [markdown]
# ###  **VIIRS fire alerts**
# ### National (iso)

# %%
iso = "BRA"
confidence = "h"  #'n', 'l'

query = f"SELECT iso, alert__year, alert__week, SUM(alert__count) AS alert__count, confidence__cat \
        FROM data WHERE iso = '{iso}' AND confidence__cat = '{confidence}' \
        GROUP BY iso, alert__year, alert__week, confidence__cat"

url = f"https://data-api.globalforestwatch.org/dataset/gadm__viirs__iso_weekly_alerts/latest/query"

sql = {"sql": query}
r = requests.get(url, params=sql)

data = r.json().get("data")
df_fire_hist = pd.DataFrame.from_dict(pd.json_normalize(data))
df_fire_hist.sort_values(by=["alert__year", "alert__week"], inplace=True)
# Add dates
dates = df_fire_hist["alert__year"] * 100 + df_fire_hist["alert__week"]
df_fire_hist["alert__date"] = pd.to_datetime(dates.astype(str) + "1", format="%Y%W%w")

# Fill missing dates with 0
df_fire_hist = df_fire_hist[["alert__date", "alert__count"]]
df_fire_hist = df_fire_hist[
    (df_fire_hist["alert__date"] >= hist_days.iloc[0])
    & (df_fire_hist["alert__date"] <= hist_days.iloc[-1])
]
df_fire_hist = df_fire_hist.drop_duplicates("alert__date")
df_fire_hist = (
    df_fire_hist.set_index("alert__date").reindex(hist_days, fill_value=0).reset_index()
)
df_fire_hist["date"] = df_fire_hist["date"].apply(lambda x: x.strftime("%Y-%m-%d"))

df_fire_hist.head()
# Out:
#          date  alert__count
# 0  2012-01-02            22
# 1  2012-01-09             0
# 2  2012-01-16            29
# 3  2012-01-23           144
# 4  2012-01-30           221

# %%
fig, ax = plt.subplots(figsize=(10, 6))
df_fire_hist.plot(
    ax=ax, x="date", y="alert__count", color="r", label="Weekly fire alerts"
)
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# ### Regional (admin1)

# %%
iso = "BRA"
adm1 = 22
confidence = "h"  #'n', 'l'

query = f"SELECT alert__year, alert__week, SUM(alert__count) AS alert__count, confidence__cat \
        FROM data WHERE iso = '{iso}' AND adm1::integer = {adm1} AND confidence__cat = '{confidence}' \
        GROUP BY alert__year, alert__week, confidence__cat"

url = f"https://data-api.globalforestwatch.org/dataset/gadm__viirs__adm1_weekly_alerts/latest/query"

sql = {"sql": query}
r = requests.get(url, params=sql)

data = r.json().get("data")
df_fire_hist = pd.DataFrame.from_dict(pd.json_normalize(data))
df_fire_hist.sort_values(by=["alert__year", "alert__week"], inplace=True)
# Add dates
dates = df_fire_hist["alert__year"] * 100 + df_fire_hist["alert__week"]
df_fire_hist["alert__date"] = pd.to_datetime(dates.astype(str) + "1", format="%Y%W%w")

# Fill missing dates with 0
df_fire_hist = df_fire_hist[["alert__date", "alert__count"]]
df_fire_hist = df_fire_hist[
    (df_fire_hist["alert__date"] >= hist_days.iloc[0])
    & (df_fire_hist["alert__date"] <= hist_days.iloc[-1])
]
df_fire_hist = df_fire_hist.drop_duplicates("alert__date")
df_fire_hist = (
    df_fire_hist.set_index("alert__date").reindex(hist_days, fill_value=0).reset_index()
)
df_fire_hist["date"] = df_fire_hist["date"].apply(lambda x: x.strftime("%Y-%m-%d"))

df_fire_hist.head()
# Out:
#          date  alert__count
# 0  2012-01-02             0
# 1  2012-01-09             0
# 2  2012-01-16             0
# 3  2012-01-23             0
# 4  2012-01-30             0

# %%
fig, ax = plt.subplots(figsize=(10, 6))
df_fire_hist.plot(
    ax=ax, x="date", y="alert__count", color="r", label="Weekly fire alerts"
)
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# ### **CHIRPS Daily precipitation data**

# %%
dataset = (
    ee.ImageCollection("UCSB-CHG/CHIRPS/DAILY")
    .filter(ee.Filter.date("2012-01-01", "2021-12-31"))
    .filterBounds(aoi)
)

chirps_hist = dataset.select("precipitation")

# %%
count = chirps_hist.size()
data = (
    nestedMappedReducer(ee.FeatureCollection(geometry.get("features")), chirps_hist)
    .toList(count)
    .getInfo()
)
# Out:
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# ~/anaconda3/envs/geoenv/lib/python3.8/site-packages/ee/data.py in _execute_cloud_call(call, num_retries)
#     333   try:
# --> 334     return call.execute(num_retries=num_retries)
#     335   except googleapiclient.errors.HttpError as e:
#
# ~/anaconda3/envs/geoenv/lib/python3.8/site-packages/googleapiclient/_helpers.py in positional_wrapper(*args, **kwargs)
#     133                     logger.warning(message)
# --> 134             return wrapped(*args, **kwargs)
#     135
#
# ~/anaconda3/envs/geoenv/lib/python3.8/site-packages/googleapiclient/http.py in execute(self, http, num_retries)
#     914         if resp.status >= 300:
# --> 915             raise HttpError(resp, content, uri=self.uri)
#     916         return self.postproc(resp, content)
#
# HttpError: <HttpError 400 when requesting https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/value:compute?prettyPrint=false&alt=json returned "Computation timed out.". Details: "Computation timed out.">
#
# During handling of the above exception, another exception occurred:
#
# EEException                               Traceback (most recent call last)
# /tmp/ipykernel_9707/2206345883.py in <module>
#       1 count = chirps_hist.size()
# ----> 2 data = nestedMappedReducer(ee.FeatureCollection(geometry.get('features')), chirps_hist).toList(count).getInfo()
#
# ~/anaconda3/envs/geoenv/lib/python3.8/site-packages/ee/computedobject.py in getInfo(self)
#      96       The object can evaluate to anything.
#      97     """
# ---> 98     return data.computeValue(self)
#      99
#     100   def encode(self, encoder):
#
# ~/anaconda3/envs/geoenv/lib/python3.8/site-packages/ee/data.py in computeValue(obj)
#     670     The result of evaluating that object on the server.
#     671   """
# --> 672   return _execute_cloud_call(
#     673       _get_cloud_api_resource().projects().value().compute(
#     674           body={'expression': serializer.encode(obj, for_cloud_api=True)},
#
# ~/anaconda3/envs/geoenv/lib/python3.8/site-packages/ee/data.py in _execute_cloud_call(call, num_retries)
#     334     return call.execute(num_retries=num_retries)
#     335   except googleapiclient.errors.HttpError as e:
# --> 336     raise _translate_cloud_exception(e)
#     337
#     338
#
# EEException: Computation timed out.

# %%
df_pre_hist = pd.DataFrame(map(lambda x: x.get("properties"), data))
# 1 week moving average
df_pre_hist["precipitation_w"] = (
    df_pre_hist[["date", "precipitation"]].rolling(window=7, center=True).sum()
)
# take historic year days
df_pre_hist = df_pre_hist[
    df_pre_hist["date"].isin(list(hist_days.apply(lambda x: x.strftime("%Y-%m-%d"))))
]
# Fill missing dates with 0
df_pre_hist = (
    df_pre_hist.set_index("date")
    .reindex(list(hist_days.apply(lambda x: x.strftime("%Y-%m-%d"))), fill_value=0)
    .reset_index()
)
df_pre_hist

# %%
fig, ax = plt.subplots(figsize=(10, 6))
df_pre_hist.plot(
    ax=ax, x="date", y="precipitation_w", color="b", label="Weekly precipitation"
)

# %% [markdown]
# ####  **Final widget example**

# %%
fig, ax = plt.subplots(figsize=(14, 6))

ax2 = ax.twinx()
df_pre_hist.plot(
    ax=ax,
    x="date",
    y="precipitation_w",
    color="b",
    label="Weekly precipitation",
    legend=True,
)
df_fire_hist.plot(
    ax=ax2,
    x="date",
    y="alert__count",
    color="r",
    label="Weekly fire alerts",
    legend=True,
)

ax.legend(loc="upper left")
ax2.legend(loc="upper right")
ax.set_ylabel("Precipitation [mm/week]", color="b")
ax2.set_ylabel("Fire alerts", color="r")

# %% [markdown]
# ### **List of countries**
# **Countries that entirely intersect with the CHIRPS**

# %%
query = f"SELECT iso, name_0 \
    FROM gadm36_countries \
    WHERE ST_Contains(ST_MakeEnvelope('-180', '-50.5', 180, 50.5, 4326), the_geom)"

url = f"https://api.resourcewatch.org/v1/query/Political-boundaries-GADM-36"

sql = {"sql": query}
r = requests.get(url, params=sql)

data = r.json().get("data")
data
# Out:
# [{'iso': 'NFK', 'name_0': 'Norfolk Island'},
#  {'iso': 'JEY', 'name_0': 'Jersey'},
#  {'iso': 'KWT', 'name_0': 'Kuwait'},
#  {'iso': 'BFA', 'name_0': 'Burkina Faso'},
#  {'iso': 'BGD', 'name_0': 'Bangladesh'},
#  {'iso': 'BGR', 'name_0': 'Bulgaria'},
#  {'iso': 'MCO', 'name_0': 'Monaco'},
#  {'iso': 'MDA', 'name_0': 'Moldova'},
#  {'iso': 'MDG', 'name_0': 'Madagascar'},
#  {'iso': 'MHL', 'name_0': 'Marshall Islands'},
#  {'iso': 'MKD', 'name_0': 'Macedonia'},
#  {'iso': 'MLI', 'name_0': 'Mali'},
#  {'iso': 'MLT', 'name_0': 'Malta'},
#  {'iso': 'MMR', 'name_0': 'Myanmar'},
#  {'iso': 'MNE', 'name_0': 'Montenegro'},
#  {'iso': 'ALB', 'name_0': 'Albania'},
#  {'iso': 'ATG', 'name_0': 'Antigua and Barbuda'},
#  {'iso': 'AUT', 'name_0': 'Austria'},
#  {'iso': 'AZE', 'name_0': 'Azerbaijan'},
#  {'iso': 'BDI', 'name_0': 'Burundi'},
#  {'iso': 'BEN', 'name_0': 'Benin'},
#  {'iso': 'BES', 'name_0': 'Bonaire, Sint Eustatius and Saba'},
#  {'iso': 'BHR', 'name_0': 'Bahrain'},
#  {'iso': 'BHS', 'name_0': 'Bahamas'},
#  {'iso': 'BIH', 'name_0': 'Bosnia and Herzegovina'},
#  {'iso': 'BRA', 'name_0': 'Brazil'},
#  {'iso': 'ABW', 'name_0': 'Aruba'},
#  {'iso': 'BRB', 'name_0': 'Barbados'},
#  {'iso': 'CHE', 'name_0': 'Switzerland'},
#  {'iso': 'CIV', 'name_0': "Côte d'Ivoire"},
#  {'iso': 'CMR', 'name_0': 'Cameroon'},
#  {'iso': 'COD', 'name_0': 'Democratic Republic of the Congo'},
#  {'iso': 'COG', 'name_0': 'Republic of Congo'},
#  {'iso': 'COK', 'name_0': 'Cook Islands'},
#  {'iso': 'COL', 'name_0': 'Colombia'},
#  {'iso': 'COM', 'name_0': 'Comoros'},
#  {'iso': 'CPV', 'name_0': 'Cape Verde'},
#  {'iso': 'CRI', 'name_0': 'Costa Rica'},
#  {'iso': 'CUB', 'name_0': 'Cuba'},
#  {'iso': 'CUW', 'name_0': 'Curaçao'},
#  {'iso': 'DJI', 'name_0': 'Djibouti'},
#  {'iso': 'BLM', 'name_0': 'Saint-Barthélemy'},
#  {'iso': 'BLZ', 'name_0': 'Belize'},
#  {'iso': 'BMU', 'name_0': 'Bermuda'},
#  {'iso': 'AND', 'name_0': 'Andorra'},
#  {'iso': 'ARE', 'name_0': 'United Arab Emirates'},
#  {'iso': 'ARM', 'name_0': 'Armenia'},
#  {'iso': 'ASM', 'name_0': 'American Samoa'},
#  {'iso': 'ATF', 'name_0': 'French Southern Territories'},
#  {'iso': 'BOL', 'name_0': 'Bolivia'},
#  {'iso': 'BWA', 'name_0': 'Botswana'},
#  {'iso': 'ERI', 'name_0': 'Eritrea'},
#  {'iso': 'ESH', 'name_0': 'Western Sahara'},
#  {'iso': 'ETH', 'name_0': 'Ethiopia'},
#  {'iso': 'FJI', 'name_0': 'Fiji'},
#  {'iso': 'MYS', 'name_0': 'Malaysia'},
#  {'iso': 'NAM', 'name_0': 'Namibia'},
#  {'iso': 'NCL', 'name_0': 'New Caledonia'},
#  {'iso': 'NRU', 'name_0': 'Nauru'},
#  {'iso': 'NGA', 'name_0': 'Nigeria'},
#  {'iso': 'IDN', 'name_0': 'Indonesia'},
#  {'iso': 'IND', 'name_0': 'India'},
#  {'iso': 'IOT', 'name_0': 'British Indian Ocean Territory'},
#  {'iso': 'HUN', 'name_0': 'Hungary'},
#  {'iso': 'OMN', 'name_0': 'Oman'},
#  {'iso': 'PAK', 'name_0': 'Pakistan'},
#  {'iso': 'GLP', 'name_0': 'Guadeloupe'},
#  {'iso': 'ESP', 'name_0': 'Spain'},
#  {'iso': 'IRN', 'name_0': 'Iran'},
#  {'iso': 'CYP', 'name_0': 'Cyprus'},
#  {'iso': 'NER', 'name_0': 'Niger'},
#  {'iso': 'SDN', 'name_0': 'Sudan'},
#  {'iso': 'RWA', 'name_0': 'Rwanda'},
#  {'iso': 'GAB', 'name_0': 'Gabon'},
#  {'iso': 'GEO', 'name_0': 'Georgia'},
#  {'iso': 'GGY', 'name_0': 'Guernsey'},
#  {'iso': 'GHA', 'name_0': 'Ghana'},
#  {'iso': 'HRV', 'name_0': 'Croatia'},
#  {'iso': 'PAN', 'name_0': 'Panama'},
#  {'iso': 'PRY', 'name_0': 'Paraguay'},
#  {'iso': 'PSE', 'name_0': 'Palestina'},
#  {'iso': 'PYF', 'name_0': 'French Polynesia'},
#  {'iso': 'QAT', 'name_0': 'Qatar'},
#  {'iso': 'REU', 'name_0': 'Reunion'},
#  {'iso': 'ROU', 'name_0': 'Romania'},
#  {'iso': 'SEN', 'name_0': 'Senegal'},
#  {'iso': 'PHL', 'name_0': 'Philippines'},
#  {'iso': 'CXR', 'name_0': 'Christmas Island'},
#  {'iso': 'CYM', 'name_0': 'Cayman Islands'},
#  {'iso': 'SGP', 'name_0': 'Singapore'},
#  {'iso': 'SHN', 'name_0': 'Saint Helena'},
#  {'iso': 'SLB', 'name_0': 'Solomon Islands'},
#  {'iso': 'SLE', 'name_0': 'Sierra Leone'},
#  {'iso': 'SLV', 'name_0': 'El Salvador'},
#  {'iso': 'IRQ', 'name_0': 'Iraq'},
#  {'iso': 'ISR', 'name_0': 'Israel'},
#  {'iso': 'ITA', 'name_0': 'Italy'},
#  {'iso': 'JAM', 'name_0': 'Jamaica'},
#  {'iso': 'KNA', 'name_0': 'Saint Kitts and Nevis'},
#  {'iso': 'GIB', 'name_0': 'Gibraltar'},
#  {'iso': 'GIN', 'name_0': 'Guinea'},
#  {'iso': 'GMB', 'name_0': 'Gambia'},
#  {'iso': 'GNB', 'name_0': 'Guinea-Bissau'},
#  {'iso': 'GNQ', 'name_0': 'Equatorial Guinea'},
#  {'iso': 'GRC', 'name_0': 'Greece'},
#  {'iso': 'GRD', 'name_0': 'Grenada'},
#  {'iso': 'GTM', 'name_0': 'Guatemala'},
#  {'iso': 'GUF', 'name_0': 'French Guiana'},
#  {'iso': 'GUM', 'name_0': 'Guam'},
#  {'iso': 'GUY', 'name_0': 'Guyana'},
#  {'iso': 'HKG', 'name_0': 'Hong Kong'},
#  {'iso': 'KOR', 'name_0': 'South Korea'},
#  {'iso': 'LAO', 'name_0': 'Laos'},
#  {'iso': 'LBN', 'name_0': 'Lebanon'},
#  {'iso': 'LBR', 'name_0': 'Liberia'},
#  {'iso': 'LBY', 'name_0': 'Libya'},
#  {'iso': 'HND', 'name_0': 'Honduras'},
#  {'iso': 'TZA', 'name_0': 'Tanzania'},
#  {'iso': 'URY', 'name_0': 'Uruguay'},
#  {'iso': 'UZB', 'name_0': 'Uzbekistan'},
#  {'iso': 'NPL', 'name_0': 'Nepal'},
#  {'iso': 'MAR', 'name_0': 'Morocco'},
#  {'iso': 'MDV', 'name_0': 'Maldives'},
#  {'iso': 'MEX', 'name_0': 'Mexico'},
#  {'iso': 'PLW', 'name_0': 'Palau'},
#  {'iso': 'KIR', 'name_0': 'Kiribati'},
#  {'iso': 'PCN', 'name_0': 'Pitcairn Islands'},
#  {'iso': 'PER', 'name_0': 'Peru'},
#  {'iso': 'STP', 'name_0': 'São Tomé and Príncipe'},
#  {'iso': 'SUR', 'name_0': 'Suriname'},
#  {'iso': 'SVK', 'name_0': 'Slovakia'},
#  {'iso': 'SVN', 'name_0': 'Slovenia'},
#  {'iso': 'LIE', 'name_0': 'Liechtenstein'},
#  {'iso': 'LKA', 'name_0': 'Sri Lanka'},
#  {'iso': 'LSO', 'name_0': 'Lesotho'},
#  {'iso': 'LUX', 'name_0': 'Luxembourg'},
#  {'iso': 'MAC', 'name_0': 'Macao'},
#  {'iso': 'UMI', 'name_0': 'United States Minor Outlying Islands'},
#  {'iso': 'TKM', 'name_0': 'Turkmenistan'},
#  {'iso': 'TLS', 'name_0': 'Timor-Leste'},
#  {'iso': 'TON', 'name_0': 'Tonga'},
#  {'iso': 'TTO', 'name_0': 'Trinidad and Tobago'},
#  {'iso': 'NIU', 'name_0': 'Niue'},
#  {'iso': 'SXM', 'name_0': 'Sint Maarten'},
#  {'iso': 'SYC', 'name_0': 'Seychelles'},
#  {'iso': 'SYR', 'name_0': 'Syria'},
#  {'iso': 'TCA', 'name_0': 'Turks and Caicos Islands'},
#  {'iso': 'TCD', 'name_0': 'Chad'},
#  {'iso': 'TGO', 'name_0': 'Togo'},
#  {'iso': 'THA', 'name_0': 'Thailand'},
#  {'iso': 'TJK', 'name_0': 'Tajikistan'},
#  {'iso': 'TKL', 'name_0': 'Tokelau'},
#  {'iso': 'BTN', 'name_0': 'Bhutan'},
#  {'iso': 'VAT', 'name_0': 'Vatican City'},
#  {'iso': 'LCA', 'name_0': 'Saint Lucia'},
#  {'iso': 'MNP', 'name_0': 'Northern Mariana Islands'},
#  {'iso': 'MOZ', 'name_0': 'Mozambique'},
#  {'iso': 'MRT', 'name_0': 'Mauritania'},
#  {'iso': 'MTQ', 'name_0': 'Martinique'},
#  {'iso': 'MWI', 'name_0': 'Malawi'},
#  {'iso': 'AGO', 'name_0': 'Angola'},
#  {'iso': 'AIA', 'name_0': 'Anguilla'},
#  {'iso': 'PNG', 'name_0': 'Papua New Guinea'},
#  {'iso': 'PRI', 'name_0': 'Puerto Rico'},
#  {'iso': 'PRK', 'name_0': 'North Korea'},
#  {'iso': 'PRT', 'name_0': 'Portugal'},
#  {'iso': 'MYT', 'name_0': 'Mayotte'},
#  {'iso': 'SAU', 'name_0': 'Saudi Arabia'},
#  {'iso': 'FSM', 'name_0': 'Micronesia'},
#  {'iso': 'XCL', 'name_0': 'Clipperton Island'},
#  {'iso': 'AFG', 'name_0': 'Afghanistan'},
#  {'iso': 'DMA', 'name_0': 'Dominica'},
#  {'iso': 'DOM', 'name_0': 'Dominican Republic'},
#  {'iso': 'DZA', 'name_0': 'Algeria'},
#  {'iso': 'ECU', 'name_0': 'Ecuador'},
#  {'iso': 'EGY', 'name_0': 'Egypt'},
#  {'iso': 'BRN', 'name_0': 'Brunei'},
#  {'iso': 'SWZ', 'name_0': 'Swaziland'},
#  {'iso': 'TUN', 'name_0': 'Tunisia'},
#  {'iso': 'TUR', 'name_0': 'Turkey'},
#  {'iso': 'TUV', 'name_0': 'Tuvalu'},
#  {'iso': 'TWN', 'name_0': 'Taiwan'},
#  {'iso': 'MAF', 'name_0': 'Saint-Martin'},
#  {'iso': 'UGA', 'name_0': 'Uganda'},
#  {'iso': 'MUS', 'name_0': 'Mauritius'},
#  {'iso': 'JOR', 'name_0': 'Jordan'},
#  {'iso': 'JPN', 'name_0': 'Japan'},
#  {'iso': 'KEN', 'name_0': 'Kenya'},
#  {'iso': 'KGZ', 'name_0': 'Kyrgyzstan'},
#  {'iso': 'KHM', 'name_0': 'Cambodia'},
#  {'iso': 'NIC', 'name_0': 'Nicaragua'},
#  {'iso': 'XAD', 'name_0': 'Akrotiri and Dhekelia'},
#  {'iso': 'CAF', 'name_0': 'Central African Republic'},
#  {'iso': 'CCK', 'name_0': 'Cocos Islands'},
#  {'iso': 'HTI', 'name_0': 'Haiti'},
#  {'iso': 'WSM', 'name_0': 'Samoa'},
#  {'iso': 'SMR', 'name_0': 'San Marino'},
#  {'iso': 'SOM', 'name_0': 'Somalia'},
#  {'iso': 'SPM', 'name_0': 'Saint Pierre and Miquelon'},
#  {'iso': 'SRB', 'name_0': 'Serbia'},
#  {'iso': 'SSD', 'name_0': 'South Sudan'},
#  {'iso': 'VCT', 'name_0': 'Saint Vincent and the Grenadines'},
#  {'iso': 'MSR', 'name_0': 'Montserrat'},
#  {'iso': 'VEN', 'name_0': 'Venezuela'},
#  {'iso': 'VGB', 'name_0': 'British Virgin Islands'},
#  {'iso': 'VIR', 'name_0': 'Virgin Islands, U.S.'},
#  {'iso': 'VNM', 'name_0': 'Vietnam'},
#  {'iso': 'VUT', 'name_0': 'Vanuatu'},
#  {'iso': 'WLF', 'name_0': 'Wallis and Futuna'},
#  {'iso': 'XCA', 'name_0': 'Caspian Sea'},
#  {'iso': 'XKO', 'name_0': 'Kosovo'},
#  {'iso': 'XNC', 'name_0': 'Northern Cyprus'},
#  {'iso': 'YEM', 'name_0': 'Yemen'},
#  {'iso': 'ZAF', 'name_0': 'South Africa'},
#  {'iso': 'ZMB', 'name_0': 'Zambia'},
#  {'iso': 'ZWE', 'name_0': 'Zimbabwe'}]

# %% [markdown]
# **Countries that partially intersect with the CHIRPS**

# %%
query = f"SELECT iso, name_0 \
    FROM gadm36_countries \
    WHERE ST_Intersects(ST_MakeEnvelope('-180', '-50.5', 180, 50.5, 4326), the_geom)"

url = f"https://api.resourcewatch.org/v1/query/Political-boundaries-GADM-36"

sql = {"sql": query}
r = requests.get(url, params=sql)

data = r.json().get("data")
data
# Out:
# [{'iso': 'NFK', 'name_0': 'Norfolk Island'},
#  {'iso': 'JEY', 'name_0': 'Jersey'},
#  {'iso': 'KWT', 'name_0': 'Kuwait'},
#  {'iso': 'BFA', 'name_0': 'Burkina Faso'},
#  {'iso': 'BGD', 'name_0': 'Bangladesh'},
#  {'iso': 'BGR', 'name_0': 'Bulgaria'},
#  {'iso': 'MCO', 'name_0': 'Monaco'},
#  {'iso': 'MDA', 'name_0': 'Moldova'},
#  {'iso': 'MDG', 'name_0': 'Madagascar'},
#  {'iso': 'MHL', 'name_0': 'Marshall Islands'},
#  {'iso': 'MKD', 'name_0': 'Macedonia'},
#  {'iso': 'MLI', 'name_0': 'Mali'},
#  {'iso': 'MLT', 'name_0': 'Malta'},
#  {'iso': 'MMR', 'name_0': 'Myanmar'},
#  {'iso': 'MNE', 'name_0': 'Montenegro'},
#  {'iso': 'MNG', 'name_0': 'Mongolia'},
#  {'iso': 'ALB', 'name_0': 'Albania'},
#  {'iso': 'ATG', 'name_0': 'Antigua and Barbuda'},
#  {'iso': 'AUS', 'name_0': 'Australia'},
#  {'iso': 'AUT', 'name_0': 'Austria'},
#  {'iso': 'AZE', 'name_0': 'Azerbaijan'},
#  {'iso': 'BDI', 'name_0': 'Burundi'},
#  {'iso': 'BEN', 'name_0': 'Benin'},
#  {'iso': 'BES', 'name_0': 'Bonaire, Sint Eustatius and Saba'},
#  {'iso': 'BHR', 'name_0': 'Bahrain'},
#  {'iso': 'BHS', 'name_0': 'Bahamas'},
#  {'iso': 'BIH', 'name_0': 'Bosnia and Herzegovina'},
#  {'iso': 'BRA', 'name_0': 'Brazil'},
#  {'iso': 'ABW', 'name_0': 'Aruba'},
#  {'iso': 'BRB', 'name_0': 'Barbados'},
#  {'iso': 'CHE', 'name_0': 'Switzerland'},
#  {'iso': 'CHL', 'name_0': 'Chile'},
#  {'iso': 'CHN', 'name_0': 'China'},
#  {'iso': 'CIV', 'name_0': "Côte d'Ivoire"},
#  {'iso': 'CMR', 'name_0': 'Cameroon'},
#  {'iso': 'COD', 'name_0': 'Democratic Republic of the Congo'},
#  {'iso': 'COG', 'name_0': 'Republic of Congo'},
#  {'iso': 'COK', 'name_0': 'Cook Islands'},
#  {'iso': 'COL', 'name_0': 'Colombia'},
#  {'iso': 'COM', 'name_0': 'Comoros'},
#  {'iso': 'CPV', 'name_0': 'Cape Verde'},
#  {'iso': 'CRI', 'name_0': 'Costa Rica'},
#  {'iso': 'CUB', 'name_0': 'Cuba'},
#  {'iso': 'CUW', 'name_0': 'Curaçao'},
#  {'iso': 'DEU', 'name_0': 'Germany'},
#  {'iso': 'DJI', 'name_0': 'Djibouti'},
#  {'iso': 'BLM', 'name_0': 'Saint-Barthélemy'},
#  {'iso': 'BLZ', 'name_0': 'Belize'},
#  {'iso': 'BMU', 'name_0': 'Bermuda'},
#  {'iso': 'AND', 'name_0': 'Andorra'},
#  {'iso': 'ARE', 'name_0': 'United Arab Emirates'},
#  {'iso': 'ARG', 'name_0': 'Argentina'},
#  {'iso': 'ARM', 'name_0': 'Armenia'},
#  {'iso': 'ASM', 'name_0': 'American Samoa'},
#  {'iso': 'ATF', 'name_0': 'French Southern Territories'},
#  {'iso': 'BOL', 'name_0': 'Bolivia'},
#  {'iso': 'BWA', 'name_0': 'Botswana'},
#  {'iso': 'ERI', 'name_0': 'Eritrea'},
#  {'iso': 'ESH', 'name_0': 'Western Sahara'},
#  {'iso': 'ETH', 'name_0': 'Ethiopia'},
#  {'iso': 'FJI', 'name_0': 'Fiji'},
#  {'iso': 'MYS', 'name_0': 'Malaysia'},
#  {'iso': 'NAM', 'name_0': 'Namibia'},
#  {'iso': 'NCL', 'name_0': 'New Caledonia'},
#  {'iso': 'NRU', 'name_0': 'Nauru'},
#  {'iso': 'NGA', 'name_0': 'Nigeria'},
#  {'iso': 'IDN', 'name_0': 'Indonesia'},
#  {'iso': 'IND', 'name_0': 'India'},
#  {'iso': 'IOT', 'name_0': 'British Indian Ocean Territory'},
#  {'iso': 'HUN', 'name_0': 'Hungary'},
#  {'iso': 'NZL', 'name_0': 'New Zealand'},
#  {'iso': 'OMN', 'name_0': 'Oman'},
#  {'iso': 'PAK', 'name_0': 'Pakistan'},
#  {'iso': 'GLP', 'name_0': 'Guadeloupe'},
#  {'iso': 'ESP', 'name_0': 'Spain'},
#  {'iso': 'IRN', 'name_0': 'Iran'},
#  {'iso': 'CYP', 'name_0': 'Cyprus'},
#  {'iso': 'CZE', 'name_0': 'Czech Republic'},
#  {'iso': 'NER', 'name_0': 'Niger'},
#  {'iso': 'SDN', 'name_0': 'Sudan'},
#  {'iso': 'RWA', 'name_0': 'Rwanda'},
#  {'iso': 'GAB', 'name_0': 'Gabon'},
#  {'iso': 'GBR', 'name_0': 'United Kingdom'},
#  {'iso': 'GEO', 'name_0': 'Georgia'},
#  {'iso': 'GGY', 'name_0': 'Guernsey'},
#  {'iso': 'GHA', 'name_0': 'Ghana'},
#  {'iso': 'HRV', 'name_0': 'Croatia'},
#  {'iso': 'PAN', 'name_0': 'Panama'},
#  {'iso': 'PRY', 'name_0': 'Paraguay'},
#  {'iso': 'PSE', 'name_0': 'Palestina'},
#  {'iso': 'PYF', 'name_0': 'French Polynesia'},
#  {'iso': 'QAT', 'name_0': 'Qatar'},
#  {'iso': 'REU', 'name_0': 'Reunion'},
#  {'iso': 'ROU', 'name_0': 'Romania'},
#  {'iso': 'SEN', 'name_0': 'Senegal'},
#  {'iso': 'PHL', 'name_0': 'Philippines'},
#  {'iso': 'CXR', 'name_0': 'Christmas Island'},
#  {'iso': 'CYM', 'name_0': 'Cayman Islands'},
#  {'iso': 'SGP', 'name_0': 'Singapore'},
#  {'iso': 'SHN', 'name_0': 'Saint Helena'},
#  {'iso': 'RUS', 'name_0': 'Russia'},
#  {'iso': 'SLB', 'name_0': 'Solomon Islands'},
#  {'iso': 'SLE', 'name_0': 'Sierra Leone'},
#  {'iso': 'SLV', 'name_0': 'El Salvador'},
#  {'iso': 'IRQ', 'name_0': 'Iraq'},
#  {'iso': 'ISR', 'name_0': 'Israel'},
#  {'iso': 'ITA', 'name_0': 'Italy'},
#  {'iso': 'JAM', 'name_0': 'Jamaica'},
#  {'iso': 'KNA', 'name_0': 'Saint Kitts and Nevis'},
#  {'iso': 'GIB', 'name_0': 'Gibraltar'},
#  {'iso': 'GIN', 'name_0': 'Guinea'},
#  {'iso': 'GMB', 'name_0': 'Gambia'},
#  {'iso': 'GNB', 'name_0': 'Guinea-Bissau'},
#  {'iso': 'GNQ', 'name_0': 'Equatorial Guinea'},
#  {'iso': 'GRC', 'name_0': 'Greece'},
#  {'iso': 'GRD', 'name_0': 'Grenada'},
#  {'iso': 'GTM', 'name_0': 'Guatemala'},
#  {'iso': 'GUF', 'name_0': 'French Guiana'},
#  {'iso': 'GUM', 'name_0': 'Guam'},
#  {'iso': 'GUY', 'name_0': 'Guyana'},
#  {'iso': 'HKG', 'name_0': 'Hong Kong'},
#  {'iso': 'KOR', 'name_0': 'South Korea'},
#  {'iso': 'LAO', 'name_0': 'Laos'},
#  {'iso': 'LBN', 'name_0': 'Lebanon'},
#  {'iso': 'LBR', 'name_0': 'Liberia'},
#  {'iso': 'LBY', 'name_0': 'Libya'},
#  {'iso': 'HND', 'name_0': 'Honduras'},
#  {'iso': 'TZA', 'name_0': 'Tanzania'},
#  {'iso': 'URY', 'name_0': 'Uruguay'},
#  {'iso': 'USA', 'name_0': 'United States'},
#  {'iso': 'UKR', 'name_0': 'Ukraine'},
#  {'iso': 'UZB', 'name_0': 'Uzbekistan'},
#  {'iso': 'NPL', 'name_0': 'Nepal'},
#  {'iso': 'MAR', 'name_0': 'Morocco'},
#  {'iso': 'MDV', 'name_0': 'Maldives'},
#  {'iso': 'MEX', 'name_0': 'Mexico'},
#  {'iso': 'PLW', 'name_0': 'Palau'},
#  {'iso': 'KIR', 'name_0': 'Kiribati'},
#  {'iso': 'PCN', 'name_0': 'Pitcairn Islands'},
#  {'iso': 'PER', 'name_0': 'Peru'},
#  {'iso': 'STP', 'name_0': 'São Tomé and Príncipe'},
#  {'iso': 'SUR', 'name_0': 'Suriname'},
#  {'iso': 'SVK', 'name_0': 'Slovakia'},
#  {'iso': 'SVN', 'name_0': 'Slovenia'},
#  {'iso': 'LIE', 'name_0': 'Liechtenstein'},
#  {'iso': 'LKA', 'name_0': 'Sri Lanka'},
#  {'iso': 'LSO', 'name_0': 'Lesotho'},
#  {'iso': 'LUX', 'name_0': 'Luxembourg'},
#  {'iso': 'MAC', 'name_0': 'Macao'},
#  {'iso': 'UMI', 'name_0': 'United States Minor Outlying Islands'},
#  {'iso': 'TKM', 'name_0': 'Turkmenistan'},
#  {'iso': 'TLS', 'name_0': 'Timor-Leste'},
#  {'iso': 'TON', 'name_0': 'Tonga'},
#  {'iso': 'TTO', 'name_0': 'Trinidad and Tobago'},
#  {'iso': 'NIU', 'name_0': 'Niue'},
#  {'iso': 'SXM', 'name_0': 'Sint Maarten'},
#  {'iso': 'SYC', 'name_0': 'Seychelles'},
#  {'iso': 'SYR', 'name_0': 'Syria'},
#  {'iso': 'TCA', 'name_0': 'Turks and Caicos Islands'},
#  {'iso': 'TCD', 'name_0': 'Chad'},
#  {'iso': 'TGO', 'name_0': 'Togo'},
#  {'iso': 'THA', 'name_0': 'Thailand'},
#  {'iso': 'TJK', 'name_0': 'Tajikistan'},
#  {'iso': 'TKL', 'name_0': 'Tokelau'},
#  {'iso': 'BTN', 'name_0': 'Bhutan'},
#  {'iso': 'VAT', 'name_0': 'Vatican City'},
#  {'iso': 'LCA', 'name_0': 'Saint Lucia'},
#  {'iso': 'MNP', 'name_0': 'Northern Mariana Islands'},
#  {'iso': 'MOZ', 'name_0': 'Mozambique'},
#  {'iso': 'MRT', 'name_0': 'Mauritania'},
#  {'iso': 'MTQ', 'name_0': 'Martinique'},
#  {'iso': 'MWI', 'name_0': 'Malawi'},
#  {'iso': 'AGO', 'name_0': 'Angola'},
#  {'iso': 'AIA', 'name_0': 'Anguilla'},
#  {'iso': 'PNG', 'name_0': 'Papua New Guinea'},
#  {'iso': 'POL', 'name_0': 'Poland'},
#  {'iso': 'PRI', 'name_0': 'Puerto Rico'},
#  {'iso': 'PRK', 'name_0': 'North Korea'},
#  {'iso': 'PRT', 'name_0': 'Portugal'},
#  {'iso': 'MYT', 'name_0': 'Mayotte'},
#  {'iso': 'SAU', 'name_0': 'Saudi Arabia'},
#  {'iso': 'FSM', 'name_0': 'Micronesia'},
#  {'iso': 'XCL', 'name_0': 'Clipperton Island'},
#  {'iso': 'AFG', 'name_0': 'Afghanistan'},
#  {'iso': 'BEL', 'name_0': 'Belgium'},
#  {'iso': 'DMA', 'name_0': 'Dominica'},
#  {'iso': 'DOM', 'name_0': 'Dominican Republic'},
#  {'iso': 'DZA', 'name_0': 'Algeria'},
#  {'iso': 'ECU', 'name_0': 'Ecuador'},
#  {'iso': 'EGY', 'name_0': 'Egypt'},
#  {'iso': 'FRA', 'name_0': 'France'},
#  {'iso': 'BRN', 'name_0': 'Brunei'},
#  {'iso': 'SWZ', 'name_0': 'Swaziland'},
#  {'iso': 'TUN', 'name_0': 'Tunisia'},
#  {'iso': 'TUR', 'name_0': 'Turkey'},
#  {'iso': 'TUV', 'name_0': 'Tuvalu'},
#  {'iso': 'TWN', 'name_0': 'Taiwan'},
#  {'iso': 'MAF', 'name_0': 'Saint-Martin'},
#  {'iso': 'UGA', 'name_0': 'Uganda'},
#  {'iso': 'MUS', 'name_0': 'Mauritius'},
#  {'iso': 'JOR', 'name_0': 'Jordan'},
#  {'iso': 'JPN', 'name_0': 'Japan'},
#  {'iso': 'KAZ', 'name_0': 'Kazakhstan'},
#  {'iso': 'KEN', 'name_0': 'Kenya'},
#  {'iso': 'KGZ', 'name_0': 'Kyrgyzstan'},
#  {'iso': 'KHM', 'name_0': 'Cambodia'},
#  {'iso': 'NIC', 'name_0': 'Nicaragua'},
#  {'iso': 'XAD', 'name_0': 'Akrotiri and Dhekelia'},
#  {'iso': 'CAF', 'name_0': 'Central African Republic'},
#  {'iso': 'CAN', 'name_0': 'Canada'},
#  {'iso': 'CCK', 'name_0': 'Cocos Islands'},
#  {'iso': 'HTI', 'name_0': 'Haiti'},
#  {'iso': 'WSM', 'name_0': 'Samoa'},
#  {'iso': 'SMR', 'name_0': 'San Marino'},
#  {'iso': 'SOM', 'name_0': 'Somalia'},
#  {'iso': 'SPM', 'name_0': 'Saint Pierre and Miquelon'},
#  {'iso': 'SRB', 'name_0': 'Serbia'},
#  {'iso': 'SSD', 'name_0': 'South Sudan'},
#  {'iso': 'VCT', 'name_0': 'Saint Vincent and the Grenadines'},
#  {'iso': 'MSR', 'name_0': 'Montserrat'},
#  {'iso': 'VEN', 'name_0': 'Venezuela'},
#  {'iso': 'VGB', 'name_0': 'British Virgin Islands'},
#  {'iso': 'VIR', 'name_0': 'Virgin Islands, U.S.'},
#  {'iso': 'VNM', 'name_0': 'Vietnam'},
#  {'iso': 'VUT', 'name_0': 'Vanuatu'},
#  {'iso': 'WLF', 'name_0': 'Wallis and Futuna'},
#  {'iso': 'XCA', 'name_0': 'Caspian Sea'},
#  {'iso': 'XKO', 'name_0': 'Kosovo'},
#  {'iso': 'XNC', 'name_0': 'Northern Cyprus'},
#  {'iso': 'YEM', 'name_0': 'Yemen'},
#  {'iso': 'ZAF', 'name_0': 'South Africa'},
#  {'iso': 'ZMB', 'name_0': 'Zambia'},
#  {'iso': 'ZWE', 'name_0': 'Zimbabwe'}]

# %% [markdown]
# **Countries that entirely and partially intersect with the CHIRPS**

# %%
query = f"WITH c as (SELECT iso, name_0 \
                     FROM gadm36_countries \
                     WHERE ST_Contains(ST_MakeEnvelope('-180', '-50.5', 180, 50.5, 4326), the_geom)), \
               i as (SELECT iso, name_0 \
                     FROM gadm36_countries \
                     WHERE ST_Intersects(ST_MakeEnvelope('-180', '-50.5', 180, 50.5, 4326), the_geom)) \
          SELECT i.iso, i.name_0 as name_0, c.name_0 IS NOT NULL as whole_country\
          FROM c \
          FULL OUTER JOIN i \
          ON c.name_0 = i.name_0 "

url = f"https://wri-01.carto.com/api/v2/sql"

sql = {"q": query}
r = requests.get(url, params=sql)

data = r.json()
data
# Out:
# {'rows': [{'iso': 'NFK', 'name_0': 'Norfolk Island', 'whole_country': True},
#   {'iso': 'JEY', 'name_0': 'Jersey', 'whole_country': True},
#   {'iso': 'KWT', 'name_0': 'Kuwait', 'whole_country': True},
#   {'iso': 'BFA', 'name_0': 'Burkina Faso', 'whole_country': True},
#   {'iso': 'BGD', 'name_0': 'Bangladesh', 'whole_country': True},
#   {'iso': 'BGR', 'name_0': 'Bulgaria', 'whole_country': True},
#   {'iso': 'MCO', 'name_0': 'Monaco', 'whole_country': True},
#   {'iso': 'MDA', 'name_0': 'Moldova', 'whole_country': True},
#   {'iso': 'MDG', 'name_0': 'Madagascar', 'whole_country': True},
#   {'iso': 'MHL', 'name_0': 'Marshall Islands', 'whole_country': True},
#   {'iso': 'MKD', 'name_0': 'Macedonia', 'whole_country': True},
#   {'iso': 'MLI', 'name_0': 'Mali', 'whole_country': True},
#   {'iso': 'MLT', 'name_0': 'Malta', 'whole_country': True},
#   {'iso': 'MMR', 'name_0': 'Myanmar', 'whole_country': True},
#   {'iso': 'MNE', 'name_0': 'Montenegro', 'whole_country': True},
#   {'iso': 'MNG', 'name_0': 'Mongolia', 'whole_country': False},
#   {'iso': 'ALB', 'name_0': 'Albania', 'whole_country': True},
#   {'iso': 'ATG', 'name_0': 'Antigua and Barbuda', 'whole_country': True},
#   {'iso': 'AUS', 'name_0': 'Australia', 'whole_country': False},
#   {'iso': 'AUT', 'name_0': 'Austria', 'whole_country': True},
#   {'iso': 'AZE', 'name_0': 'Azerbaijan', 'whole_country': True},
#   {'iso': 'BDI', 'name_0': 'Burundi', 'whole_country': True},
#   {'iso': 'BEN', 'name_0': 'Benin', 'whole_country': True},
#   {'iso': 'BES',
#    'name_0': 'Bonaire, Sint Eustatius and Saba',
#    'whole_country': True},
#   {'iso': 'BHR', 'name_0': 'Bahrain', 'whole_country': True},
#   {'iso': 'BHS', 'name_0': 'Bahamas', 'whole_country': True},
#   {'iso': 'BIH', 'name_0': 'Bosnia and Herzegovina', 'whole_country': True},
#   {'iso': 'BRA', 'name_0': 'Brazil', 'whole_country': True},
#   {'iso': 'ABW', 'name_0': 'Aruba', 'whole_country': True},
#   {'iso': 'BRB', 'name_0': 'Barbados', 'whole_country': True},
#   {'iso': 'CHE', 'name_0': 'Switzerland', 'whole_country': True},
#   {'iso': 'CHL', 'name_0': 'Chile', 'whole_country': False},
#   {'iso': 'CHN', 'name_0': 'China', 'whole_country': False},
#   {'iso': 'CIV', 'name_0': "Côte d'Ivoire", 'whole_country': True},
#   {'iso': 'CMR', 'name_0': 'Cameroon', 'whole_country': True},
#   {'iso': 'COD',
#    'name_0': 'Democratic Republic of the Congo',
#    'whole_country': True},
#   {'iso': 'COG', 'name_0': 'Republic of Congo', 'whole_country': True},
#   {'iso': 'COK', 'name_0': 'Cook Islands', 'whole_country': True},
#   {'iso': 'COL', 'name_0': 'Colombia', 'whole_country': True},
#   {'iso': 'COM', 'name_0': 'Comoros', 'whole_country': True},
#   {'iso': 'CPV', 'name_0': 'Cape Verde', 'whole_country': True},
#   {'iso': 'CRI', 'name_0': 'Costa Rica', 'whole_country': True},
#   {'iso': 'CUB', 'name_0': 'Cuba', 'whole_country': True},
#   {'iso': 'CUW', 'name_0': 'Curaçao', 'whole_country': True},
#   {'iso': 'DEU', 'name_0': 'Germany', 'whole_country': False},
#   {'iso': 'DJI', 'name_0': 'Djibouti', 'whole_country': True},
#   {'iso': 'BLM', 'name_0': 'Saint-Barthélemy', 'whole_country': True},
#   {'iso': 'BLZ', 'name_0': 'Belize', 'whole_country': True},
#   {'iso': 'BMU', 'name_0': 'Bermuda', 'whole_country': True},
#   {'iso': 'AND', 'name_0': 'Andorra', 'whole_country': True},
#   {'iso': 'ARE', 'name_0': 'United Arab Emirates', 'whole_country': True},
#   {'iso': 'ARG', 'name_0': 'Argentina', 'whole_country': False},
#   {'iso': 'ARM', 'name_0': 'Armenia', 'whole_country': True},
#   {'iso': 'ASM', 'name_0': 'American Samoa', 'whole_country': True},
#   {'iso': 'ATF',
#    'name_0': 'French Southern Territories',
#    'whole_country': True},
#   {'iso': 'BOL', 'name_0': 'Bolivia', 'whole_country': True},
#   {'iso': 'BWA', 'name_0': 'Botswana', 'whole_country': True},
#   {'iso': 'ERI', 'name_0': 'Eritrea', 'whole_country': True},
#   {'iso': 'ESH', 'name_0': 'Western Sahara', 'whole_country': True},
#   {'iso': 'ETH', 'name_0': 'Ethiopia', 'whole_country': True},
#   {'iso': 'FJI', 'name_0': 'Fiji', 'whole_country': True},
#   {'iso': 'MYS', 'name_0': 'Malaysia', 'whole_country': True},
#   {'iso': 'NAM', 'name_0': 'Namibia', 'whole_country': True},
#   {'iso': 'NCL', 'name_0': 'New Caledonia', 'whole_country': True},
#   {'iso': 'NRU', 'name_0': 'Nauru', 'whole_country': True},
#   {'iso': 'NGA', 'name_0': 'Nigeria', 'whole_country': True},
#   {'iso': 'IDN', 'name_0': 'Indonesia', 'whole_country': True},
#   {'iso': 'IND', 'name_0': 'India', 'whole_country': True},
#   {'iso': 'IOT',
#    'name_0': 'British Indian Ocean Territory',
#    'whole_country': True},
#   {'iso': 'HUN', 'name_0': 'Hungary', 'whole_country': True},
#   {'iso': 'NZL', 'name_0': 'New Zealand', 'whole_country': False},
#   {'iso': 'OMN', 'name_0': 'Oman', 'whole_country': True},
#   {'iso': 'PAK', 'name_0': 'Pakistan', 'whole_country': True},
#   {'iso': 'GLP', 'name_0': 'Guadeloupe', 'whole_country': True},
#   {'iso': 'ESP', 'name_0': 'Spain', 'whole_country': True},
#   {'iso': 'IRN', 'name_0': 'Iran', 'whole_country': True},
#   {'iso': 'CYP', 'name_0': 'Cyprus', 'whole_country': True},
#   {'iso': 'CZE', 'name_0': 'Czech Republic', 'whole_country': False},
#   {'iso': 'NER', 'name_0': 'Niger', 'whole_country': True},
#   {'iso': 'SDN', 'name_0': 'Sudan', 'whole_country': True},
#   {'iso': 'RWA', 'name_0': 'Rwanda', 'whole_country': True},
#   {'iso': 'GAB', 'name_0': 'Gabon', 'whole_country': True},
#   {'iso': 'GBR', 'name_0': 'United Kingdom', 'whole_country': False},
#   {'iso': 'GEO', 'name_0': 'Georgia', 'whole_country': True},
#   {'iso': 'GGY', 'name_0': 'Guernsey', 'whole_country': True},
#   {'iso': 'GHA', 'name_0': 'Ghana', 'whole_country': True},
#   {'iso': 'HRV', 'name_0': 'Croatia', 'whole_country': True},
#   {'iso': 'PAN', 'name_0': 'Panama', 'whole_country': True},
#   {'iso': 'PRY', 'name_0': 'Paraguay', 'whole_country': True},
#   {'iso': 'PSE', 'name_0': 'Palestina', 'whole_country': True},
#   {'iso': 'PYF', 'name_0': 'French Polynesia', 'whole_country': True},
#   {'iso': 'QAT', 'name_0': 'Qatar', 'whole_country': True},
#   {'iso': 'REU', 'name_0': 'Reunion', 'whole_country': True},
#   {'iso': 'ROU', 'name_0': 'Romania', 'whole_country': True},
#   {'iso': 'SEN', 'name_0': 'Senegal', 'whole_country': True},
#   {'iso': 'PHL', 'name_0': 'Philippines', 'whole_country': True},
#   {'iso': 'CXR', 'name_0': 'Christmas Island', 'whole_country': True},
#   {'iso': 'CYM', 'name_0': 'Cayman Islands', 'whole_country': True},
#   {'iso': 'SGP', 'name_0': 'Singapore', 'whole_country': True},
#   {'iso': 'SHN', 'name_0': 'Saint Helena', 'whole_country': True},
#   {'iso': 'RUS', 'name_0': 'Russia', 'whole_country': False},
#   {'iso': 'SLB', 'name_0': 'Solomon Islands', 'whole_country': True},
#   {'iso': 'SLE', 'name_0': 'Sierra Leone', 'whole_country': True},
#   {'iso': 'SLV', 'name_0': 'El Salvador', 'whole_country': True},
#   {'iso': 'IRQ', 'name_0': 'Iraq', 'whole_country': True},
#   {'iso': 'ISR', 'name_0': 'Israel', 'whole_country': True},
#   {'iso': 'ITA', 'name_0': 'Italy', 'whole_country': True},
#   {'iso': 'JAM', 'name_0': 'Jamaica', 'whole_country': True},
#   {'iso': 'KNA', 'name_0': 'Saint Kitts and Nevis', 'whole_country': True},
#   {'iso': 'GIB', 'name_0': 'Gibraltar', 'whole_country': True},
#   {'iso': 'GIN', 'name_0': 'Guinea', 'whole_country': True},
#   {'iso': 'GMB', 'name_0': 'Gambia', 'whole_country': True},
#   {'iso': 'GNB', 'name_0': 'Guinea-Bissau', 'whole_country': True},
#   {'iso': 'GNQ', 'name_0': 'Equatorial Guinea', 'whole_country': True},
#   {'iso': 'GRC', 'name_0': 'Greece', 'whole_country': True},
#   {'iso': 'GRD', 'name_0': 'Grenada', 'whole_country': True},
#   {'iso': 'GTM', 'name_0': 'Guatemala', 'whole_country': True},
#   {'iso': 'GUF', 'name_0': 'French Guiana', 'whole_country': True},
#   {'iso': 'GUM', 'name_0': 'Guam', 'whole_country': True},
#   {'iso': 'GUY', 'name_0': 'Guyana', 'whole_country': True},
#   {'iso': 'HKG', 'name_0': 'Hong Kong', 'whole_country': True},
#   {'iso': 'KOR', 'name_0': 'South Korea', 'whole_country': True},
#   {'iso': 'LAO', 'name_0': 'Laos', 'whole_country': True},
#   {'iso': 'LBN', 'name_0': 'Lebanon', 'whole_country': True},
#   {'iso': 'LBR', 'name_0': 'Liberia', 'whole_country': True},
#   {'iso': 'LBY', 'name_0': 'Libya', 'whole_country': True},
#   {'iso': 'HND', 'name_0': 'Honduras', 'whole_country': True},
#   {'iso': 'TZA', 'name_0': 'Tanzania', 'whole_country': True},
#   {'iso': 'URY', 'name_0': 'Uruguay', 'whole_country': True},
#   {'iso': 'USA', 'name_0': 'United States', 'whole_country': False},
#   {'iso': 'UKR', 'name_0': 'Ukraine', 'whole_country': False},
#   {'iso': 'UZB', 'name_0': 'Uzbekistan', 'whole_country': True},
#   {'iso': 'NPL', 'name_0': 'Nepal', 'whole_country': True},
#   {'iso': 'MAR', 'name_0': 'Morocco', 'whole_country': True},
#   {'iso': 'MDV', 'name_0': 'Maldives', 'whole_country': True},
#   {'iso': 'MEX', 'name_0': 'Mexico', 'whole_country': True},
#   {'iso': 'PLW', 'name_0': 'Palau', 'whole_country': True},
#   {'iso': 'KIR', 'name_0': 'Kiribati', 'whole_country': True},
#   {'iso': 'PCN', 'name_0': 'Pitcairn Islands', 'whole_country': True},
#   {'iso': 'PER', 'name_0': 'Peru', 'whole_country': True},
#   {'iso': 'STP', 'name_0': 'São Tomé and Príncipe', 'whole_country': True},
#   {'iso': 'SUR', 'name_0': 'Suriname', 'whole_country': True},
#   {'iso': 'SVK', 'name_0': 'Slovakia', 'whole_country': True},
#   {'iso': 'SVN', 'name_0': 'Slovenia', 'whole_country': True},
#   {'iso': 'LIE', 'name_0': 'Liechtenstein', 'whole_country': True},
#   {'iso': 'LKA', 'name_0': 'Sri Lanka', 'whole_country': True},
#   {'iso': 'LSO', 'name_0': 'Lesotho', 'whole_country': True},
#   {'iso': 'LUX', 'name_0': 'Luxembourg', 'whole_country': True},
#   {'iso': 'MAC', 'name_0': 'Macao', 'whole_country': True},
#   {'iso': 'UMI',
#    'name_0': 'United States Minor Outlying Islands',
#    'whole_country': True},
#   {'iso': 'TKM', 'name_0': 'Turkmenistan', 'whole_country': True},
#   {'iso': 'TLS', 'name_0': 'Timor-Leste', 'whole_country': True},
#   {'iso': 'TON', 'name_0': 'Tonga', 'whole_country': True},
#   {'iso': 'TTO', 'name_0': 'Trinidad and Tobago', 'whole_country': True},
#   {'iso': 'NIU', 'name_0': 'Niue', 'whole_country': True},
#   {'iso': 'SXM', 'name_0': 'Sint Maarten', 'whole_country': True},
#   {'iso': 'SYC', 'name_0': 'Seychelles', 'whole_country': True},
#   {'iso': 'SYR', 'name_0': 'Syria', 'whole_country': True},
#   {'iso': 'TCA', 'name_0': 'Turks and Caicos Islands', 'whole_country': True},
#   {'iso': 'TCD', 'name_0': 'Chad', 'whole_country': True},
#   {'iso': 'TGO', 'name_0': 'Togo', 'whole_country': True},
#   {'iso': 'THA', 'name_0': 'Thailand', 'whole_country': True},
#   {'iso': 'TJK', 'name_0': 'Tajikistan', 'whole_country': True},
#   {'iso': 'TKL', 'name_0': 'Tokelau', 'whole_country': True},
#   {'iso': 'BTN', 'name_0': 'Bhutan', 'whole_country': True},
#   {'iso': 'VAT', 'name_0': 'Vatican City', 'whole_country': True},
#   {'iso': 'LCA', 'name_0': 'Saint Lucia', 'whole_country': True},
#   {'iso': 'MNP', 'name_0': 'Northern Mariana Islands', 'whole_country': True},
#   {'iso': 'MOZ', 'name_0': 'Mozambique', 'whole_country': True},
#   {'iso': 'MRT', 'name_0': 'Mauritania', 'whole_country': True},
#   {'iso': 'MTQ', 'name_0': 'Martinique', 'whole_country': True},
#   {'iso': 'MWI', 'name_0': 'Malawi', 'whole_country': True},
#   {'iso': 'AGO', 'name_0': 'Angola', 'whole_country': True},
#   {'iso': 'AIA', 'name_0': 'Anguilla', 'whole_country': True},
#   {'iso': 'PNG', 'name_0': 'Papua New Guinea', 'whole_country': True},
#   {'iso': 'POL', 'name_0': 'Poland', 'whole_country': False},
#   {'iso': 'PRI', 'name_0': 'Puerto Rico', 'whole_country': True},
#   {'iso': 'PRK', 'name_0': 'North Korea', 'whole_country': True},
#   {'iso': 'PRT', 'name_0': 'Portugal', 'whole_country': True},
#   {'iso': 'MYT', 'name_0': 'Mayotte', 'whole_country': True},
#   {'iso': 'SAU', 'name_0': 'Saudi Arabia', 'whole_country': True},
#   {'iso': 'FSM', 'name_0': 'Micronesia', 'whole_country': True},
#   {'iso': 'XCL', 'name_0': 'Clipperton Island', 'whole_country': True},
#   {'iso': 'AFG', 'name_0': 'Afghanistan', 'whole_country': True},
#   {'iso': 'BEL', 'name_0': 'Belgium', 'whole_country': False},
#   {'iso': 'DMA', 'name_0': 'Dominica', 'whole_country': True},
#   {'iso': 'DOM', 'name_0': 'Dominican Republic', 'whole_country': True},
#   {'iso': 'DZA', 'name_0': 'Algeria', 'whole_country': True},
#   {'iso': 'ECU', 'name_0': 'Ecuador', 'whole_country': True},
#   {'iso': 'EGY', 'name_0': 'Egypt', 'whole_country': True},
#   {'iso': 'FRA', 'name_0': 'France', 'whole_country': False},
#   {'iso': 'BRN', 'name_0': 'Brunei', 'whole_country': True},
#   {'iso': 'SWZ', 'name_0': 'Swaziland', 'whole_country': True},
#   {'iso': 'TUN', 'name_0': 'Tunisia', 'whole_country': True},
#   {'iso': 'TUR', 'name_0': 'Turkey', 'whole_country': True},
#   {'iso': 'TUV', 'name_0': 'Tuvalu', 'whole_country': True},
#   {'iso': 'TWN', 'name_0': 'Taiwan', 'whole_country': True},
#   {'iso': 'MAF', 'name_0': 'Saint-Martin', 'whole_country': True},
#   {'iso': 'UGA', 'name_0': 'Uganda', 'whole_country': True},
#   {'iso': 'MUS', 'name_0': 'Mauritius', 'whole_country': True},
#   {'iso': 'JOR', 'name_0': 'Jordan', 'whole_country': True},
#   {'iso': 'JPN', 'name_0': 'Japan', 'whole_country': True},
#   {'iso': 'KAZ', 'name_0': 'Kazakhstan', 'whole_country': False},
#   {'iso': 'KEN', 'name_0': 'Kenya', 'whole_country': True},
#   {'iso': 'KGZ', 'name_0': 'Kyrgyzstan', 'whole_country': True},
#   {'iso': 'KHM', 'name_0': 'Cambodia', 'whole_country': True},
#   {'iso': 'NIC', 'name_0': 'Nicaragua', 'whole_country': True},
#   {'iso': 'XAD', 'name_0': 'Akrotiri and Dhekelia', 'whole_country': True},
#   {'iso': 'CAF', 'name_0': 'Central African Republic', 'whole_country': True},
#   {'iso': 'CAN', 'name_0': 'Canada', 'whole_country': False},
#   {'iso': 'CCK', 'name_0': 'Cocos Islands', 'whole_country': True},
#   {'iso': 'HTI', 'name_0': 'Haiti', 'whole_country': True},
#   {'iso': 'WSM', 'name_0': 'Samoa', 'whole_country': True},
#   {'iso': 'SMR', 'name_0': 'San Marino', 'whole_country': True},
#   {'iso': 'SOM', 'name_0': 'Somalia', 'whole_country': True},
#   {'iso': 'SPM', 'name_0': 'Saint Pierre and Miquelon', 'whole_country': True},
#   {'iso': 'SRB', 'name_0': 'Serbia', 'whole_country': True},
#   {'iso': 'SSD', 'name_0': 'South Sudan', 'whole_country': True},
#   {'iso': 'VCT',
#    'name_0': 'Saint Vincent and the Grenadines',
#    'whole_country': True},
#   {'iso': 'MSR', 'name_0': 'Montserrat', 'whole_country': True},
#   {'iso': 'VEN', 'name_0': 'Venezuela', 'whole_country': True},
#   {'iso': 'VGB', 'name_0': 'British Virgin Islands', 'whole_country': True},
#   {'iso': 'VIR', 'name_0': 'Virgin Islands, U.S.', 'whole_country': True},
#   {'iso': 'VNM', 'name_0': 'Vietnam', 'whole_country': True},
#   {'iso': 'VUT', 'name_0': 'Vanuatu', 'whole_country': True},
#   {'iso': 'WLF', 'name_0': 'Wallis and Futuna', 'whole_country': True},
#   {'iso': 'XCA', 'name_0': 'Caspian Sea', 'whole_country': True},
#   {'iso': 'XKO', 'name_0': 'Kosovo', 'whole_country': True},
#   {'iso': 'XNC', 'name_0': 'Northern Cyprus', 'whole_country': True},
#   {'iso': 'YEM', 'name_0': 'Yemen', 'whole_country': True},
#   {'iso': 'ZAF', 'name_0': 'South Africa', 'whole_country': True},
#   {'iso': 'ZMB', 'name_0': 'Zambia', 'whole_country': True},
#   {'iso': 'ZWE', 'name_0': 'Zimbabwe', 'whole_country': True}],
#  'time': 3.287,
#  'fields': {'iso': {'type': 'string', 'pgtype': 'text'},
#   'name_0': {'type': 'string', 'pgtype': 'text'},
#   'whole_country': {'type': 'boolean', 'pgtype': 'bool'}},
#  'total_rows': 233}

# %%
query = f"WITH c as (SELECT iso, name_0 FROM gadm36_countries WHERE ST_Contains(ST_MakeEnvelope('-180', '-50.5', 180, 50.5, 4326), the_geom)), i as (SELECT iso, name_0 FROM gadm36_countries WHERE ST_Intersects(ST_MakeEnvelope('-180', '-50.5', 180, 50.5, 4326), the_geom)) SELECT i.iso, i.name_0 as name_0, c.name_0 IS NOT NULL as whole_country FROM c FULL OUTER JOIN i ON c.name_0 = i.name_0 "

url = f"https://wri-01.carto.com/api/v2/sql"

sql = {"q": query}
r = requests.get(url, params=sql)

r.url
# Out:
# 'https://wri-01.carto.com/api/v2/sql?q=WITH+c+as+%28SELECT+iso%2C+name_0+FROM+gadm36_countries+WHERE+ST_Contains%28ST_MakeEnvelope%28%27-180%27%2C+%27-50.5%27%2C+180%2C+50.5%2C+4326%29%2C+the_geom%29%29%2C+i+as+%28SELECT+iso%2C+name_0+FROM+gadm36_countries+WHERE+ST_Intersects%28ST_MakeEnvelope%28%27-180%27%2C+%27-50.5%27%2C+180%2C+50.5%2C+4326%29%2C+the_geom%29%29+SELECT+i.iso%2C+i.name_0+as+name_0%2C+c.name_0+IS+NOT+NULL+as+whole_country+FROM+c+FULL+OUTER+JOIN+i+ON+c.name_0+%3D+i.name_0+'

# %% [markdown]
# **All regions names and codes for each country**

# %%
iso = "ESP"

query = f"SELECT iso, name_1, gid_1 \
    FROM gadm36_adm1 \
    WHERE  iso = '{iso}'"

url = (
    f"https://api.resourcewatch.org/v1/query/Political-boundaries-Admin-1-level-GADM-36"
)

sql = {"sql": query}
r = requests.get(url, params=sql)

data = r.json().get("data")

data
# Out:
# [{'iso': 'ESP', 'name_1': 'Castilla-La Mancha', 'gid_1': 'ESP.4_1'},
#  {'iso': 'ESP', 'name_1': 'Castilla y León', 'gid_1': 'ESP.5_1'},
#  {'iso': 'ESP', 'name_1': 'Cataluña', 'gid_1': 'ESP.6_1'},
#  {'iso': 'ESP', 'name_1': 'Islas Canarias', 'gid_1': 'ESP.14_1'},
#  {'iso': 'ESP', 'name_1': 'Galicia', 'gid_1': 'ESP.12_1'},
#  {'iso': 'ESP', 'name_1': 'Islas Baleares', 'gid_1': 'ESP.13_1'},
#  {'iso': 'ESP', 'name_1': 'La Rioja', 'gid_1': 'ESP.15_1'},
#  {'iso': 'ESP', 'name_1': 'Comunidad Valenciana', 'gid_1': 'ESP.10_1'},
#  {'iso': 'ESP', 'name_1': 'Comunidad de Madrid', 'gid_1': 'ESP.8_1'},
#  {'iso': 'ESP', 'name_1': 'Comunidad Foral de Navarra', 'gid_1': 'ESP.9_1'},
#  {'iso': 'ESP', 'name_1': 'Andalucía', 'gid_1': 'ESP.1_1'},
#  {'iso': 'ESP', 'name_1': 'País Vasco', 'gid_1': 'ESP.16_1'},
#  {'iso': 'ESP', 'name_1': 'Principado de Asturias', 'gid_1': 'ESP.17_1'},
#  {'iso': 'ESP', 'name_1': 'Región de Murcia', 'gid_1': 'ESP.18_1'},
#  {'iso': 'ESP', 'name_1': 'Aragón', 'gid_1': 'ESP.2_1'},
#  {'iso': 'ESP', 'name_1': 'Extremadura', 'gid_1': 'ESP.11_1'},
#  {'iso': 'ESP', 'name_1': 'Cantabria', 'gid_1': 'ESP.3_1'},
#  {'iso': 'ESP', 'name_1': 'Ceuta y Melilla', 'gid_1': 'ESP.7_1'}]

# %%
iso = "ESP"

query = f"SELECT iso, name_1, gid_1 FROM gadm36_adm1 WHERE  iso = '{iso}'"

url = (
    f"https://api.resourcewatch.org/v1/query/Political-boundaries-Admin-1-level-GADM-36"
)

sql = {"sql": query}
r = requests.get(url, params=sql)

r.url
# Out:
# 'https://api.resourcewatch.org/v1/query/Political-boundaries-Admin-1-level-GADM-36?sql=SELECT+iso%2C+name_1%2C+gid_1+FROM+gadm36_adm1+WHERE++iso+%3D+%27ESP%27'

# %% [markdown]
# **Regions that entirely intersect with the CHIRPS**

# %%
iso = "USA"

query = f"SELECT iso, name_0, name_1, gid_1 \
    FROM gadm36_adm1 \
    WHERE  iso = '{iso}' AND ST_Contains(ST_MakeEnvelope('-180', '-50.5', 180, 50.5, 4326), the_geom)"

url = (
    f"https://api.resourcewatch.org/v1/query/Political-boundaries-Admin-1-level-GADM-36"
)

sql = {"sql": query}
r = requests.get(url, params=sql)

data = r.json().get("data")

data
# Out:
# [{'iso': 'USA',
#   'name_0': 'United States',
#   'name_1': 'Utah',
#   'gid_1': 'USA.45_1'},
#  {'iso': 'USA',
#   'name_0': 'United States',
#   'name_1': 'California',
#   'gid_1': 'USA.5_1'},
#  {'iso': 'USA',
#   'name_0': 'United States',
#   'name_1': 'Nebraska',
#   'gid_1': 'USA.28_1'},
#  {'iso': 'USA',
#   'name_0': 'United States',
#   'name_1': 'Montana',
#   'gid_1': 'USA.27_1'},
#  {'iso': 'USA',
#   'name_0': 'United States',
#   'name_1': 'Mississippi',
#   'gid_1': 'USA.25_1'},
#  {'iso': 'USA',
#   'name_0': 'United States',
#   'name_1': 'Wisconsin',
#   'gid_1': 'USA.50_1'},
#  {'iso': 'USA',
#   'name_0': 'United States',
#   'name_1': 'West Virginia',
#   'gid_1': 'USA.49_1'},
#  {'iso': 'USA',
#   'name_0': 'United States',
#   'name_1': 'New Jersey',
#   'gid_1': 'USA.31_1'},
#  {'iso': 'USA',
#   'name_0': 'United States',
#   'name_1': 'Vermont',
#   'gid_1': 'USA.46_1'},
#  {'iso': 'USA',
#   'name_0': 'United States',
#   'name_1': 'New Mexico',
#   'gid_1': 'USA.32_1'},
#  {'iso': 'USA',
#   'name_0': 'United States',
#   'name_1': 'Kansas',
#   'gid_1': 'USA.17_1'},
#  {'iso': 'USA',
#   'name_0': 'United States',
#   'name_1': 'Kentucky',
#   'gid_1': 'USA.18_1'},
#  {'iso': 'USA',
#   'name_0': 'United States',
#   'name_1': 'Arizona',
#   'gid_1': 'USA.3_1'},
#  {'iso': 'USA',
#   'name_0': 'United States',
#   'name_1': 'Michigan',
#   'gid_1': 'USA.23_1'},
#  {'iso': 'USA',
#   'name_0': 'United States',
#   'name_1': 'Connecticut',
#   'gid_1': 'USA.7_1'},
#  {'iso': 'USA',
#   'name_0': 'United States',
#   'name_1': 'North Carolina',
#   'gid_1': 'USA.34_1'},
#  {'iso': 'USA',
#   'name_0': 'United States',
#   'name_1': 'Nevada',
#   'gid_1': 'USA.29_1'},
#  {'iso': 'USA',
#   'name_0': 'United States',
#   'name_1': 'Colorado',
#   'gid_1': 'USA.6_1'},
#  {'iso': 'USA',
#   'name_0': 'United States',
#   'name_1': 'Virginia',
#   'gid_1': 'USA.47_1'},
#  {'iso': 'USA',
#   'name_0': 'United States',
#   'name_1': 'South Carolina',
#   'gid_1': 'USA.41_1'},
#  {'iso': 'USA',
#   'name_0': 'United States',
#   'name_1': 'Tennessee',
#   'gid_1': 'USA.43_1'},
#  {'iso': 'USA',
#   'name_0': 'United States',
#   'name_1': 'Delaware',
#   'gid_1': 'USA.8_1'},
#  {'iso': 'USA',
#   'name_0': 'United States',
#   'name_1': 'Texas',
#   'gid_1': 'USA.44_1'},
#  {'iso': 'USA',
#   'name_0': 'United States',
#   'name_1': 'New Hampshire',
#   'gid_1': 'USA.30_1'},
#  {'iso': 'USA',
#   'name_0': 'United States',
#   'name_1': 'Louisiana',
#   'gid_1': 'USA.19_1'},
#  {'iso': 'USA',
#   'name_0': 'United States',
#   'name_1': 'Illinois',
#   'gid_1': 'USA.14_1'},
#  {'iso': 'USA',
#   'name_0': 'United States',
#   'name_1': 'Florida',
#   'gid_1': 'USA.10_1'},
#  {'iso': 'USA',
#   'name_0': 'United States',
#   'name_1': 'Pennsylvania',
#   'gid_1': 'USA.39_1'},
#  {'iso': 'USA',
#   'name_0': 'United States',
#   'name_1': 'Ohio',
#   'gid_1': 'USA.36_1'},
#  {'iso': 'USA',
#   'name_0': 'United States',
#   'name_1': 'Rhode Island',
#   'gid_1': 'USA.40_1'},
#  {'iso': 'USA',
#   'name_0': 'United States',
#   'name_1': 'Oklahoma',
#   'gid_1': 'USA.37_1'},
#  {'iso': 'USA',
#   'name_0': 'United States',
#   'name_1': 'Alabama',
#   'gid_1': 'USA.1_1'},
#  {'iso': 'USA',
#   'name_0': 'United States',
#   'name_1': 'Hawaii',
#   'gid_1': 'USA.12_1'},
#  {'iso': 'USA',
#   'name_0': 'United States',
#   'name_1': 'Wyoming',
#   'gid_1': 'USA.51_1'},
#  {'iso': 'USA',
#   'name_0': 'United States',
#   'name_1': 'Arkansas',
#   'gid_1': 'USA.4_1'},
#  {'iso': 'USA',
#   'name_0': 'United States',
#   'name_1': 'Georgia',
#   'gid_1': 'USA.11_1'},
#  {'iso': 'USA',
#   'name_0': 'United States',
#   'name_1': 'Minnesota',
#   'gid_1': 'USA.24_1'},
#  {'iso': 'USA',
#   'name_0': 'United States',
#   'name_1': 'Iowa',
#   'gid_1': 'USA.16_1'},
#  {'iso': 'USA',
#   'name_0': 'United States',
#   'name_1': 'Massachusetts',
#   'gid_1': 'USA.22_1'},
#  {'iso': 'USA',
#   'name_0': 'United States',
#   'name_1': 'Oregon',
#   'gid_1': 'USA.38_1'},
#  {'iso': 'USA',
#   'name_0': 'United States',
#   'name_1': 'New York',
#   'gid_1': 'USA.33_1'},
#  {'iso': 'USA',
#   'name_0': 'United States',
#   'name_1': 'Indiana',
#   'gid_1': 'USA.15_1'},
#  {'iso': 'USA',
#   'name_0': 'United States',
#   'name_1': 'Missouri',
#   'gid_1': 'USA.26_1'},
#  {'iso': 'USA',
#   'name_0': 'United States',
#   'name_1': 'District of Columbia',
#   'gid_1': 'USA.9_1'},
#  {'iso': 'USA',
#   'name_0': 'United States',
#   'name_1': 'Maryland',
#   'gid_1': 'USA.21_1'},
#  {'iso': 'USA',
#   'name_0': 'United States',
#   'name_1': 'Idaho',
#   'gid_1': 'USA.13_1'},
#  {'iso': 'USA',
#   'name_0': 'United States',
#   'name_1': 'North Dakota',
#   'gid_1': 'USA.35_1'},
#  {'iso': 'USA',
#   'name_0': 'United States',
#   'name_1': 'Washington',
#   'gid_1': 'USA.48_1'},
#  {'iso': 'USA',
#   'name_0': 'United States',
#   'name_1': 'Maine',
#   'gid_1': 'USA.20_1'},
#  {'iso': 'USA',
#   'name_0': 'United States',
#   'name_1': 'South Dakota',
#   'gid_1': 'USA.42_1'}]

# %%
iso = "USA"

query = f"SELECT iso, name_0, name_1, gid_1 FROM gadm36_adm1 WHERE  iso = '{iso}' AND ST_Contains(ST_MakeEnvelope('-180', '-50.5', 180, 50.5, 4326), the_geom)"

url = (
    f"https://api.resourcewatch.org/v1/query/Political-boundaries-Admin-1-level-GADM-36"
)

sql = {"sql": query}
r = requests.get(url, params=sql)

r.url
# Out:
# 'https://api.resourcewatch.org/v1/query/Political-boundaries-Admin-1-level-GADM-36?sql=SELECT+iso%2C+name_0%2C+name_1%2C+gid_1+FROM+gadm36_adm1+WHERE++iso+%3D+%27USA%27+AND+ST_Contains%28ST_MakeEnvelope%28%27-180%27%2C+%27-50.5%27%2C+180%2C+50.5%2C+4326%29%2C+the_geom%29'
