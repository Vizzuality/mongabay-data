# %% [markdown]
# # Mongabay Fire Tool Googel Cloud Function
#
# [Getting started with Python for Google Cloud Functions](https://medium.com/@timhberry/getting-started-with-python-for-google-cloud-functions-646a8cddbb33).
#
# **`main.py` file**

# %%
import os
import ee
import json
import requests
import numpy as np
import pandas as pd
import datetime as dt

#service_account = 'gee-tiles@skydipper-196010.iam.gserviceaccount.com'
#credentials = ee.ServiceAccountCredentials(service_account, 'privatekey.json')
#ee.Initialize(credentials)
ee.Initialize()

def serializer(df_pre, df_fire):

    return json.loads(pd.merge(df_fire, df_pre, how='left', on='date').to_json(orient='records'))

def get_geometry(iso, adm1=None):
    """
    Return a geometry as a GeoJSON from geostore.

    Parameters
    ----------
        iso : str
            Country iso code.
        adm1 : int or bool, optional
            Admin 1 code. Must be non-negative.

    Returns
    -------
        geometry : GeoJSON
            GeoJSON object describing the geometry.

    Examples
    --------
    >>> get_geometry('BRA', 22)
    {'crs': {},
    'features': [{'geometry': {'coordinates': [[[[-62.8922, -12.8601],
        [-62.8921, -12.8588],
        [-62.9457, -12.8571],
        ...]]],
        'type': 'MultiPolygon'},
    'properties': None,
    'type': 'Feature'}],
    'type': 'FeatureCollection'}
    """
    if adm1:
        if adm1 < 0:
            raise ValueError("Code number %s must be non-negative." % adm1)
        url = f'https://api.resourcewatch.org/v2/geostore/admin/{iso}/{adm1}'

    else:
        url = f'https://api.resourcewatch.org/v2/geostore/admin/{iso}'

    r = requests.get(url)
    geometry = r.json().get('data').get('attributes').get('geojson')

    return geometry

def get_dates(date_text=None):
    """
    Return relevant dates

    Parameters
    ----------
        date_text : str, optional
            String with the last date. Format should be YYYY-MM-DD.

    Returns
    -------
        dates : DatetimeIndex
            List of dates.
        start_date : Timestamp
            First date for moving window computation.
        end_date : Timestamp
            Last date for moving window computation.
        start_year_date : Timestamp
            First day of the 1 year range.    
    """
    if date_text:
        try:
            dt.datetime.strptime(date_text, '%Y-%m-%d')
        except ValueError:
            raise ValueError("Incorrect data format, should be YYYY-MM-DD")
        date = pd.to_datetime(date_text)

    else:
        date = pd.to_datetime('today').normalize()

    nDays_year =  len(pd.date_range(date.replace(month=1, day=1) , date.replace(month=12, day=31) ,freq='D'))
    start_year_date = date - dt.timedelta(days=nDays_year)
    start_date = date - dt.timedelta(days=nDays_year+61)
    end_date = date + dt.timedelta(days=61)
    dates = pd.date_range(start_date, end_date, freq='D').astype(str)
    dates = dates[(dates <= pd.to_datetime('today').normalize().strftime('%Y-%m-%d'))]

    return dates, start_date, date, end_date, start_year_date

def nestedMappedReducer(featureCol, imageCol):
    """
    Computes mean values for each geometry in a FeatureCollection and each image in an ImageCollection.
    To prevent "Computed value is too large" error we will map reduceRegion() over the FeatureCollection instead of using reduceRegions().

    Parameters
    ----------
        featureCol : ee.FeatureCollection
            FeatureCollection with the geometries that we want to intersect with.
        imageCol : ee.ImageCollection
            ImageCollection with a time series of images.

    Returns
    -------
        featureCol : ee.FeatureCollection
            FeatureCollection with the mean values for each geometry and date.  
    """
    def mapReducerOverImgCol(feature):
        def imgReducer(image):
            return ee.Feature(feature.geometry().centroid(100),
                image.reduceRegion(
                    geometry = feature.geometry(),
                    reducer = ee.Reducer.mean(),
                    tileScale = 10,
                    maxPixels = 1e+13,
                    bestEffort = True 
                )).set({'date': image.date().format("YYYY-MM-dd")}).copyProperties(feature)

        return imageCol.map(imgReducer)

    return featureCol.map(mapReducerOverImgCol).flatten()

def fire_tool(request):
    #request = request.get_json()
    request = request
    
    # Get geometry as GeoJSON from geostore
    geometry = get_geometry(request['iso'], request['adm1'])

    # Convert geometry to ee.Geometry
    aoi = ee.Geometry(geometry.get('features')[0].get('geometry'))

    # Get relevant dates
    dates, start_date, date, end_date, start_year_date = get_dates(request['date_text'])

    # Read ImageCollection
    dataset = ee.ImageCollection('UCSB-CHG/CHIRPS/DAILY') \
        .filter(ee.Filter.date(start_date.strftime('%Y-%m-%d'), (end_date + dt.timedelta(days=1)).strftime('%Y-%m-%d'))).filterBounds(aoi)
    chirps = dataset.select('precipitation')

    # Get mean precipitation values over time
    count = chirps.size()
    data = nestedMappedReducer(ee.FeatureCollection(geometry.get('features')), chirps).toList(count).getInfo()
    df_pre = pd.DataFrame(map(lambda x: x.get('properties'), data))

    # VIIRS fire alerts
    confidence = 'h' #'n', 'l'

    if request['adm1']:
        query =(f"SELECT alert__date, SUM(alert__count) AS alert__count \
                FROM data WHERE iso = \'{request['iso']}\' AND adm1::integer = {request['adm1']} AND confidence__cat = \'{confidence}\' AND alert__date >= \'{start_date}\' AND alert__date <= \'{end_date}\' \
                GROUP BY iso, adm1, alert__date, confidence__cat \
                ORDER BY alert__date"
        )
    else:
        query =(f"SELECT alert__date, SUM(alert__count) AS alert__count \
                FROM data WHERE iso = \'{request['iso']}\' AND confidence__cat = \'{confidence}\' AND alert__date >= \'{start_date}\' AND alert__date <= \'{end_date}\' \
                GROUP BY iso, alert__date, confidence__cat \
                ORDER BY alert__date"
        )

    url = f"https://data-api.globalforestwatch.org/dataset/gadm__viirs__adm2_daily_alerts/latest/query/json"

    sql = {"sql": query}
    r = requests.get(url, params=sql)

    data = r.json().get('data')
    if data: 
        df_fire = pd.DataFrame.from_dict(pd.json_normalize(data))
        # Fill missing dates with 0
        df_fire = df_fire.set_index('alert__date').reindex(dates, fill_value=0).reset_index().rename(columns={'index': 'alert__date'})
        df_fire.rename(columns = {'alert__date': 'date', 'alert__count': 'fire'}, inplace= True)
    else:
        df_fire = pd.DataFrame({"date": dates, 'fire': 0})

    # Moving averages
    # 1 week moving average
    df_pre['precipitation_w'] = df_pre[['date', 'precipitation']].rolling(window=7, center=True).mean()
    df_fire['fire_w'] = df_fire[['date', 'fire']].rolling(window=7, center=True).mean()
    # 2 month moving average
    df_pre['precipitation_2m'] = df_pre[['date', 'precipitation']].rolling(window=61, center=True).mean()
    df_fire['fire_2m'] = df_fire[['date', 'fire']].rolling(window=61, center=True).mean()
    # take current year days
    df_pre = df_pre[(df_pre['date'] >= start_year_date.strftime('%Y-%m-%d')) & (df_pre['date'] <= date.strftime('%Y-%m-%d'))]
    df_fire = df_fire[(df_fire['date'] >= start_year_date.strftime('%Y-%m-%d')) & (df_fire['date'] <= date.strftime('%Y-%m-%d'))]

    return json.dumps(serializer(df_pre, df_fire))

# %%
payload = {
    "iso": "BRA",
    "adm1": '',#22,
    "date_text": ''#'2020-10-10'
}

# %%
fire_tool(payload)
# Out:
# '[{"date": "2021-01-19", "fire": 19, "fire_w": 16.2857142857, "fire_2m": 24.5245901639, "precipitation": 10.1783731691, "precipitation_w": 7.9593605542, "precipitation_2m": 8.0486192929}, {"date": "2021-01-20", "fire": 16, "fire_w": 17.1428571429, "fire_2m": 24.1967213115, "precipitation": 7.7280316131, "precipitation_w": 7.5732291466, "precipitation_2m": 8.1366162802}, {"date": "2021-01-21", "fire": 8, "fire_w": 16.7142857143, "fire_2m": 24.131147541, "precipitation": 5.8904112751, "precipitation_w": 7.5731903175, "precipitation_2m": 8.226276396}, {"date": "2021-01-22", "fire": 12, "fire_w": 15.2857142857, "fire_2m": 23.8196721311, "precipitation": 6.2353554567, "precipitation_w": 7.5763050993, "precipitation_2m": 8.2700877828}, {"date": "2021-01-23", "fire": 25, "fire_w": 13.7142857143, "fire_2m": 24.4426229508, "precipitation": 7.0891128928, "precipitation_w": 7.2681786668, "precipitation_2m": 8.2513188591}, {"date": "2021-01-24", "fire": 12, "fire_w": 12.0, "fire_2m": 24.1803278689, "precipitation": 8.1238955221, "precipitation_w": 7.7507670032, "precipitation_2m": 8.2317610767}, {"date": "2021-01-25", "fire": 15, "fire_w": 13.5714285714, "fire_2m": 24.4426229508, "precipitation": 7.7889557666, "precipitation_w": 8.2023264891, "precipitation_2m": 8.2366040854}, {"date": "2021-01-26", "fire": 8, "fire_w": 16.0, "fire_2m": 24.4754098361, "precipitation": 8.0214881409, "precipitation_w": 8.4653519, "precipitation_2m": 8.225282264}, {"date": "2021-01-27", "fire": 4, "fire_w": 13.8571428571, "fire_2m": 24.5245901639, "precipitation": 11.1061499684, "precipitation_w": 8.4518718246, "precipitation_2m": 8.1815719107}, {"date": "2021-01-28", "fire": 19, "fire_w": 12.8571428571, "fire_2m": 23.4754098361, "precipitation": 9.0513276762, "precipitation_w": 8.2785138312, "precipitation_2m": 8.1610956398}, {"date": "2021-01-29", "fire": 29, "fire_w": 11.5714285714, "fire_2m": 21.7868852459, "precipitation": 8.0765333328, "precipitation_w": 7.741448468, "precipitation_2m": 8.1372583584}, {"date": "2021-01-30", "fire": 10, "fire_w": 13.5714285714, "fire_2m": 21.0655737705, "precipitation": 6.9947523649, "precipitation_w": 7.302136237, "precipitation_2m": 8.1512889784}, {"date": "2021-01-31", "fire": 5, "fire_w": 21.0, "fire_2m": 20.7049180328, "precipitation": 6.9103895683, "precipitation_w": 6.5952897452, "precipitation_2m": 8.1734914514}, {"date": "2021-02-01", "fire": 6, "fire_w": 23.2857142857, "fire_2m": 20.5245901639, "precipitation": 4.0294982244, "precipitation_w": 6.0091006752, "precipitation_2m": 8.211029866}, {"date": "2021-02-02", "fire": 22, "fire_w": 26.8571428571, "fire_2m": 20.0163934426, "precipitation": 4.9463025236, "precipitation_w": 6.0645697221, "precipitation_2m": 8.2330972262}, {"date": "2021-02-03", "fire": 56, "fire_w": 29.8571428571, "fire_2m": 19.4262295082, "precipitation": 6.1582245259, "precipitation_w": 6.5304342861, "precipitation_2m": 8.2512502465}, {"date": "2021-02-04", "fire": 35, "fire_w": 31.5714285714, "fire_2m": 19.1475409836, "precipitation": 4.9480041864, "precipitation_w": 6.6484114936, "precipitation_2m": 8.2655458046}, {"date": "2021-02-05", "fire": 54, "fire_w": 32.8571428571, "fire_2m": 19.6229508197, "precipitation": 8.4648166613, "precipitation_w": 7.152586707, "precipitation_2m": 8.3521154653}, {"date": "2021-02-06", "fire": 31, "fire_w": 31.5714285714, "fire_2m": 19.9016393443, "precipitation": 10.255804313, "precipitation_w": 7.7631637847, "precipitation_2m": 8.3750581483}, {"date": "2021-02-07", "fire": 17, "fire_w": 26.8571428571, "fire_2m": 18.5081967213, "precipitation": 7.7362300206, "precipitation_w": 8.2223958268, "precipitation_2m": 8.4249377387}, {"date": "2021-02-08", "fire": 15, "fire_w": 23.8571428571, "fire_2m": 18.2131147541, "precipitation": 7.558724718, "precipitation_w": 8.9009577279, "precipitation_2m": 8.4208354598}, {"date": "2021-02-09", "fire": 13, "fire_w": 16.8571428571, "fire_2m": 17.6721311475, "precipitation": 9.2203420675, "precipitation_w": 9.3378100392, "pre ...

# %% [markdown]
# ### Googel Cloud Function
# **Deploy function**

# %%
# !cd ../cloud_function/fire_tool

# %%
# !gcloud functions deploy fire_tool --runtime python38 --trigger-http --timeout 540 --allow-unauthenticated

# %% [markdown]
# **Request function**

# %%
from pprint import pprint
import json
import requests

# %%
payload = {
    "iso": "BRA",
    "adm1": None, #22,
    "date_text": '2021-10-10'
}

# %%
url = f'https://us-central1-fire-water-chart.cloudfunctions.net/fire_water_chart'

headers = {'Content-Type': 'application/json'}

r = requests.post(url, data=json.dumps(payload), headers=headers)
pprint(r.json())
# Out:
# [{'date': '2020-10-10',
#   'fire': 1471,
#   'fire_2m': 1037.9344262295,
#   'fire_w': 1351.7142857143,
#   'precipitation': 3.4790379842,
#   'precipitation_2m': 3.2704856626,
#   'precipitation_w': 2.618913792},
#  {'date': '2020-10-11',
#   'fire': 360,
#   'fire_2m': 1013.0655737705,
#   'fire_w': 1187.4285714286,
#   'precipitation': 4.4609568604,
#   'precipitation_2m': 3.3231709162,
#   'precipitation_w': 2.7997660046},
#  {'date': '2020-10-12',
#   'fire': 327,
#   'fire_2m': 966.7868852459,
#   'fire_w': 891.5714285714,
#   'precipitation': 1.7485759726,
#   'precipitation_2m': 3.3853917886,
#   'precipitation_w': 3.1723082159},
#  {'date': '2020-10-13',
#   'fire': 558,
#   'fire_2m': 907.868852459,
#   'fire_w': 662.8571428571,
#   'precipitation': 2.0621667602,
#   'precipitation_2m': 3.44790053,
#   'precipitation_w': 3.0817650254},
#  {'date': '2020-10-14',
#   'fire': 684,
#   'fire_2m': 847.3442622951,
#   'fire_w': 551.0,
#   'precipitation': 3.3466497836,
#   'precipitation_2m': 3.5283329712,
#   'precipitation_w': 2.8082798763},
#  {'date': '2020-10-15',
#   'fire': 600,
#   'fire_2m': 813.3770491803,
#   'fire_w': 576.2857142857,
#   'precipitation': 4.7158074635,
#   'precipitation_2m': 3.5760846479,
#   'precipitation_w': 2.5388105733},
#  {'date': '2020-10-16',
#   'fire': 640,
#   'fire_2m': 785.3606557377,
#   'fire_w': 586.0,
#   'precipitation': 1.7591603534,
#   'precipitation_2m': 3.6372905287,
#   'precipitation_w': 2.8000052765},
#  {'date': '2020-10-17',
#   'fire': 688,
#   'fire_2m': 738.3114754098,
#   'fire_w': 579.4285714286,
#   'precipitation': 1.5646419403,
#   'precipitation_2m': 3.6996621039,
#   'precipitation_w': 2.8188339034},
#  {'date': '2020-10-18',
#   'fire': 537,
#   'fire_2m': 721.0163934426,
#   'fire_w': 568.0,
#   'precipitation': 2.5746717395,
#   'precipitation_2m': 3.8019203651,
#   'precipitation_w': 2.7443065514},
#  {'date': '2020-10-19',
#   'fire': 395,
#   'fire_2m': 704.6557377049,
#   'fire_w': 517.7142857143,
#   'precipitation': 3.576938895,
#   'precipitation_2m': 3.934957538,
#   'precipitation_w': 2.5755888966},
#  {'date': '2020-10-20',
#   'fire': 512,
#   'fire_2m': 694.0327868852,
#   'fire_w': 446.7142857143,
#   'precipitation': 2.1939671487,
#   'precipitation_2m': 4.0777693371,
#   'precipitation_w': 2.9791173587},
#  {'date': '2020-10-21',
#   'fire': 604,
#   'fire_2m': 686.4098360656,
#   'fire_w': 364.4285714286,
#   'precipitation': 2.8249583194,
#   'precipitation_2m': 4.1445318243,
#   'precipitation_w': 3.4928799001},
#  {'date': '2020-10-22',
#   'fire': 248,
#   'fire_2m': 683.9180327869,
#   'fire_w': 320.8571428571,
#   'precipitation': 3.5347838797,
#   'precipitation_2m': 4.1939113826,
#   'precipitation_w': 3.6069030309},
#  {'date': '2020-10-23',
#   'fire': 143,
#   'fire_2m': 680.9016393443,
#   'fire_w': 294.0,
#   'precipitation': 4.5838595882,
#   'precipitation_2m': 4.2528355854,
#   'precipitation_w': 3.998520729},
#  {'date': '2020-10-24',
#   'fire': 112,
#   'fire_2m': 676.1803278689,
#   'fire_w': 228.8571428571,
#   'precipitation': 5.16097973,
#   'precipitation_2m': 4.2846169484,
#   'precipitation_w': 4.7099057573},
#  {'date': '2020-10-25',
#   'fire': 232,
#   'fire_2m': 667.4262295082,
#   'fire_w': 166.8571428571,
#   'precipitation': 3.3728336554,
#   'precipitation_2m': 4.3300142755,
#   'precipitation_w': 5.244881367},
#  {'date': '2020-10-26',
#   'fire': 207,
#   'fire_2m': 655.131147541,
#   'fire_w': 159.8571428571,
#   'precipitation': 6.3182627814,
#   'precipitation_2m': 4.3488528872,
#   'precipitation_w': 5.5569080979},
#  {'date': '2020-10-27',
#   'fire': 56,
#   'fire_2m': 643.9672131148,
#   'fire_w': 163.5714285714,
#   'precipitation': 7.1736623471,
#   'precipitation_2m': 4.3637899092,
#   'precipitation_w': 5.9227367413},
#  {'date': '2020-10-28',
#   'fire': 170,
#   'fire_2m': 623.8032786885,
#   'fire_w': 176.0,
#   'precipitation': 6.5697875875,
#   'precipitation_2m': 4.3670941484,
#   'precipitation_w': 6.2171992446},
#  {'date': '2020-10-29',
#   'fire': 199,
#   'fire_2m': 597.9508196721,
#   'fire_w': 173.7142857143,
#   'precipitation': 5.7189709957,
#   'precipitation_2m': 4.3784549667,
#   'precipitation_w': 6.4538149447},
#  {'date': '2020-10-30',
#   'fire': 169,
#   'fire_2m': 576.4754098361,
#   'fire_w': 168.0,
#   'precipitation': 7.1446600919,
#   'precipitation_2m': 4.4115051264,
#   'precipitation_w': 6.0998848149},
#  {'date': '2020-10-31',
#   'fire': 199,
#   'fire_2m': 534.0655737705,
#   'fire_w': 181.1428571429,
#   'precipitation': 7.2222172532,
#   'precipitation_2m': 4.4830096926,
#   'precipitation_w': 6.0261667553},
#  {'date': '2020-11-01',
#   'fire': 216,
#   'fire_2m': 494.0491803279,
#   'fire_w': 188.7142857143,
#   'precipitation': 5.0291435559,
#   'precipitation_2m': 4.5023742542,
#   'precipitation_w': 5.8328057555},
#  {'date': '2020-11-02',
#   'fire': 167,
#   'fire_2m': 457.262295082,
#   'fire_w': 201.2857142857,
#   'precipitation': 3.8407518735,
#   'precipitation_2m': 4.5601807983,
#   'precipitation_w': 5.700449818},
#  {'date': '2020-11-03',
#   'fire': 148,
#   'fire_2m': 421.7540983607,
#   'fire_w': 238.1428571429,
#   'precipitation': 6.6576359298,
#   'precipitation_2m': 4.634047691,
#   'precipitation_w': 5.38738096},
#  {'date': '2020-11-04',
#   'fire': 223,
#   'fire_2m': 394.4918032787,
#   'fire_w': 250.8571428571,
#   'precipitation': 5.2162605888,
#   'precipitation_2m': 4.6847535655,
#   'precipitation_w': 4.8608992594},
#  {'date': '2020-11-05',
#   'fire': 287,
#   'fire_2m': 374.3114754098,
#   'fire_w': 247.4285714286,
#   'precipitation': 4.7924794327,
#   'precipitation_2m': 4.7365873936,
#   'precipitation_w': 4.6772765684},
#  {'date': '2020-11-06',
#   'fire': 427,
#   'fire_2m': 352.2131147541,
#   'fire_w': 257.5714285714,
#   'precipitation': 4.9531780862,
#   'precipitation_2m': 4.7919428277,
#   'precipitation_w': 4.9919384455},
#  {'date': '2020-11-07',
#   'fire': 288,
#   'fire_2m': 322.8852459016,
#   'fire_w': 271.5714285714,
#   'precipitation': 3.5368453492,
#   'precipitation_2m': 4.8573209082,
#   'precipitation_w': 4.7758593902},
#  {'date': '2020-11-08',
#   'fire': 192,
#   'fire_2m': 280.6885245902,
#   'fire_w': 280.0,
#   'precipitation': 3.7437847186,
#   'precipitation_2m': 4.9080084681,
#   'precipitation_w': 4.8254173574},
#  {'date': '2020-11-09',
#   'fire': 238,
#   'fire_2m': 244.6885245902,
#   'fire_w': 247.4285714286,
#   'precipitation': 6.0433850131,
#   'precipitation_2m': 4.9718439246,
#   'precipitation_w': 4.8476018852},
#  {'date': '2020-11-10',
#   'fire': 246,
#   'fire_2m': 221.0819672131,
#   'fire_w': 198.2857142857,
#   'precipitation': 5.1450825428,
#   'precipitation_2m': 5.0208985836,
#   'precipitation_w': 5.0006731983},
#  {'date': '2020-11-11',
#   'fire': 282,
#   'fire_2m': 217.2131147541,
#   'fire_w': 190.0,
#   'precipitation': 5.563166359,
#   'precipitation_2m': 5.0410867204,
#   'precipitation_w': 5.1872994284},
#  {'date': '2020-11-12',
#   'fire': 59,
#   'fire_2m': 215.6229508197,
#   'fire_w': 172.0,
#   'precipitation': 4.9477711273,
#   'precipitation_2m': 5.0885934371,
#   'precipitation_w': 5.4778200397},
#  {'date': '2020-11-13',
#   'fire': 83,
#   'fire_2m': 207.9016393443,
#   'fire_w': 153.8571428571,
#   'precipitation': 6.0246772782,
#   'precipitation_2m': 5.1249786642,
#   'precipitation_w': 5.4686612354},
#  {'date': '2020-11-14',
#   'fire': 230,
#   'fire_2m': 196.868852459,
#   'fire_w': 132.8571428571,
#   'precipitation': 4.8432289598,
#   'precipitation_2m': 5.1658668808,
#   'precipitation_w': 5.8122376911},
#  {'date': '2020-11-15',
#   'fire': 66,
#   'fire_2m': 187.606557377,
#   'fire_w': 97.4285714286,
#   'precipitation': 5.7774289976,
#   'precipitation_2m': 5.1797498024,
#   'precipitation_w': 6.2815330234},
#  {'date': '2020-11-16',
#   'fire': 111,
#   'fire_2m': 177.6885245902,
#   'fire_w': 89.8571428571,
#   'precipitation': 5.9792733833,
#   'precipitation_2m': 5.2349561439,
#   'precipitation_w': 7.0005520214},
#  {'date': '2020-11-17',
#   'fire': 99,
#   'fire_2m': 168.2950819672,
#   'fire_w': 81.5714285714,
#   'precipitation': 7.5501177325,
#   'precipitation_2m': 5.2790197032,
#   'precipitation_w': 7.1010201798},
#  {'date': '2020-11-18',
#   'fire': 34,
#   'fire_2m': 160.0655737705,
#   'fire_w': 60.4285714286,
#   'precipitation': 8.8482336854,
#   'precipitation_2m': 5.3234020281,
#   'precipitation_w': 7.2898453085},
#  {'date': '2020-11-19',
#   'fire': 6,
#   'fire_2m': 155.4426229508,
#   'fire_w': 73.5714285714,
#   'precipitation': 9.9809041131,
#   'precipitation_2m': 5.3402698313,
#   'precipitation_w': 7.3719914016},
#  {'date': '2020-11-20',
#   'fire': 25,
#   'fire_2m': 147.6393442623,
#   'fire_w': 82.2857142857,
#   'precipitation': 6.727954387,
#   'precipitation_2m': 5.3908859204,
#   'precipitation_w': 7.0786602127},
#  {'date': '2020-11-21',
#   'fire': 82,
#   'fire_2m': 138.131147541,
#   'fire_w': 85.1428571429,
#   'precipitation': 6.165004861,
#   'precipitation_2m': 5.4618413874,
#   'precipitation_w': 6.5574746383},
#  {'date': '2020-11-22',
#   'fire': 158,
#   'fire_2m': 134.6557377049,
#   'fire_w': 99.0,
#   'precipitation': 6.3524516489,
#   'precipitation_2m': 5.5347506445,
#   'precipitation_w': 5.8528871502},
#  {'date': '2020-11-23',
#   'fire': 172,
#   'fire_2m': 132.5409836066,
#   'fire_w': 112.1428571429,
#   'precipitation': 3.925955061,
#   'precipitation_2m': 5.5934198518,
#   'precipitation_w': 5.1367800893},
#  {'date': '2020-11-24',
#   'fire': 119,
#   'fire_2m': 131.262295082,
#   'fire_w': 131.1428571429,
#   'precipitation': 3.9018187115,
#   'precipitation_2m': 5.6310490255,
#   'precipitation_w': 4.6306463297},
#  {'date': '2020-11-25',
#   'fire': 131,
#   'fire_2m': 127.5737704918,
#   'fire_w': 141.7142857143,
#   'precipitation': 3.9161212692,
#   'precipitation_2m': 5.6850020384,
#   'precipitation_w': 4.2788973822},
#  {'date': '2020-11-26',
#   'fire': 98,
#   'fire_2m': 124.4754098361,
#   'fire_w': 136.0,
#   'precipitation': 4.9681546864,
#   'precipitation_2m': 5.7277514296,
#   'precipitation_w': 4.1060539379},
#  {'date': '2020-11-27',
#   'fire': 158,
#   'fire_2m': 123.8032786885,
#   'fire_w': 127.7142857143,
#   'precipitation': 3.18501807,
#   'precipitation_2m': 5.7867170113,
#   'precipitation_w': 4.4538875749},
#  {'date': '2020-11-28',
#   'fire': 156,
#   'fire_2m': 122.2131147541,
#   'fire_w': 143.5714285714,
#   'precipitation': 3.7027622288,
#   'precipitation_2m': 5.8060779868,
#   'precipitation_w': 4.3456153161},
#  {'date': '2020-11-29',
#   'fire': 118,
#   'fire_2m': 120.6885245902,
#   'fire_w': 154.8571428571,
#   'precipitation': 5.1425475382,
#   'precipitation_2m': 5.848132277,
#   'precipitation_w': 4.4650821087},
#  {'date': '2020-11-30',
#   'fire': 114,
#   'fire_2m': 118.6557377049,
#   'fire_w': 156.5714285714,
#   'precipitation': 6.3607905203,
#   'precipitation_2m': 5.8404524818,
#   'precipitation_w': 4.6156402524},
#  {'date': '2020-12-01',
#   'fire': 230,
#   'fire_2m': 115.8196721311,
#   'fire_w': 141.7142857143,
#   'precipitation': 3.1439128997,
#   'precipitation_2m': 5.8198860723,
#   'precipitation_w': 4.8958074689},
#  {'date': '2020-12-02',
#   'fire': 210,
#   'fire_2m': 112.6885245902,
#   'fire_w': 155.2857142857,
#   'precipitation': 4.7523888178,
#   'precipitation_2m': 5.8171834129,
#   'precipitation_w': 5.2768776796},
#  {'date': '2020-12-03',
#   'fire': 110,
#   'fire_2m': 110.5409836066,
#   'fire_w': 144.1428571429,
#   'precipitation': 6.0220616921,
#   'precipitation_2m': 5.8554171681,
#   'precipitation_w': 5.4511664576},
#  {'date': '2020-12-04',
#   'fire': 54,
#   'fire_2m': 108.8196721311,
#   'fire_w': 134.2857142857,
#   'precipitation': 5.1461885855,
#   'precipitation_2m': 5.8840236806,
#   'precipitation_w': 5.4094459845},
#  {'date': '2020-12-05',
#   'fire': 251,
#   'fire_2m': 105.6229508197,
#   'fire_w': 115.2857142857,
#   'precipitation': 6.3702537032,
#   'precipitation_2m': 5.9240370755,
#   'precipitation_w': 5.7031660181},
#  {'date': '2020-12-06',
#   'fire': 40,
#   'fire_2m': 101.0327868852,
#   'fire_w': 91.7142857143,
#   'precipitation': 6.3625689846,
#   'precipitation_2m': 5.9171137426,
#   'precipitation_w': 5.9223855493},
#  {'date': '2020-12-07',
#   'fire': 45,
#   'fire_2m': 94.4590163934,
#   'fire_w': 80.4285714286,
#   'precipitation': 6.0687472086,
#   'precipitation_2m': 5.9478210498,
#   'precipitation_w': 5.9865727623},
#  {'date': '2020-12-08',
#   'fire': 97,
#   'fire_2m': 91.6557377049,
#   'fire_w': 90.4285714286,
#   'precipitation': 5.1999531349,
#   'precipitation_2m': 6.0112977672,
#   'precipitation_w': 6.0646077077},
#  {'date': '2020-12-09',
#   'fire': 45,
#   'fire_2m': 89.4426229508,
#   'fire_w': 87.4285714286,
#   'precipitation': 6.2869255358,
#   'precipitation_2m': 6.089909557,
#   'precipitation_w': 5.8183551346},
#  {'date': '2020-12-10',
#   'fire': 31,
#   'fire_2m': 86.1967213115,
#   'fire_w': 94.1428571429,
#   'precipitation': 6.4713721831,
#   'precipitation_2m': 6.1119222123,
#   'precipitation_w': 5.521083224},
#  {'date': '2020-12-11',
#   'fire': 124,
#   'fire_2m': 82.1639344262,
#   'fire_w': 89.2857142857,
#   'precipitation': 5.6924332037,
#   'precipitation_2m': 6.1386265341,
#   'precipitation_w': 5.4885237657},
#  {'date': '2020-12-12',
#   'fire': 230,
#   'fire_2m': 77.6557377049,
#   'fire_w': 80.4285714286,
#   'precipitation': 4.6464856914,
#   'precipitation_2m': 6.1384114223,
#   'precipitation_w': 5.5403398435},
#  {'date': '2020-12-13',
#   'fire': 87,
#   'fire_2m': 76.7868852459,
#   'fire_w': 79.0,
#   'precipitation': 4.2816656108,
#   'precipitation_2m': 6.168125434,
#   'precipitation_w': 5.3746000789},
#  {'date': '2020-12-14',
#   'fire': 11,
#   'fire_2m': 75.5737704918,
#   'fire_w': 91.0,
#   'precipitation': 5.840831,
#   'precipitation_2m': 6.1786647238,
#   'precipitation_w': 5.0576210615},
#  {'date': '2020-12-15',
#   'fire': 35,
#   'fire_2m': 72.5901639344,
#   'fire_w': 78.2857142857,
#   'precipitation': 5.56266568,
#   'precipitation_2m': 6.245794289,
#   'precipitation_w': 4.9989868263},
#  {'date': '2020-12-16',
#   'fire': 35,
#   'fire_2m': 71.737704918,
#   'fire_w': 61.5714285714,
#   'precipitation': 5.1267471834,
#   'precipitation_2m': 6.2662836888,
#   'precipitation_w': 4.9931852827},
#  {'date': '2020-12-17',
#   'fire': 115,
#   'fire_2m': 70.2295081967,
#   'fire_w': 54.2857142857,
#   'precipitation': 4.2525190611,
#   'precipitation_2m': 6.3287879407,
#   'precipitation_w': 5.1360257079},
#  {'date': '2020-12-18',
#   'fire': 35,
#   'fire_2m': 68.8524590164,
#   'fire_w': 56.1428571429,
#   'precipitation': 5.2819935573,
#   'precipitation_2m': 6.3381985898,
#   'precipitation_w': 5.323512966},
#  {'date': '2020-12-19',
#   'fire': 113,
#   'fire_2m': 68.7049180328,
#   'fire_w': 56.2857142857,
#   'precipitation': 4.6058748864,
#   'precipitation_2m': 6.320475944,
#   'precipitation_w': 5.669167663},
#  {'date': '2020-12-20',
#   'fire': 36,
#   'fire_2m': 68.9180327869,
#   'fire_w': 53.2857142857,
#   'precipitation': 5.2815485874,
#   'precipitation_2m': 6.3237131416,
#   'precipitation_w': 6.1028725281},
#  {'date': '2020-12-21',
#   'fire': 24,
#   'fire_2m': 68.7704918033,
#   'fire_w': 41.7142857143,
#   'precipitation': 7.1532418063,
#   'precipitation_2m': 6.3401078503,
#   'precipitation_w': 6.5605639943},
#  {'date': '2020-12-22',
#   'fire': 36,
#   'fire_2m': 67.5573770492,
#   'fire_w': 37.7142857143,
#   'precipitation': 7.9822485595,
#   'precipitation_2m': 6.3356063161,
#   'precipitation_w': 6.7579888349},
#  {'date': '2020-12-23',
#   'fire': 14,
#   'fire_2m': 65.1639344262,
#   'fire_w': 24.1428571429,
#   'precipitation': 8.1626812385,
#   'precipitation_2m': 6.3336867064,
#   'precipitation_w': 7.3751460864},
#  {'date': '2020-12-24',
#   'fire': 34,
#   'fire_2m': 62.7540983607,
#   'fire_w': 21.1428571429,
#   'precipitation': 7.4563593245,
#   'precipitation_2m': 6.3855417528,
#   'precipitation_w': 8.1592909779},
#  {'date': '2020-12-25',
#   'fire': 7,
#   'fire_2m': 61.0,
#   'fire_w': 28.1428571429,
#   'precipitation': 6.6639674416,
#   'precipitation_2m': 6.4547561267,
#   'precipitation_w': 8.2446574476},
#  {'date': '2020-12-26',
#   'fire': 18,
#   'fire_2m': 59.0983606557,
#   'fire_w': 38.1428571429,
#   'precipitation': 8.9259756469,
#   'precipitation_2m': 6.5182452168,
#   'precipitation_w': 8.2878051817},
#  {'date': '2020-12-27',
#   'fire': 15,
#   'fire_2m': 57.6229508197,
#   'fire_w': 42.5714285714,
#   'precipitation': 10.7705628278,
#   'precipitation_2m': 6.5682998636,
#   'precipitation_w': 8.0754496591},
#  {'date': '2020-12-28',
#   'fire': 73,
#   'fire_2m': 55.0983606557,
#   'fire_w': 41.4285714286,
#   'precipitation': 7.7508070945,
#   'precipitation_2m': 6.6981544849,
#   'precipitation_w': 7.8627792234},
#  {'date': '2020-12-29',
#   'fire': 106,
#   'fire_2m': 52.8524590164,
#   'fire_w': 44.0,
#   'precipitation': 8.284282698,
#   'precipitation_2m': 6.7858358857,
#   'precipitation_w': 7.6056812083},
#  {'date': '2020-12-30',
#   'fire': 45,
#   'fire_2m': 51.393442623,
#   'fire_w': 46.5714285714,
#   'precipitation': 6.6761925804,
#   'precipitation_2m': 6.8339340135,
#   'precipitation_w': 7.2124005354},
#  {'date': '2020-12-31',
#   'fire': 26,
#   'fire_2m': 49.6885245902,
#   'fire_w': 50.5714285714,
#   'precipitation': 5.9676662747,
#   'precipitation_2m': 6.8443268306,
#   'precipitation_w': 6.8741248734},
#  {'date': '2021-01-01',
#   'fire': 25,
#   'fire_2m': 46.0,
#   'fire_w': 44.1428571429,
#   'precipitation': 4.8642813357,
#   'precipitation_2m': 6.9060723498,
#   'precipitation_w': 6.860734957},
#  {'date': '2021-01-02',
#   'fire': 36,
#   'fire_2m': 42.6557377049,
#   'fire_w': 30.0,
#   'precipitation': 6.1730109366,
#   'precipitation_2m': 6.8942216843,
#   'precipitation_w': 6.3015740181},
#  {'date': '2021-01-03',
#   'fire': 43,
#   'fire_2m': 41.2131147541,
#   'fire_w': 27.2857142857,
#   'precipitation': 8.4026331938,
#   'precipitation_2m': 6.8765862881,
#   'precipitation_w': 6.323021339},
#  {'date': '2021-01-04',
#   'fire': 28,
#   'fire_2m': 41.2459016393,
#   'fire_w': 40.2857142857,
#   'precipitation': 7.65707768,
#   'precipitation_2m': 6.8931770412,
#   'precipitation_w': 6.528915458},
#  {'date': '2021-01-05',
#   'fire': 7,
#   'fire_2m': 37.7049180328,
#   'fire_w': 44.8571428571,
#   'precipitation': 4.3701561251,
#   'precipitation_2m': 6.8698614754,
#   'precipitation_w': 7.0538901099},
#  {'date': '2021-01-06',
#   'fire': 26,
#   'fire_2m': 37.9344262295,
#   'fire_w': 45.4285714286,
#   'precipitation': 6.826323827,
#   'precipitation_2m': 6.904324552,
#   'precipitation_w': 7.2271966882},
#  {'date': '2021-01-07',
#   'fire': 117,
#   'fire_2m': 37.7049180328,
#   'fire_w': 39.2857142857,
#   'precipitation': 7.4089251075,
#   'precipitation_2m': 6.9729648324,
#   'precipitation_w': 6.9945413997},
#  {'date': '2021-01-08',
#   'fire': 57,
#   'fire_2m': 36.393442623,
#   'fire_w': 36.2857142857,
#   'precipitation': 8.5391038994,
#   'precipitation_2m': 7.014543142,
#   'precipitation_w': 6.6935366646},
#  {'date': '2021-01-09',
#   'fire': 40,
#   'fire_2m': 35.9016393443,
#   'fire_w': 36.1428571429,
#   'precipitation': 7.3861569845,
#   'precipitation_2m': 7.035392309,
#   'precipitation_w': 7.0349894812},
#  {'date': '2021-01-10',
#   'fire': 0,
#   'fire_2m': 35.606557377,
#   'fire_w': 33.7142857143,
#   'precipitation': 6.774046174,
#   'precipitation_2m': 7.080457389,
#   'precipitation_w': 7.0123109289},
#  {'date': '2021-01-11',
#   'fire': 7,
#   'fire_2m': 33.9508196721,
#   'fire_w': 23.8571428571,
#   'precipitation': 5.5500445345,
#   'precipitation_2m': 7.1407920713,
#   'precipitation_w': 7.2307691182},
#  {'date': '2021-01-12',
#   'fire': 6,
#   'fire_2m': 30.4098360656,
#   'fire_w': 17.7142857143,
#   'precipitation': 6.7603258415,
#   'precipitation_2m': 7.2236027566,
#   'precipitation_w': 7.0147946169},
#  {'date': '2021-01-13',
#   'fire': 9,
#   'fire_2m': 29.0655737705,
#   'fire_w': 14.7142857143,
#   'precipitation': 6.6675739606,
#   'precipitation_2m': 7.3423095964,
#   'precipitation_w': 7.3584911542},
#  {'date': '2021-01-14',
#   'fire': 48,
#   'fire_2m': 28.9508196721,
#   'fire_w': 16.8571428571,
#   'precipitation': 8.9381324325,
#   'precipitation_2m': 7.4254163887,
#   'precipitation_w': 7.5513656045},
#  {'date': '2021-01-15',
#   'fire': 14,
#   'fire_2m': 28.5081967213,
#   'fire_w': 19.4285714286,
#   'precipitation': 7.0272823906,
#   'precipitation_2m': 7.5867446665,
#   'precipitation_w': 7.8680952844},
#  {'date': '2021-01-16',
#   'fire': 19,
#   'fire_2m': 28.0983606557,
#   'fire_w': 21.2857142857,
#   'precipitation': 9.7920327457,
#   'precipitation_2m': 7.729297828,
#   'precipitation_w': 8.3563877597},
#  {'date': '2021-01-17',
#   'fire': 15,
#   'fire_2m': 26.3278688525,
#   'fire_w': 22.2857142857,
#   'precipitation': 8.1241673261,
#   'precipitation_2m': 7.8459846589,
#   'precipitation_w': 8.5078817101},
#  {'date': '2021-01-18',
#   'fire': 25,
#   'fire_2m': 26.2295081967,
#   'fire_w': 16.5714285714,
#   'precipitation': 7.7671522934,
#   'precipitation_2m': 7.9473697719,
#   'precipitation_w': 8.0724929733},
#  {'date': '2021-01-19',
#   'fire': 19,
#   'fire_2m': 24.5245901639,
#   'fire_w': 16.2857142857,
#   'precipitation': 10.1783731691,
#   'precipitation_2m': 8.0486192929,
#   'precipitation_w': 7.9593605542},
#  {'date': '2021-01-20',
#   'fire': 16,
#   'fire_2m': 24.1967213115,
#   'fire_w': 17.1428571429,
#   'precipitation': 7.7280316131,
#   'precipitation_2m': 8.1366162802,
#   'precipitation_w': 7.5732291466},
#  {'date': '2021-01-21',
#   'fire': 8,
#   'fire_2m': 24.131147541,
#   'fire_w': 16.7142857143,
#   'precipitation': 5.8904112751,
#   'precipitation_2m': 8.226276396,
#   'precipitation_w': 7.5731903175},
#  {'date': '2021-01-22',
#   'fire': 12,
#   'fire_2m': 23.8196721311,
#   'fire_w': 15.2857142857,
#   'precipitation': 6.2353554567,
#   'precipitation_2m': 8.2700877828,
#   'precipitation_w': 7.5763050993},
#  {'date': '2021-01-23',
#   'fire': 25,
#   'fire_2m': 24.4426229508,
#   'fire_w': 13.7142857143,
#   'precipitation': 7.0891128928,
#   'precipitation_2m': 8.2513188591,
#   'precipitation_w': 7.2681786668},
#  {'date': '2021-01-24',
#   'fire': 12,
#   'fire_2m': 24.1803278689,
#   'fire_w': 12.0,
#   'precipitation': 8.1238955221,
#   'precipitation_2m': 8.2317610767,
#   'precipitation_w': 7.7507670032},
#  {'date': '2021-01-25',
#   'fire': 15,
#   'fire_2m': 24.4426229508,
#   'fire_w': 13.5714285714,
#   'precipitation': 7.7889557666,
#   'precipitation_2m': 8.2366040854,
#   'precipitation_w': 8.2023264891},
#  {'date': '2021-01-26',
#   'fire': 8,
#   'fire_2m': 24.4754098361,
#   'fire_w': 16.0,
#   'precipitation': 8.0214881409,
#   'precipitation_2m': 8.225282264,
#   'precipitation_w': 8.4653519},
#  {'date': '2021-01-27',
#   'fire': 4,
#   'fire_2m': 24.5245901639,
#   'fire_w': 13.8571428571,
#   'precipitation': 11.1061499684,
#   'precipitation_2m': 8.1815719107,
#   'precipitation_w': 8.4518718246},
#  {'date': '2021-01-28',
#   'fire': 19,
#   'fire_2m': 23.4754098361,
#   'fire_w': 12.8571428571,
#   'precipitation': 9.0513276762,
#   'precipitation_2m': 8.1610956398,
#   'precipitation_w': 8.2785138312},
#  {'date': '2021-01-29',
#   'fire': 29,
#   'fire_2m': 21.7868852459,
#   'fire_w': 11.5714285714,
#   'precipitation': 8.0765333328,
#   'precipitation_2m': 8.1372583584,
#   'precipitation_w': 7.741448468},
#  {'date': '2021-01-30',
#   'fire': 10,
#   'fire_2m': 21.0655737705,
#   'fire_w': 13.5714285714,
#   'precipitation': 6.9947523649,
#   'precipitation_2m': 8.1512889784,
#   'precipitation_w': 7.302136237},
#  {'date': '2021-01-31',
#   'fire': 5,
#   'fire_2m': 20.7049180328,
#   'fire_w': 21.0,
#   'precipitation': 6.9103895683,
#   'precipitation_2m': 8.1734914514,
#   'precipitation_w': 6.5952897452},
#  {'date': '2021-02-01',
#   'fire': 6,
#   'fire_2m': 20.5245901639,
#   'fire_w': 23.2857142857,
#   'precipitation': 4.0294982244,
#   'precipitation_2m': 8.211029866,
#   'precipitation_w': 6.0091006752},
#  {'date': '2021-02-02',
#   'fire': 22,
#   'fire_2m': 20.0163934426,
#   'fire_w': 26.8571428571,
#   'precipitation': 4.9463025236,
#   'precipitation_2m': 8.2330972262,
#   'precipitation_w': 6.0645697221},
#  {'date': '2021-02-03',
#   'fire': 56,
#   'fire_2m': 19.4262295082,
#   'fire_w': 29.8571428571,
#   'precipitation': 6.1582245259,
#   'precipitation_2m': 8.2512502465,
#   'precipitation_w': 6.5304342861},
#  {'date': '2021-02-04',
#   'fire': 35,
#   'fire_2m': 19.1475409836,
#   'fire_w': 31.5714285714,
#   'precipitation': 4.9480041864,
#   'precipitation_2m': 8.2655458046,
#   'precipitation_w': 6.6484114936},
#  {'date': '2021-02-05',
#   'fire': 54,
#   'fire_2m': 19.6229508197,
#   'fire_w': 32.8571428571,
#   'precipitation': 8.4648166613,
#   'precipitation_2m': 8.3521154653,
#   'precipitation_w': 7.152586707},
#  {'date': '2021-02-06',
#   'fire': 31,
#   'fire_2m': 19.9016393443,
#   'fire_w': 31.5714285714,
#   'precipitation': 10.255804313,
#   'precipitation_2m': 8.3750581483,
#   'precipitation_w': 7.7631637847},
#  {'date': '2021-02-07',
#   'fire': 17,
#   'fire_2m': 18.5081967213,
#   'fire_w': 26.8571428571,
#   'precipitation': 7.7362300206,
#   'precipitation_2m': 8.4249377387,
#   'precipitation_w': 8.2223958268},
#  {'date': '2021-02-08',
#   'fire': 15,
#   'fire_2m': 18.2131147541,
#   'fire_w': 23.8571428571,
#   'precipitation': 7.558724718,
#   'precipitation_2m': 8.4208354598,
#   'precipitation_w': 8.9009577279},
#  {'date': '2021-02-09',
#   'fire': 13,
#   'fire_2m': 17.6721311475,
#   'fire_w': 16.8571428571,
#   'precipitation': 9.2203420675,
#   'precipitation_2m': 8.4253552128,
#   'precipitation_w': 9.3378100392},
#  {'date': '2021-02-10',
#   'fire': 23,
#   'fire_2m': 18.2786885246,
#   'fire_w': 13.0,
#   'precipitation': 9.3728488204,
#   'precipitation_2m': 8.4408918641,
#   'precipitation_w': 9.4313158992},
#  {'date': '2021-02-11',
#   'fire': 14,
#   'fire_2m': 18.5573770492,
#   'fire_w': 11.7142857143,
#   'precipitation': 9.6979374944,
#   'precipitation_2m': 8.4680582399,
#   'precipitation_w': 10.5266674137},
#  {'date': '2021-02-12',
#   'fire': 5,
#   'fire_2m': 18.6557377049,
#   'fire_w': 11.0,
#   'precipitation': 11.5227828405,
#   'precipitation_2m': 8.4677395142,
#   'precipitation_w': 11.4214910307},
#  {'date': '2021-02-13',
#   'fire': 4,
#   'fire_2m': 18.5081967213,
#   'fire_w': 10.1428571429,
#   'precipitation': 10.9103453328,
#   'precipitation_2m': 8.4383183153,
#   'precipitation_w': 11.7286444129},
#  {'date': '2021-02-14',
#   'fire': 8,
#   'fire_2m': 17.737704918,
#   'fire_w': 11.0,
#   'precipitation': 15.4036906224,
#   'precipitation_2m': 8.3713987758,
#   'precipitation_w': 12.02773536},
#  {'date': '2021-02-15',
#   'fire': 10,
#   'fire_2m': 17.6885245902,
#   'fire_w': 10.2857142857,
#   'precipitation': 13.8224900368,
#   'precipitation_2m': 8.410383477,
#   'precipitation_w': 12.1826150992},
#  {'date': '2021-02-16',
#   'fire': 7,
#   'fire_2m': 17.6393442623,
#   'fire_w': 11.8571428571,
#   'precipitation': 11.3704157428,
#   'precipitation_2m': 8.4014237967,
#   'precipitation_w': 12.0578410958},
#  {'date': '2021-02-17',
#   'fire': 29,
#   'fire_2m': 17.7868852459,
#   'fire_w': 14.1428571429,
#   'precipitation': 11.4664854503,
#   'precipitation_2m': 8.4046168649,
#   'precipitation_w': 12.3024358867},
#  {'date': '2021-02-18',
#   'fire': 9,
#   'fire_2m': 17.9836065574,
#   'fire_w': 15.4285714286,
#   'precipitation': 10.782095669,
#   'precipitation_2m': 8.4056580832,
#   'precipitation_w': 11.6240148193},
#  {'date': '2021-02-19',
#   'fire': 16,
#   'fire_2m': 17.9508196721,
#   'fire_w': 21.4285714286,
#   'precipitation': 10.6493648163,
#   'precipitation_2m': 8.3575566376,
#   'precipitation_w': 10.6519129419},
#  {'date': '2021-02-20',
#   'fire': 20,
#   'fire_2m': 17.8196721311,
#   'fire_w': 23.0,
#   'precipitation': 12.6225088692,
#   'precipitation_2m': 8.333852086,
#   'precipitation_w': 9.9223299212},
#  {'date': '2021-02-21',
#   'fire': 17,
#   'fire_2m': 18.0327868852,
#   'fire_w': 22.1428571429,
#   'precipitation': 10.654743151,
#   'precipitation_2m': 8.3681674814,
#   'precipitation_w': 9.2784592817},
#  {'date': '2021-02-22',
#   'fire': 52,
#   'fire_2m': 18.6229508197,
#   'fire_w': 23.7142857143,
#   'precipitation': 7.0177768947,
#   'precipitation_2m': 8.4092867,
#   'precipitation_w': 8.9146376914},
#  {'date': '2021-02-23',
#   'fire': 18,
#   'fire_2m': 18.6557377049,
#   'fire_w': 24.0,
#   'precipitation': 6.2633345977,
#   'precipitation_2m': 8.4209025535,
#   'precipitation_w': 8.5510471863},
#  {'date': '2021-02-24',
#   'fire': 23,
#   'fire_2m': 18.9180327869,
#   'fire_w': 22.4285714286,
#   'precipitation': 6.9593909742,
#   'precipitation_2m': 8.38679001,
#   'precipitation_w': 7.6766537145},
#  {'date': '2021-02-25',
#   'fire': 20,
#   'fire_2m': 19.0,
#   'fire_w': 20.4285714286,
#   'precipitation': 8.235344537,
#   'precipitation_2m': 8.3608618033,
#   'precipitation_w': 7.1302916261},
#  {'date': '2021-02-26',
#   'fire': 18,
#   'fire_2m': 19.4754098361,
#   'fire_w': 13.1428571429,
#   'precipitation': 8.1042312803,
#   'precipitation_2m': 8.339104143,
#   'precipitation_w': 7.2037606987},
#  {'date': '2021-02-27',
#   'fire': 9,
#   'fire_2m': 19.9016393443,
#   'fire_w': 11.1428571429,
#   'precipitation': 6.5017545669,
#   'precipitation_2m': 8.2576692701,
#   'precipitation_w': 7.3550010603},
#  {'date': '2021-02-28',
#   'fire': 3,
#   'fire_2m': 19.9180327869,
#   'fire_w': 9.8571428571,
#   'precipitation': 6.8302085321,
#   'precipitation_2m': 8.2438949374,
#   'precipitation_w': 7.3828201531},
#  {'date': '2021-03-01',
#   'fire': 1,
#   'fire_2m': 20.1803278689,
#   'fire_w': 7.7142857143,
#   'precipitation': 7.5320604028,
#   'precipitation_2m': 8.2473724824,
#   'precipitation_w': 7.280502349},
#  {'date': '2021-03-02',
#   'fire': 4,
#   'fire_2m': 20.2295081967,
#   'fire_w': 6.1428571429,
#   'precipitation': 7.3220171288,
#   'precipitation_2m': 8.2512977519,
#   'precipitation_w': 7.4813217993},
#  {'date': '2021-03-03',
#   'fire': 14,
#   'fire_2m': 20.2459016393,
#   'fire_w': 6.4285714286,
#   'precipitation': 7.1541246237,
#   'precipitation_2m': 8.2420660795,
#   'precipitation_w': 7.7709435364},
#  {'date': '2021-03-04',
#   'fire': 5,
#   'fire_2m': 20.5901639344,
#   'fire_w': 11.1428571429,
#   'precipitation': 7.5191199087,
#   'precipitation_2m': 8.2754980943,
#   'precipitation_w': 8.1739002357},
#  {'date': '2021-03-05',
#   'fire': 7,
#   'fire_2m': 20.3114754098,
#   'fire_w': 17.1428571429,
#   'precipitation': 9.5099674324,
#   'precipitation_2m': 8.2860287083,
#   'precipitation_w': 8.2730098199},
#  {'date': '2021-03-06',
#   'fire': 11,
#   'fire_2m': 19.606557377,
#   'fire_w': 21.1428571429,
#   'precipitation': 8.5291067266,
#   'precipitation_2m': 8.2973816077,
#   'precipitation_w': 8.720090247},
#  {'date': '2021-03-07',
#   'fire': 36,
#   'fire_2m': 19.262295082,
#   'fire_w': 24.7142857143,
#   'precipitation': 9.650905427,
#   'precipitation_2m': 8.3209728472,
#   'precipitation_w': 8.8821959988},
#  {'date': '2021-03-08',
#   'fire': 43,
#   'fire_2m': 18.606557377,
#   'fire_w': 25.0,
#   'precipitation': 8.2258274922,
#   'precipitation_2m': 8.2545226643,
#   'precipitation_w': 8.9025877143},
#  {'date': '2021-03-09',
#   'fire': 32,
#   'fire_2m': 18.6557377049,
#   'fire_w': 29.2857142857,
#   'precipitation': 10.4515801183,
#   'precipitation_2m': 8.1592004418,
#   'precipitation_w': 8.6471326393},
#  {'date': '2021-03-10',
#   'fire': 39,
#   'fire_2m': 18.7213114754,
#   'fire_w': 31.1428571429,
#   'precipitation': 8.2888648865,
#   'precipitation_2m': 8.0872425369,
#   'precipitation_w': 8.4582878867},
#  {'date': '2021-03-11',
#   'fire': 7,
#   'fire_2m': 18.7049180328,
#   'fire_w': 27.7142857143,
#   'precipitation': 7.6618619173,
#   'precipitation_2m': 8.0261570953,
#   'precipitation_w': 8.0425704791},
#  {'date': '2021-03-12',
#   'fire': 37,
#   'fire_2m': 18.7213114754,
#   'fire_w': 21.5714285714,
#   'precipitation': 7.7217819074,
#   'precipitation_2m': 7.9787862261,
#   'precipitation_w': 7.5635780982},
#  {'date': '2021-03-13',
#   'fire': 24,
#   'fire_2m': 18.6229508197,
#   'fire_w': 17.1428571429,
#   'precipitation': 7.2071934583,
#   'precipitation_2m': 7.89614789,
#   'precipitation_w': 6.7642152985},
#  {'date': '2021-03-14',
#   'fire': 12,
#   'fire_2m': 18.8852459016,
#   'fire_w': 13.1428571429,
#   'precipitation': 6.7408835735,
#   'precipitation_2m': 7.825927453,
#   'precipitation_w': 6.9237130528},
#  {'date': '2021-03-15',
#   'fire': 0,
#   'fire_2m': 19.2295081967,
#   'fire_w': 14.4285714286,
#   'precipitation': 4.8728808262,
#   'precipitation_2m': 7.7605612861,
#   'precipitation_w': 7.1499459571},
#  {'date': '2021-03-16',
#   'fire': 1,
#   'fire_2m': 19.3278688525,
#   'fire_w': 12.5714285714,
#   'precipitation': 4.8560405205,
#   'precipitation_2m': 7.6730830844,
#   'precipitation_w': 7.235254897},
#  {'date': '2021-03-17',
#   'fire': 11,
#   'fire_2m': 19.5573770492,
#   'fire_w': 14.4285714286,
#   'precipitation': 9.4053491662,
#   'precipitation_2m': 7.5263221087,
#   'precipitation_w': 7.32432249},
#  {'date': '2021-03-18',
#   'fire': 16,
#   'fire_2m': 19.5737704918,
#   'fire_w': 15.1428571429,
#   'precipitation': 9.2454922475,
#   'precipitation_2m': 7.4296482734,
#   'precipitation_w': 7.396222692},
#  {'date': '2021-03-19',
#   'fire': 24,
#   'fire_2m': 19.5573770492,
#   'fire_w': 16.2857142857,
#   'precipitation': 8.3189444871,
#   'precipitation_2m': 7.3767083561,
#   'precipitation_w': 7.5975331401},
#  {'date': '2021-03-20',
#   'fire': 37,
#   'fire_2m': 19.1803278689,
#   'fire_w': 19.1428571429,
#   'precipitation': 7.8306666091,
#   'precipitation_2m': 7.2944789214,
#   'precipitation_w': 8.0443345507},
#  {'date': '2021-03-21',
#   'fire': 17,
#   'fire_2m': 19.1639344262,
#   'fire_w': 24.4285714286,
#   'precipitation': 7.2441849872,
#   'precipitation_2m': 7.2011028298,
#   'precipitation_w': 7.9498029261},
#  {'date': '2021-03-22',
#   'fire': 8,
#   'fire_2m': 19.4426229508,
#   'fire_w': 26.0,
#   'precipitation': 6.2820539629,
#   'precipitation_2m': 7.1147052027,
#   'precipitation_w': 7.7429725982},
#  {'date': '2021-03-23',
#   'fire': 21,
#   'fire_2m': 19.7213114754,
#   'fire_w': 26.5714285714,
#   'precipitation': 7.9836503947,
#   'precipitation_2m': 6.9950494564,
#   'precipitation_w': 7.4178420101},
#  {'date': '2021-03-24',
#   'fire': 48,
#   'fire_2m': 19.737704918,
#   'fire_w': 24.1428571429,
#   'precipitation': 8.743627794,
#   'precipitation_2m': 6.8976149836,
#   'precipitation_w': 7.1859375175},
#  {'date': '2021-03-25',
#   'fire': 27,
#   'fire_2m': 19.0327868852,
#   'fire_w': 27.0,
#   'precipitation': 7.7976799527,
#   'precipitation_2m': 6.8615926927,
#   'precipitation_w': 7.1073783566},
#  {'date': '2021-03-26',
#   'fire': 28,
#   'fire_2m': 18.7868852459,
#   'fire_w': 30.1428571429,
#   'precipitation': 6.0430303703,
#   'precipitation_2m': 6.8955249385,
#   'precipitation_w': 7.0868881794},
#  {'date': '2021-03-27',
#   'fire': 20,
#   'fire_2m': 18.5573770492,
#   'fire_w': 30.0,
#   'precipitation': 6.2073351611,
#   'precipitation_2m': 6.9271645383,
#   'precipitation_w': 7.1193800346},
#  {'date': '2021-03-28',
#   'fire': 37,
#   'fire_2m': 18.6393442623,
#   'fire_w': 29.5714285714,
#   'precipitation': 6.6942708605,
#   'precipitation_2m': 6.8775943321,
#   'precipitation_w': 7.0543851461},
#  {'date': '2021-03-29',
#   'fire': 30,
#   'fire_2m': 18.6721311475,
#   'fire_w': 27.5714285714,
#   'precipitation': 6.1386227229,
#   'precipitation_2m': 6.8168918787,
#   'precipitation_w': 6.9738871251},
#  {'date': '2021-03-30',
#   'fire': 20,
#   'fire_2m': 18.7540983607,
#   'fire_w': 24.4285714286,
#   'precipitation': 8.2110933805,
#   'precipitation_2m': 6.8156225376,
#   'precipitation_w': 7.0173481514},
#  {'date': '2021-03-31',
#   'fire': 45,
#   'fire_2m': 18.8360655738,
#   'fire_w': 25.4285714286,
#   'precipitation': 8.2886635745,
#   'precipitation_2m': 6.7756636404,
#   'precipitation_w': 6.9975647178},
#  {'date': '2021-04-01',
#   'fire': 13,
#   'fire_2m': 19.1147540984,
#   'fire_w': 20.8571428571,
#   'precipitation': 7.2341938059,
#   'precipitation_2m': 6.7423285246,
#   'precipitation_w': 6.8396217341},
#  {'date': '2021-04-02',
#   'fire': 6,
#   'fire_2m': 19.5901639344,
#   'fire_w': 18.4285714286,
#   'precipitation': 6.3472575542,
#   'precipitation_2m': 6.6812650995,
#   'precipitation_w': 6.9413544014},
#  {'date': '2021-04-03',
#   'fire': 27,
#   'fire_2m': 20.1147540984,
#   'fire_w': 17.5714285714,
#   'precipitation': 6.0688511264,
#   'precipitation_2m': 6.6186853605,
#   'precipitation_w': 6.680779603},
#  {'date': '2021-04-04',
#   'fire': 5,
#   'fire_2m': 20.606557377,
#   'fire_w': 13.1428571429,
#   'precipitation': 5.5886699745,
#   'precipitation_2m': 6.5595652259,
#   'precipitation_w': 6.1268784505},
#  {'date': '2021-04-05',
#   'fire': 13,
#   'fire_2m': 20.7868852459,
#   'fire_w': 16.1428571429,
#   'precipitation': 6.8507513939,
#   'precipitation_2m': 6.4667165033,
#   'precipitation_w': 5.7278720128},
#  {'date': '2021-04-06',
#   'fire': 14,
#   'fire_2m': 20.8852459016,
#   'fire_w': 18.2857142857,
#   'precipitation': 6.3870697914,
#   'precipitation_2m': 6.3832748132,
#   'precipitation_w': 5.299234908},
#  {'date': '2021-04-07',
#   'fire': 14,
#   'fire_2m': 20.7868852459,
#   'fire_w': 16.4285714286,
#   'precipitation': 4.4113555072,
#   'precipitation_2m': 6.304261555,
#   'precipitation_w': 4.9797580014},
#  {'date': '2021-04-08',
#   'fire': 34,
#   'fire_2m': 20.8196721311,
#   'fire_w': 17.7142857143,
#   'precipitation': 4.4411487417,
#   'precipitation_2m': 6.2225184532,
#   'precipitation_w': 5.0857650113},
#  {'date': '2021-04-09',
#   'fire': 21,
#   'fire_2m': 20.6557377049,
#   'fire_w': 18.2857142857,
#   'precipitation': 3.3467978206,
#   'precipitation_2m': 6.106492986,
#   'precipitation_w': 4.725930572},
#  {'date': '2021-04-10',
#   'fire': 14,
#   'fire_2m': 20.868852459,
#   'fire_w': 20.5714285714,
#   'precipitation': 3.8325127801,
#   'precipitation_2m': 6.0096681511,
#   'precipitation_w': 4.5869907214},
#  {'date': '2021-04-11',
#   'fire': 14,
#   'fire_2m': 21.3114754098,
#   'fire_w': 22.2857142857,
#   'precipitation': 6.3307190443,
#   'precipitation_2m': 5.9160833455,
#   'precipitation_w': 5.0332894575},
#  {'date': '2021-04-12',
#   'fire': 17,
#   'fire_2m': 21.393442623,
#   'fire_w': 18.8571428571,
#   'precipitation': 4.331910319,
#   'precipitation_2m': 5.8476681865,
#   'precipitation_w': 5.1951503556},
#  {'date': '2021-04-13',
#   'fire': 30,
#   'fire_2m': 21.5573770492,
#   'fire_w': 19.0,
#   'precipitation': 5.4144908368,
#   'precipitation_2m': 5.8051437648,
#   'precipitation_w': 5.6386465396},
#  {'date': '2021-04-14',
#   'fire': 26,
#   'fire_2m': 22.6229508197,
#   'fire_w': 18.5714285714,
#   'precipitation': 7.5354466601,
#   'precipitation_2m': 5.7769589881,
#   'precipitation_w': 6.2233427258},
#  {'date': '2021-04-15',
#   'fire': 10,
#   'fire_2m': 22.9836065574,
#   'fire_w': 17.4285714286,
#   'precipitation': 5.5741750285,
#   'precipitation_2m': 5.7610202461,
#   'precipitation_w': 6.4819658316},
#  {'date': '2021-04-16',
#   'fire': 22,
#   'fire_2m': 23.0655737705,
#   'fire_w': 15.8571428571,
#   'precipitation': 6.4512711086,
#   'precipitation_2m': 5.756255005,
#   'precipitation_w': 6.7846200622},
#  {'date': '2021-04-17',
#   'fire': 11,
#   'fire_2m': 23.393442623,
#   'fire_w': 12.7142857143,
#   'precipitation': 7.9253860834,
#   'precipitation_2m': 5.6857437318,
#   'precipitation_w': 6.7377148114},
#  {'date': '2021-04-18',
#   'fire': 6,
#   'fire_2m': 24.606557377,
#   'fire_w': 13.7142857143,
#   'precipitation': 8.1410807849,
#   'precipitation_2m': 5.5909407135,
#   'precipitation_w': 6.4296666551},
#  {'date': '2021-04-19',
#   'fire': 6,
#   'fire_2m': 25.8524590164,
#   'fire_w': 17.5714285714,
#   'precipitation': 6.4504899329,
#   'precipitation_2m': 5.4860047088,
#   'precipitation_w': 6.3938571283},
#  {'date': '2021-04-20',
#   'fire': 8,
#   'fire_2m': 27.1967213115,
#   'fire_w': 17.0,
#   'precipitation': 5.0861540813,
#   'precipitation_2m': 5.3874433723,
#   'precipitation_w': 6.1452812999},
#  {'date': '2021-04-21',
#   'fire': 33,
#   'fire_2m': 28.4590163934,
#   'fire_w': 16.7142857143,
#   'precipitation': 5.3791095663,
#   'precipitation_2m': 5.3098362129,
#   'precipitation_w': 5.7017143097},
#  {'date': '2021-04-22',
#   'fire': 37,
#   'fire_2m': 28.6393442623,
#   'fire_w': 16.2857142857,
#   'precipitation': 5.3235083404,
#   'precipitation_2m': 5.3073411716,
#   'precipitation_w': 5.7291601391},
#  {'date': '2021-04-23',
#   'fire': 18,
#   'fire_2m': 28.7049180328,
#   'fire_w': 16.7142857143,
#   'precipitation': 4.7112403102,
#   'precipitation_2m': 5.253561136,
#   'precipitation_w': 6.0775768005},
#  {'date': '2021-04-24',
#   'fire': 9,
#   'fire_2m': 28.7704918033,
#   'fire_w': 19.1428571429,
#   'precipitation': 4.8204171516,
#   'precipitation_2m': 5.1576684542,
#   'precipitation_w': 6.0954922119},
#  {'date': '2021-04-25',
#   'fire': 3,
#   'fire_2m': 30.5737704918,
#   'fire_w': 17.2857142857,
#   'precipitation': 8.3332015908,
#   'precipitation_2m': 5.0765324758,
#   'precipitation_w': 5.9558167916},
#  {'date': '2021-04-26',
#   'fire': 9,
#   'fire_2m': 32.8360655738,
#   'fire_w': 14.0,
#   'precipitation': 8.8894065627,
#   'precipitation_2m': 5.0058916917,
#   'precipitation_w': 6.1130762798},
#  {'date': '2021-04-27',
#   'fire': 25,
#   'fire_2m': 34.0983606557,
#   'fire_w': 12.5714285714,
#   'precipitation': 5.2115619615,
#   'precipitation_2m': 4.9299919502,
#   'precipitation_w': 6.0675727783},
#  {'date': '2021-04-28',
#   'fire': 20,
#   'fire_2m': 33.9016393443,
#   'fire_w': 13.8571428571,
#   'precipitation': 4.4013816242,
#   'precipitation_2m': 4.8669367595,
#   'precipitation_w': 6.164458663},
#  {'date': '2021-04-29',
#   'fire': 14,
#   'fire_2m': 35.0163934426,
#   'fire_w': 18.1428571429,
#   'precipitation': 6.4243247579,
#   'precipitation_2m': 4.8166240034,
#   'precipitation_w': 5.4878796062},
#  {'date': '2021-04-30',
#   'fire': 8,
#   'fire_2m': 35.8360655738,
#   'fire_w': 23.4285714286,
#   'precipitation': 4.3927157991,
#   'precipitation_2m': 4.7423746861,
#   'precipitation_w': 4.6946444605},
#  {'date': '2021-05-01',
#   'fire': 18,
#   'fire_2m': 36.4918032787,
#   'fire_w': 24.8571428571,
#   'precipitation': 5.4986183445,
#   'precipitation_2m': 4.6521648415,
#   'precipitation_w': 4.5091058522},
#  {'date': '2021-05-02',
#   'fire': 33,
#   'fire_2m': 37.2131147541,
#   'fire_w': 24.5714285714,
#   'precipitation': 3.5971481933,
#   'precipitation_2m': 4.5691585253,
#   'precipitation_w': 4.4297935279},
#  {'date': '2021-05-03',
#   'fire': 46,
#   'fire_2m': 38.2786885246,
#   'fire_w': 25.0,
#   'precipitation': 3.3367605434,
#   'precipitation_2m': 4.4847632334,
#   'precipitation_w': 4.0033419378},
#  {'date': '2021-05-04',
#   'fire': 35,
#   'fire_2m': 39.4754098361,
#   'fire_w': 28.1428571429,
#   'precipitation': 3.912791703,
#   'precipitation_2m': 4.4275496766,
#   'precipitation_w': 4.0659677772},
#  {'date': '2021-05-05',
#   'fire': 18,
#   'fire_2m': 41.2950819672,
#   'fire_w': 32.0,
#   'precipitation': 3.8461953539,
#   'precipitation_2m': 4.3779633983,
#   'precipitation_w': 3.74323634},
#  {'date': '2021-05-06',
#   'fire': 17,
#   'fire_2m': 41.0819672131,
#   'fire_w': 30.4285714286,
#   'precipitation': 3.4391636275,
#   'precipitation_2m': 4.29925084,
#   'precipitation_w': 3.7113618292},
#  {'date': '2021-05-07',
#   'fire': 30,
#   'fire_2m': 41.2131147541,
#   'fire_w': 31.2857142857,
#   'precipitation': 4.831096675,
#   'precipitation_2m': 4.2497824425,
#   'precipitation_w': 3.5750460316},
#  {'date': '2021-05-08',
#   'fire': 45,
#   'fire_2m': 41.1803278689,
#   'fire_w': 31.1428571429,
#   'precipitation': 3.2394982841,
#   'precipitation_2m': 4.2396084734,
#   'precipitation_w': 3.2951027562},
#  {'date': '2021-05-09',
#   'fire': 22,
#   'fire_2m': 41.5409836066,
#   'fire_w': 34.5714285714,
#   'precipitation': 3.3740266176,
#   'precipitation_2m': 4.2329697595,
#   'precipitation_w': 3.2525687354},
#  {'date': '2021-05-10',
#   'fire': 52,
#   'fire_2m': 41.9344262295,
#   'fire_w': 37.0,
#   'precipitation': 2.3825499601,
#   'precipitation_2m': 4.2345461805,
#   'precipitation_w': 3.4202887507},
#  {'date': '2021-05-11',
#   'fire': 34,
#   'fire_2m': 42.8032786885,
#   'fire_w': 43.7142857143,
#   'precipitation': 1.9531887753,
#   'precipitation_2m': 4.2596719585,
#   'precipitation_w': 3.4475052533},
#  {'date': '2021-05-12',
#   'fire': 42,
#   'fire_2m': 43.393442623,
#   'fire_w': 40.4285714286,
#   'precipitation': 3.5484572086,
#   'precipitation_2m': 4.2114481262,
#   'precipitation_w': 3.5419508647},
#  {'date': '2021-05-13',
#   'fire': 34,
#   'fire_2m': 43.5737704918,
#   'fire_w': 38.1428571429,
#   'precipitation': 4.6132037341,
#   'precipitation_2m': 4.179910971,
#   'precipitation_w': 3.7121414645},
#  {'date': '2021-05-14',
#   'fire': 77,
#   'fire_2m': 43.7540983607,
#   'fire_w': 35.1428571429,
#   'precipitation': 5.0216121931,
#   'precipitation_2m': 4.1307936776,
#   'precipitation_w': 4.100943113},
#  {'date': '2021-05-15',
#   'fire': 22,
#   'fire_2m': 44.5245901639,
#   'fire_w': 43.1428571429,
#   'precipitation': 3.9006175643,
#   'precipitation_2m': 4.051894186,
#   'precipitation_w': 4.3165601637},
#  {'date': '2021-05-16',
#   'fire': 6,
#   'fire_2m': 45.393442623,
#   'fire_w': 51.4285714286,
#   'precipitation': 4.5653608163,
#   'precipitation_2m': 4.0172683832,
#   'precipitation_w': 4.0836160197},
#  {'date': '2021-05-17',
#   'fire': 31,
#   'fire_2m': 46.6885245902,
#   'fire_w': 63.5714285714,
#   'precipitation': 5.1041614996,
#   'precipitation_2m': 3.9730166487,
#   'precipitation_w': 3.6843619266},
#  {'date': '2021-05-18',
#   'fire': 90,
#   'fire_2m': 47.2295081967,
#   'fire_w': 66.0,
#   'precipitation': 3.4625081299,
#   'precipitation_2m': 3.8858320178,
#   'precipitation_w': 3.3255813659},
#  {'date': '2021-05-19',
#   'fire': 100,
#   'fire_2m': 48.8524590164,
#   'fire_w': 65.5714285714,
#   'precipitation': 1.9178482007,
#   'precipitation_2m': 3.7913316493,
#   'precipitation_w': 3.6440440627},
#  {'date': '2021-05-20',
#   'fire': 119,
#   'fire_2m': 49.5901639344,
#   'fire_w': 68.2857142857,
#   'precipitation': 1.8184250822,
#   'precipitation_2m': 3.7461813304,
#   'precipitation_w': 3.663716549},
#  {'date': '2021-05-21',
#   'fire': 94,
#   'fire_2m': 50.9180327869,
#   'fire_w': 71.2857142857,
#   'precipitation': 2.5101482683,
#   'precipitation_2m': 3.69744373,
#   'precipitation_w': 3.3480040783},
#  {'date': '2021-05-22',
#   'fire': 19,
#   'fire_2m': 52.7540983607,
#   'fire_w': 78.0,
#   'precipitation': 6.129856442,
#   'precipitation_2m': 3.6280204418,
#   'precipitation_w': 3.2602722411},
#  {'date': '2021-05-23',
#   'fire': 25,
#   'fire_2m': 53.3114754098,
#   'fire_w': 87.4285714286,
#   'precipitation': 4.7030682203,
#   'precipitation_2m': 3.5564767969,
#   'precipitation_w': 3.234000004},
#  {'date': '2021-05-24',
#   'fire': 52,
#   'fire_2m': 53.9180327869,
#   'fire_w': 84.2857142857,
#   'precipitation': 2.8941742046,
#   'precipitation_2m': 3.5166531352,
#   'precipitation_w': 3.1995751251},
#  {'date': '2021-05-25',
#   'fire': 137,
#   'fire_2m': 55.9836065574,
#   'fire_w': 74.4285714286,
#   'precipitation': 2.8483852694,
#   'precipitation_2m': 3.4770531357,
#   'precipitation_w': 3.2478259764},
#  {'date': '2021-05-26',
#   'fire': 166,
#   'fire_2m': 57.4098360656,
#   'fire_w': 85.7142857143,
#   'precipitation': 1.7339425413,
#   'precipitation_2m': 3.3644045084,
#   'precipitation_w': 2.8106385712},
#  {'date': '2021-05-27',
#   'fire': 97,
#   'fire_2m': 60.9344262295,
#   'fire_w': 92.1428571429,
#   'precipitation': 1.5774509301,
#   'precipitation_2m': 3.251746475,
#   'precipitation_w': 2.664755257},
#  {'date': '2021-05-28',
#   'fire': 25,
#   'fire_2m': 62.7049180328,
#   'fire_w': 96.8571428571,
#   'precipitation': 2.8479042273,
#   'precipitation_2m': 3.2128954244,
#   'precipitation_w': 2.6492822358},
#  {'date': '2021-05-29',
#   'fire': 98,
#   'fire_2m': 63.9180327869,
#   'fire_w': 85.4285714286,
#   'precipitation': 3.0695446052,
#   'precipitation_2m': 3.188541111,
#   'precipitation_w': 2.552485557},
#  {'date': '2021-05-30',
#   'fire': 70,
#   'fire_2m': 64.9836065574,
#   'fire_w': 71.8571428571,
#   'precipitation': 3.681885021,
#   'precipitation_2m': 3.1309616842,
#   'precipitation_w': 2.4760858718},
#  {'date': '2021-05-31',
#   'fire': 85,
#   'fire_2m': 68.4098360656,
#   'fire_w': 72.2857142857,
#   'precipitation': 2.7858630564,
#   'precipitation_2m': 3.0704363187,
#   'precipitation_w': 2.619139191},
#  {'date': '2021-06-01',
#   'fire': 57,
#   'fire_2m': 71.9344262295,
#   'fire_w': 85.2857142857,
#   'precipitation': 2.1708085175,
#   'precipitation_2m': 3.005731805,
#   'precipitation_w': 2.578568158},
#  {'date': '2021-06-02',
#   'fire': 71,
#   'fire_2m': 72.3606557377,
#   'fire_w': 71.2857142857,
#   'precipitation': 1.199144745,
#   'precipitation_2m': 2.9863480333,
#   'precipitation_w': 2.4328168341},
#  {'date': '2021-06-03',
#   'fire': 100,
#   'fire_2m': 72.9180327869,
#   'fire_w': 64.4285714286,
#   'precipitation': 2.5788241646,
#   'precipitation_2m': 2.969063476,
#   'precipitation_w': 2.3881900514},
#  {'date': '2021-06-04',
#   'fire': 116,
#   'fire_2m': 73.8852459016,
#   'fire_w': 54.0,
#   'precipitation': 2.5639069968,
#   'precipitation_2m': 2.9381330516,
#   'precipitation_w': 2.5317443859},
#  {'date': '2021-06-05',
#   'fire': 0,
#   'fire_2m': 76.3442622951,
#   'fire_w': 53.8571428571,
#   'precipitation': 2.0492853379,
#   'precipitation_2m': 2.9144175214,
#   'precipitation_w': 2.7982270531},
#  {'date': '2021-06-06',
#   'fire': 22,
#   'fire_2m': 81.2459016393,
#   'fire_w': 50.1428571429,
#   'precipitation': 3.3694975416,
#   'precipitation_2m': 2.8953047913,
#   'precipitation_w': 3.1187720186},
#  {'date': '2021-06-07',
#   'fire': 12,
#   'fire_2m': 83.2950819672,
#   'fire_w': 45.4285714286,
#   'precipitation': 3.7907433978,
#   'precipitation_2m': 2.8362457686,
#   'precipitation_w': 3.516823601},
#  {'date': '2021-06-08',
#   'fire': 56,
#   'fire_2m': 84.5573770492,
#   'fire_w': 36.0,
#   'precipitation': 4.0361871882,
#   'precipitation_2m': 2.8308304426,
#   'precipitation_w': 3.6347033549},
#  {'date': '2021-06-09',
#   'fire': 45,
#   'fire_2m': 86.0983606557,
#   'fire_w': 40.0,
#   'precipitation': 3.4429595032,
#   'precipitation_2m': 2.8040453044,
#   'precipitation_w': 3.6859688563},
#  {'date': '2021-06-10',
#   'fire': 67,
#   'fire_2m': 88.6229508197,
#   'fire_w': 42.7142857143,
#   'precipitation': 5.3651852417,
#   'precipitation_2m': 2.7986160871,
#   'precipitation_w': 3.5500886279},
#  {'date': '2021-06-11',
#   'fire': 50,
# ...
#  {'date': '2021-07-23',
#   'fire': 414,
#   'fire_2m': 441.9016393443,
#   'fire_w': 287.2857142857,
#   'precipitation': 1.5564831139,
#   'precipitation_2m': 1.6897836637,
#   'precipitation_w': 1.4924514731},
#  {'date': '2021-07-24',
#   'fire': 277,
#   'fire_2m': 464.868852459,
#   'fire_w': 337.5714285714,
#   'precipitation': 1.6081680106,
#   'precipitation_2m': 1.6641152674,
#   'precipitation_w': 1.7732283369},
#  {'date': '2021-07-25',
#   'fire': 255,
#   'fire_2m': 484.9344262295,
#   'fire_w': 344.0,
#   'precipitation': 1.8048329222,
#   'precipitation_2m': 1.6409810247,
#   'precipitation_w': 2.0130578749},
#  {'date': '2021-07-26',
#   'fire': 297,
#   'fire_2m': 503.7049180328,
#   'fire_w': 339.2857142857,
#   'precipitation': 2.5727957944,
#   'precipitation_2m': 1.6464996361,
#   'precipitation_w': 2.1383726987},
#  {'date': '2021-07-27',
#   'fire': 445,
#   'fire_2m': 515.1639344262,
#   'fire_w': 320.2857142857,
#   'precipitation': 3.3075912711,
#   'precipitation_2m': 1.6406888856,
#   'precipitation_w': 2.0949868886},
#  {'date': '2021-07-28',
#   'fire': 367,
#   'fire_2m': 523.3606557377,
#   'fire_w': 333.1428571429,
#   'precipitation': 2.5131342323,
#   'precipitation_2m': 1.6517890256,
#   'precipitation_w': 2.2207883668},
#  {'date': '2021-07-29',
#   'fire': 320,
#   'fire_2m': 537.0163934426,
#   'fire_w': 343.0,
#   'precipitation': 1.605603546,
#   'precipitation_2m': 1.6692880029,
#   'precipitation_w': 2.0891711754},
#  {'date': '2021-07-30',
#   'fire': 281,
#   'fire_2m': 548.9672131148,
#   'fire_w': 354.8571428571,
#   'precipitation': 1.2527824432,
#   'precipitation_2m': 1.6791056302,
#   'precipitation_w': 1.7918627829},
#  {'date': '2021-07-31',
#   'fire': 367,
#   'fire_2m': 551.737704918,
#   'fire_w': 293.2857142857,
#   'precipitation': 2.4887783587,
#   'precipitation_2m': 1.7221101203,
#   'precipitation_w': 1.3429452023},
#  {'date': '2021-08-01',
#   'fire': 324,
#   'fire_2m': 551.7704918033,
#   'fire_w': 258.5714285714,
#   'precipitation': 0.8835125823,
#   'precipitation_2m': 1.7510573562,
#   'precipitation_w': 1.0606924107},
#  {'date': '2021-08-02',
#   'fire': 380,
#   'fire_2m': 558.0163934426,
#   'fire_w': 308.7142857143,
#   'precipitation': 0.4916370467,
#   'precipitation_2m': 1.7591402994,
#   'precipitation_w': 0.9792964775},
#  {'date': '2021-08-03',
#   'fire': 14,
#   'fire_2m': 562.0983606557,
#   'fire_w': 346.8571428571,
#   'precipitation': 0.165168207,
#   'precipitation_2m': 1.7455447344,
#   'precipitation_w': 0.9080600629},
#  {'date': '2021-08-04',
#   'fire': 124,
#   'fire_2m': 569.0819672131,
#   'fire_w': 418.2857142857,
#   'precipitation': 0.5373646913,
#   'precipitation_2m': 1.7605484268,
#   'precipitation_w': 0.6610535551},
#  {'date': '2021-08-05',
#   'fire': 671,
#   'fire_2m': 577.737704918,
#   'fire_w': 484.7142857143,
#   'precipitation': 1.0358320136,
#   'precipitation_2m': 1.7583428508,
#   'precipitation_w': 0.6438405581},
#  {'date': '2021-08-06',
#   'fire': 548,
#   'fire_2m': 585.868852459,
#   'fire_w': 537.7142857143,
#   'precipitation': 0.754127541,
#   'precipitation_2m': 1.7667149375,
#   'precipitation_w': 0.7456415806},
#  {'date': '2021-08-07',
#   'fire': 867,
#   'fire_2m': 591.9672131148,
#   'fire_w': 655.4285714286,
#   'precipitation': 0.7597328041,
#   'precipitation_2m': 1.7791552251,
#   'precipitation_w': 0.8761067662},
#  {'date': '2021-08-08',
#   'fire': 789,
#   'fire_2m': 611.9508196721,
#   'fire_w': 770.5714285714,
#   'precipitation': 0.7630216031,
#   'precipitation_2m': 1.7779442652,
#   'precipitation_w': 0.9972321009},
#  {'date': '2021-08-09',
#   'fire': 751,
#   'fire_2m': 642.7704918033,
#   'fire_w': 804.4285714286,
#   'precipitation': 1.2042442038,
#   'precipitation_2m': 1.8112628079,
#   'precipitation_w': 1.1867762022},
#  {'date': '2021-08-10',
#   'fire': 838,
#   'fire_2m': 665.4098360656,
#   'fire_w': 819.1428571429,
#   'precipitation': 1.0784245064,
#   'precipitation_2m': 1.855703314,
#   'precipitation_w': 1.6182383277},
#  {'date': '2021-08-11',
#   'fire': 930,
#   'fire_2m': 679.4590163934,
#   'fire_w': 798.2857142857,
#   'precipitation': 1.3852420344,
#   'precipitation_2m': 1.8712315703,
#   'precipitation_w': 1.7727411801},
#  {'date': '2021-08-12',
#   'fire': 908,
#   'fire_2m': 686.6885245902,
#   'fire_w': 791.7142857143,
#   'precipitation': 2.3626407223,
#   'precipitation_2m': 1.8693924555,
#   'precipitation_w': 1.8346389758},
#  {'date': '2021-08-13',
#   'fire': 651,
#   'fire_2m': 702.6721311475,
#   'fire_w': 762.0,
#   'precipitation': 3.77436242,
#   'precipitation_2m': 1.8548358826,
#   'precipitation_w': 1.8785932977},
#  {'date': '2021-08-14',
#   'fire': 721,
#   'fire_2m': 716.5245901639,
#   'fire_w': 796.4285714286,
#   'precipitation': 1.8412527704,
#   'precipitation_2m': 1.8635008669,
#   'precipitation_w': 1.8247547208},
#  {'date': '2021-08-15',
#   'fire': 743,
#   'fire_2m': 739.8852459016,
#   'fire_w': 892.5714285714,
#   'precipitation': 1.196306173,
#   'precipitation_2m': 1.8823842141,
#   'precipitation_w': 1.8593790544},
#  {'date': '2021-08-16',
#   'fire': 543,
#   'fire_2m': 776.1475409836,
#   'fire_w': 974.8571428571,
#   'precipitation': 1.5119244571,
#   'precipitation_2m': 1.8810199702,
#   'precipitation_w': 1.7446459609},
#  {'date': '2021-08-17',
#   'fire': 1079,
#   'fire_2m': 797.0,
#   'fire_w': 1055.5714285714,
#   'precipitation': 0.7015544687,
#   'precipitation_2m': 1.9016093961,
#   'precipitation_w': 1.3444193804},
#  {'date': '2021-08-18',
#   'fire': 1603,
#   'fire_2m': 812.4754098361,
#   'fire_w': 1144.0,
#   'precipitation': 1.6276123695,
#   'precipitation_2m': 1.9401714041,
#   'precipitation_w': 1.2248265464},
#  {'date': '2021-08-19',
#   'fire': 1484,
#   'fire_2m': 828.8524590164,
#   'fire_w': 1353.5714285714,
#   'precipitation': 1.5595090674,
#   'precipitation_2m': 1.9577421444,
#   'precipitation_w': 1.1342017782},
#  {'date': '2021-08-20',
#   'fire': 1216,
#   'fire_2m': 864.868852459,
#   'fire_w': 1484.0,
#   'precipitation': 0.9727763565,
#   'precipitation_2m': 1.9605127726,
#   'precipitation_w': 1.0205303942},
#  {'date': '2021-08-21',
#   'fire': 1340,
#   'fire_2m': 910.0983606557,
#   'fire_w': 1524.0,
#   'precipitation': 1.0041029328,
#   'precipitation_2m': 1.9789686474,
#   'precipitation_w': 1.062255239},
#  {'date': '2021-08-22',
#   'fire': 2210,
#   'fire_2m': 941.7213114754,
#   'fire_w': 1471.4285714286,
#   'precipitation': 0.5619327951,
#   'precipitation_2m': 1.9992902996,
#   'precipitation_w': 1.0866349884},
#  {'date': '2021-08-23',
#   'fire': 1456,
#   'fire_2m': 955.7704918033,
#   'fire_w': 1391.2857142857,
#   'precipitation': 0.7162247697,
#   'precipitation_2m': 2.0111522265,
#   'precipitation_w': 1.1013923713},
#  {'date': '2021-08-24',
#   'fire': 1359,
#   'fire_2m': 965.5409836066,
#   'fire_w': 1308.0,
#   'precipitation': 0.9936283822,
#   'precipitation_2m': 2.0340684073,
#   'precipitation_w': 1.4651038084},
#  {'date': '2021-08-25',
#   'fire': 1235,
#   'fire_2m': 967.1967213115,
#   'fire_w': 1249.0,
#   'precipitation': 1.7982706148,
#   'precipitation_2m': 2.0872166289,
#   'precipitation_w': 1.8906899777},
#  {'date': '2021-08-26',
#   'fire': 923,
#   'fire_2m': 968.4590163934,
#   'fire_w': 1048.7142857143,
#   'precipitation': 1.662810748,
#   'precipitation_2m': 2.0833890177,
#   'precipitation_w': 2.3119645775},
#  {'date': '2021-08-27',
#   'fire': 633,
#   'fire_2m': 970.868852459,
#   'fire_w': 895.8571428571,
#   'precipitation': 3.5187564163,
#   'precipitation_2m': 2.0726907739,
#   'precipitation_w': 2.6844956669},
#  {'date': '2021-08-28',
#   'fire': 927,
#   'fire_2m': 973.3442622951,
#   'fire_w': 735.2857142857,
#   'precipitation': 3.983206118,
#   'precipitation_2m': 2.0758517659,
#   'precipitation_w': 3.016466527},
#  {'date': '2021-08-29',
#   'fire': 808,
#   'fire_2m': 980.4590163934,
#   'fire_w': 621.7142857143,
#   'precipitation': 3.5108549933,
#   'precipitation_2m': 2.0878969589,
#   'precipitation_w': 3.1749703897},
#  {'date': '2021-08-30',
#   'fire': 386,
#   'fire_2m': 981.8360655738,
#   'fire_w': 536.8571428571,
#   'precipitation': 3.3239423956,
#   'precipitation_2m': 2.1031254144,
#   'precipitation_w': 3.1450078656},
#  {'date': '2021-08-31',
#   'fire': 235,
#   'fire_2m': 983.7540983607,
#   'fire_w': 520.7142857143,
#   'precipitation': 3.3174244032,
#   'precipitation_2m': 2.1079352615,
#   'precipitation_w': 3.0625085279},
#  {'date': '2021-09-01',
#   'fire': 440,
#   'fire_2m': 992.3442622951,
#   'fire_w': 487.7142857143,
#   'precipitation': 2.9077976534,
#   'precipitation_2m': 2.1725347151,
#   'precipitation_w': 2.8170516361},
#  {'date': '2021-09-02',
#   'fire': 329,
#   'fire_2m': 995.4426229508,
#   'fire_w': 488.2857142857,
#   'precipitation': 1.4530730797,
#   'precipitation_2m': 2.2428191394,
#   'precipitation_w': 2.7132129775},
#  {'date': '2021-09-03',
#   'fire': 520,
#   'fire_2m': 1011.9016393443,
#   'fire_w': 508.4285714286,
#   'precipitation': 2.9412610524,
#   'precipitation_2m': 2.3063837795,
#   'precipitation_w': 2.5222717548},
#  {'date': '2021-09-04',
#   'fire': 696,
#   'fire_2m': 1019.868852459,
#   'fire_w': 666.4285714286,
#   'precipitation': 2.2650078753,
#   'precipitation_2m': 2.3552029758,
#   'precipitation_w': 2.4533961036},
#  {'date': '2021-09-05',
#   'fire': 812,
#   'fire_2m': 1024.393442623,
#   'fire_w': 888.7142857143,
#   'precipitation': 2.783984383,
#   'precipitation_2m': 2.3983283135,
#   'precipitation_w': 2.5769341941},
#  {'date': '2021-09-06',
#   'fire': 527,
#   'fire_2m': 1050.3278688525,
#   'fire_w': 1068.4285714286,
#   'precipitation': 1.9873538363,
#   'precipitation_2m': 2.4314637372,
#   'precipitation_w': 3.0496721226},
#  {'date': '2021-09-07',
#   'fire': 1341,
#   'fire_2m': 1061.4098360656,
#   'fire_w': 1155.1428571429,
#   'precipitation': 2.835294845,
#   'precipitation_2m': 2.4829308488,
#   'precipitation_w': 3.1037287603},
#  {'date': '2021-09-08',
#   'fire': 1996,
#   'fire_2m': 1060.9672131148,
#   'fire_w': 1149.8571428571,
#   'precipitation': 3.7725642869,
#   'precipitation_2m': 2.5186115376,
#   'precipitation_w': 3.0934706358},
#  {'date': '2021-09-09',
#   'fire': 1587,
#   'fire_2m': 1058.3606557377,
#   'fire_w': 1207.8571428571,
#   'precipitation': 4.7622385792,
#   'precipitation_2m': 2.5574337854,
#   'precipitation_w': 2.9069491513},
#  {'date': '2021-09-10',
#   'fire': 1127,
#   'fire_2m': 1052.0163934426,
#   'fire_w': 1278.1428571429,
#   'precipitation': 3.3196575164,
#   'precipitation_2m': 2.6180718742,
#   'precipitation_w': 2.9316921879},
#  {'date': '2021-09-11',
#   'fire': 659,
#   'fire_2m': 1041.8852459016,
#   'fire_w': 1304.1428571429,
#   'precipitation': 2.1932010039,
#   'precipitation_2m': 2.6788480051,
#   'precipitation_w': 2.9440203096},
#  {'date': '2021-09-12',
#   'fire': 1218,
#   'fire_2m': 1034.6557377049,
#   'fire_w': 1358.5714285714,
#   'precipitation': 1.4783339912,
#   'precipitation_2m': 2.6795029612,
#   'precipitation_w': 2.7398143264},
#  {'date': '2021-09-13',
#   'fire': 1019,
#   'fire_2m': 1033.4918032787,
#   'fire_w': 1343.0,
#   'precipitation': 2.1605550926,
#   'precipitation_2m': 2.6517300906,
#   'precipitation_w': 2.4659959424},
#  {'date': '2021-09-14',
#   'fire': 1523,
#   'fire_2m': 1028.7213114754,
#   'fire_w': 1352.1428571429,
#   'precipitation': 2.9215916971,
#   'precipitation_2m': 2.7150721522,
#   'precipitation_w': 2.5519178303},
#  {'date': '2021-09-15',
#   'fire': 2377,
#   'fire_2m': 1021.9344262295,
#   'fire_w': 1434.1428571429,
#   'precipitation': 2.3431224042,
#   'precipitation_2m': 2.8155050597,
#   'precipitation_w': 2.5126265608},
#  {'date': '2021-09-16',
#   'fire': 1478,
#   'fire_2m': 1018.4590163934,
#   'fire_w': 1587.2857142857,
#   'precipitation': 2.845509891,
#   'precipitation_2m': 2.8714794534,
#   'precipitation_w': 2.5173162113},
#  {'date': '2021-09-17',
#   'fire': 1191,
#   'fire_2m': 1007.7049180328,
#   'fire_w': 1881.8571428571,
#   'precipitation': 3.9211107321,
#   'precipitation_2m': 2.9190107333,
#   'precipitation_w': 2.4886848879},
#  {'date': '2021-09-18',
#   'fire': 1233,
#   'fire_2m': 985.0491803279,
#   'fire_w': 1990.2857142857,
#   'precipitation': 1.9181621176,
#   'precipitation_2m': 2.9801492558,
#   'precipitation_w': 2.3524604405},
#  {'date': '2021-09-19',
#   'fire': 2290,
#   'fire_2m': 964.5409836066,
#   'fire_w': 1832.2857142857,
#   'precipitation': 1.5111615441,
#   'precipitation_2m': 3.0171256537,
#   'precipitation_w': 2.3434516189},
#  {'date': '2021-09-20',
#   'fire': 3081,
#   'fire_2m': 947.5573770492,
#   'fire_w': 1745.8571428571,
#   'precipitation': 1.960135829,
#   'precipitation_2m': 3.0416658886,
#   'precipitation_w': 2.3663866403},
#  {'date': '2021-09-21',
#   'fire': 2282,
#   'fire_2m': 928.3442622951,
#   'fire_w': 1626.5714285714,
#   'precipitation': 1.9680205657,
#   'precipitation_2m': 3.0994092383,
#   'precipitation_w': 2.527210027},
#  {'date': '2021-09-22',
#   'fire': 1271,
#   'fire_2m': 894.3278688525,
#   'fire_w': 1503.8571428571,
#   'precipitation': 2.280060653,
#   'precipitation_2m': 3.19331794,
#   'precipitation_w': 2.5873742263},
#  {'date': '2021-09-23',
#   'fire': 873,
#   'fire_2m': 876.4590163934,
#   'fire_w': 1261.2857142857,
#   'precipitation': 3.0060550404,
#   'precipitation_2m': 3.2933902846,
#   'precipitation_w': 2.7507794916},
#  {'date': '2021-09-24',
#   'fire': 356,
#   'fire_2m': 855.8196721311,
#   'fire_w': 895.1428571429,
#   'precipitation': 5.0468744391,
#   'precipitation_2m': 3.3883961037,
#   'precipitation_w': 2.8573250502},
#  {'date': '2021-09-25',
#   'fire': 374,
#   'fire_2m': 836.393442623,
#   'fire_w': 676.8571428571,
#   'precipitation': 2.339311513,
#   'precipitation_2m': 3.4485821049,
#   'precipitation_w': 2.910516444},
#  {'date': '2021-09-26',
#   'fire': 592,
#   'fire_2m': 823.9180327869,
#   'fire_w': 547.4285714286,
#   'precipitation': 2.6549984013,
#   'precipitation_2m': 3.5067836203,
#   'precipitation_w': 2.8964675262},
#  {'date': '2021-09-27',
#   'fire': 518,
#   'fire_2m': 820.1475409836,
#   'fire_w': 491.8571428571,
#   'precipitation': 2.7059547393,
#   'precipitation_2m': 3.548571193,
#   'precipitation_w': 2.8644852395},
#  {'date': '2021-09-28',
#   'fire': 754,
#   'fire_2m': 816.9672131148,
#   'fire_w': 562.1428571429,
#   'precipitation': 2.3403603221,
#   'precipitation_2m': 3.5489483176,
#   'precipitation_w': 2.8326573553},
#  {'date': '2021-09-29',
#   'fire': 365,
#   'fire_2m': 813.4590163934,
#   'fire_w': 590.0,
#   'precipitation': 2.1817182285,
#   'precipitation_2m': 3.536106581,
#   'precipitation_w': 3.1811824146},
#  {'date': '2021-09-30',
#   'fire': 484,
#   'fire_2m': 810.1639344262,
#   'fire_w': 650.8571428571,
#   'precipitation': 2.7821790331,
#   'precipitation_2m': 3.5382701365,
#   'precipitation_w': 3.3794128217},
#  {'date': '2021-10-01',
#   'fire': 848,
#   'fire_2m': 808.5081967213,
#   'fire_w': 664.0,
#   'precipitation': 4.8240792501,
#   'precipitation_2m': 3.5581627775,
#   'precipitation_w': 3.495038669},
#  {'date': '2021-10-02',
#   'fire': 569,
#   'fire_2m': 801.5573770492,
#   'fire_w': 691.5714285714,
#   'precipitation': 4.7789869281,
#   'precipitation_2m': 3.6326692274,
#   'precipitation_w': 3.6844839961},
#  {'date': '2021-10-03',
#   'fire': 1018,
#   'fire_2m': 797.3770491803,
#   'fire_w': 943.7142857143,
#   'precipitation': 4.0426112508,
#   'precipitation_2m': 3.7362991582,
#   'precipitation_w': 3.7692940183},
#  {'date': '2021-10-04',
#   'fire': 610,
#   'fire_2m': 791.7868852459,
#   'fire_w': 1095.0,
#   'precipitation': 3.5153356704,
#   'precipitation_2m': 3.7961658555,
#   'precipitation_w': 3.9288722446},
#  {'date': '2021-10-05',
#   'fire': 947,
#   'fire_2m': 783.5737704918,
#   'fire_w': 1082.7142857143,
#   'precipitation': 3.6664776122,
#   'precipitation_2m': 3.8513334547,
#   'precipitation_w': 3.6596528684},
#  {'date': '2021-10-06',
#   'fire': 2130,
#   'fire_2m': 772.2950819672,
#   'fire_w': 1086.0,
#   'precipitation': 2.7753883837,
#   'precipitation_2m': 3.9106292795,
#   'precipitation_w': 3.4872834957},
#  {'date': '2021-10-07',
#   'fire': 1543,
#   'fire_2m': 764.3442622951,
#   'fire_w': 1005.0,
#   'precipitation': 3.8992266171,
#   'precipitation_2m': 3.985255284,
#   'precipitation_w': 3.5922458774},
#  {'date': '2021-10-08',
#   'fire': 762,
#   'fire_2m': 743.3114754098,
#   'fire_w': 962.4285714286,
#   'precipitation': 2.9395436169,
#   'precipitation_2m': 4.0464977733,
#   'precipitation_w': 3.8175673564},
#  {'date': '2021-10-09',
#   'fire': 592,
#   'fire_2m': 711.6721311475,
#   'fire_w': 893.8571428571,
#   'precipitation': 3.5724013186,
#   'precipitation_2m': 4.0892279487,
#   'precipitation_w': 3.6370124173},
#  {'date': '2021-10-10',
#   'fire': 451,
#   'fire_2m': 688.4918032787,
#   'fire_w': 672.4285714286,
#   'precipitation': 4.7773479232,
#   'precipitation_2m': 4.1489140047,
#   'precipitation_w': 3.5377022647}]

# %%
# !curl -X POST https://us-central1-skydipper-196010.cloudfunctions.net/fire_tool"https://us-central1-fire-water-chart.cloudfunctions.net/fire_water_chart" -H "Content-Type:application/json" --data '{"iso": "BRA", "adm1": 22, "date_text": "2021-10-10"}'
# Out:
# [{"date": "2020-10-10", "fire": 356, "fire_w": 93.5714285714, "fire_2m": 34.5245901639, "precipitation": 0.2018636235, "precipitation_w": 2.2670981327, "precipitation_2m": 5.1149473581}, {"date": "2020-10-11", "fire": 16, "fire_w": 92.5714285714, "fire_2m": 34.0819672131, "precipitation": 5.2612908266, "precipitation_w": 3.5613245354, "precipitation_2m": 5.1539803312}, {"date": "2020-10-12", "fire": 9, "fire_w": 86.4285714286, "fire_2m": 33.9344262295, "precipitation": 3.1359100564, "precipitation_w": 4.3597407212, "precipitation_2m": 5.1847560883}, {"date": "2020-10-13", "fire": 9, "fire_w": 66.4285714286, "fire_2m": 33.0, "precipitation": 5.1519799746, "precipitation_w": 4.9503342209, "precipitation_2m": 5.2079660651}, {"date": "2020-10-14", "fire": 32, "fire_w": 18.1428571429, "fire_2m": 31.7049180328, "precipitation": 9.4813654909, "precipitation_w": 5.1191926729, "precipitation_2m": 5.2299289004}, {"date": "2020-10-15", "fire": 2, "fire_w": 18.5714285714, "fire_2m": 30.6885245902, "precipitation": 6.7310094182, "precipitation_w": 5.1992908249, "precipitation_2m": 5.3347866914}, {"date": "2020-10-16", "fire": 41, "fire_w": 17.4285714286, "fire_2m": 30.6557377049, "precipitation": 4.688920156, "precipitation_w": 6.1180133326, "precipitation_2m": 5.3644368615}, {"date": "2020-10-17", "fire": 18, "fire_w": 21.2857142857, "fire_2m": 30.3442622951, "precipitation": 1.3838727875, "precipitation_w": 5.5604305487, "precipitation_2m": 5.4465706954}, {"date": "2020-10-18", "fire": 19, "fire_w": 22.2857142857, "fire_2m": 29.9836065574, "precipitation": 5.8219778908, "precipitation_w": 4.6504390679, "precipitation_2m": 5.5577774999}, {"date": "2020-10-19", "fire": 1, "fire_w": 22.4285714286, "fire_2m": 29.0, "precipitation": 9.5669676098, "precipitation_w": 4.6365229999, "precipitation_2m": 5.6938497127}, {"date": "2020-10-20", "fire": 36, "fire_w": 17.0, "fire_2m": 27.868852459, "precipitation": 1.2489004877, "precipitation_w": 4.9416406965, "precipitation_2m": 5.821743569}, {"date": "2020-10-21", "fire": 39, "fire_w": 15.2857142857, "fire_2m": 27.6721311475, "precipitation": 3.1114251256, "precipitation_w": 5.2364868182, "precipitation_2m": 5.725332129}, {"date": "2020-10-22", "fire": 3, "fire_w": 12.8571428571, "fire_2m": 27.7049180328, "precipitation": 6.6335969423, "precipitation_w": 4.9616632224, "precipitation_2m": 5.6026616585}, {"date": "2020-10-23", "fire": 3, "fire_w": 16.1428571429, "fire_2m": 27.8524590164, "precipitation": 6.8247440319, "precipitation_w": 3.9679326822, "precipitation_2m": 5.483187409}, {"date": "2020-10-24", "fire": 6, "fire_w": 12.1428571429, "fire_2m": 27.7049180328, "precipitation": 3.4477956392, "precipitation_w": 6.4258584345, "precipitation_2m": 5.4355144088}, {"date": "2020-10-25", "fire": 2, "fire_w": 7.1428571429, "fire_2m": 27.1147540984, "precipitation": 3.8982127203, "precipitation_w": 6.6244073548, "precipitation_2m": 5.4315573105}, {"date": "2020-10-26", "fire": 24, "fire_w": 6.7142857143, "fire_2m": 26.6885245902, "precipitation": 2.6108538281, "precipitation_w": 6.9102928895, "precipitation_2m": 5.3841794707}, {"date": "2020-10-27", "fire": 8, "fire_w": 6.2857142857, "fire_2m": 26.5081967213, "precipitation": 18.4543807541, "precipitation_w": 7.9622809211, "precipitation_2m": 5.33477031}, {"date": "2020-10-28", "fire": 4, "fire_w": 5.4285714286, "fire_2m": 26.3442622951, "precipitation": 4.5012675678, "precipitation_w": 9.2169591163, "precipitation_2m": 5.4127978245}, {"date": "2020-10-29", "fire": 0, "fire_w": 7.7142857143, "fire_2m": 25.3278688525, "precipitation": 8.6347956851, "precipitation_w": 9.280196098, "precipitation_2m": 5.4549563218}, {"date": "2020-10-30", "fire": 0, "fire_w": 6.1428571429, "fire_2m": 23.6721311475, "precipitation": 14.1886602527, "precipitation_w": 9.1784039571, "precipitation_2m": 5.4226624751}, {"date": "2020-10-31", "fire": 0, "fire_w": 5.4285714286, "fire_2m": 21.7540983607, "precipitation": 12.2305430062, "precipitation_w": 7.1524287478, "precipitation_ ...

# %% [markdown]
# **Handling CORS requests**
#
# Cross-Origin Resource Sharing (CORS) is a way to let applications running on one domain access content from another domain, for example, letting `yourdomain.com` make requests to `region-project.cloudfunctions.net/yourfunction`.
#
# If CORS isn't set up properly, you're likely to get errors that look like this:
#
#
# ```js
# XMLHttpRequest cannot load https://region-project.cloudfunctions.net/function.
# No 'Access-Control-Allow-Origin' header is present on the requested resource.
# Origin 'http://yourdomain.com' is therefore not allowed access.
# ```
#
# CORS consists of two requests, a pre-flight request followed by the main request.
#
# To resolve this issue, [Google’s documentation](https://cloud.google.com/functions/docs/writing/http#handling_cors_requests) recommends setting the proper headers in the Cloud Funtion itself by adding the following code:
#
# ```python
# # Set CORS headers for the preflight request
# if request.method == 'OPTIONS':
#     # Allows GET requests from any origin with the Content-Type
#     # header and caches preflight response for an 3600s
#     headers = {
#         'Access-Control-Allow-Origin': '*',
#         'Access-Control-Allow-Methods': 'PUT',
#         'Access-Control-Allow-Headers': 'Content-Type',
#         'Access-Control-Max-Age': '3600'
#     }
#
#     return ('', 204, headers)
#
# # Set CORS headers for the main request
# headers = {
#     'Access-Control-Allow-Origin': '*'
# }
# ```
#
# The updated version of the Google Cloud Function can be found below.
#
# As you can see, there is an additional `if` block that sets the correct headers for a pre-flight request with the `OPTIONS` method.
#
# After the correct headers have been set, the main request is made with the output of the function, a 200 response code, and the CORS headers – `(json.dumps(serializer(df_pre, df_fire)), 200, headers)`.
#
# ```python
# def fire_water_chart(request):
#
#     # Set CORS headers for the preflight request
#     if request.method == 'OPTIONS':
#         # Allows GET requests from any origin with the Content-Type
#         # header and caches preflight response for an 3600s
#         headers = {
#             'Access-Control-Allow-Origin': '*',
#             'Access-Control-Allow-Methods': 'POST',
#             'Access-Control-Allow-Headers': 'Content-Type',
#             'Access-Control-Max-Age': '3600'
#         }
#
#         return ('', 204, headers)
#
#     # Set CORS headers for the main request
#     headers = {
#         'Access-Control-Allow-Origin': '*'
#     }
#
#     request_json = request.get_json()
#
#     # Get geometry as GeoJSON from geostore
#     geometry = get_geometry(request_json['iso'], request_json['adm1'])
#
#     # Convert geometry to ee.Geometry
#     aoi = ee.Geometry(geometry.get('features')[0].get('geometry'))
#
#     # Get relevant dates
#     dates, start_date, end_date, start_year_date = get_dates(request_json['date_text'])
#
#     # Read ImageCollection
#     dataset = ee.ImageCollection('UCSB-CHG/CHIRPS/DAILY') \
#         .filter(ee.Filter.date(start_date.strftime('%Y-%m-%d'), (end_date + dt.timedelta(days=1)).strftime('%Y-%m-%d'))).filterBounds(aoi)
#     chirps = dataset.select('precipitation')
#
#     # Get mean precipitation values over time
#     count = chirps.size()
#     data = nestedMappedReducer(ee.FeatureCollection(geometry.get('features')), chirps).toList(count).getInfo()
#     df_pre = pd.DataFrame(map(lambda x: x.get('properties'), data))
#
#     # VIIRS fire alerts
#     confidence = 'h' #'n', 'l'
#
#     if request_json['adm1']:
#         query =(f"SELECT alert__date, SUM(alert__count) AS alert__count \
#                 FROM data WHERE iso = \'{request_json['iso']}\' AND adm1::integer = {request_json['adm1']} AND confidence__cat = \'{confidence}\' AND alert__date >= \'{start_date}\' AND alert__date <= \'{end_date}\' \
#                 GROUP BY iso, adm1, alert__date, confidence__cat \
#                 ORDER BY alert__date"
#         )
#     else:
#         query =(f"SELECT alert__date, SUM(alert__count) AS alert__count \
#                 FROM data WHERE iso = \'{request_json['iso']}\' AND confidence__cat = \'{confidence}\' AND alert__date >= \'{start_date}\' AND alert__date <= \'{end_date}\' \
#                 GROUP BY iso, alert__date, confidence__cat \
#                 ORDER BY alert__date"
#         )
#
#     url = f"https://data-api.globalforestwatch.org/dataset/gadm__viirs__adm2_daily_alerts/latest/query/json"
#
#     sql = {"sql": query}
#     r = requests.get(url, params=sql)
#
#     data = r.json().get('data')
#     if data:
#         df_fire = pd.DataFrame.from_dict(pd.json_normalize(data))
#         # Fill missing dates with 0
#         df_fire = df_fire.set_index('alert__date').reindex(dates, fill_value=0).reset_index().rename(columns={'index': 'alert__date'})
#         df_fire.rename(columns = {'alert__date': 'date', 'alert__count': 'fire'}, inplace= True)
#     else:
#         df_fire = pd.DataFrame({"date": dates, 'fire': 0})
#
#     # Moving averages
#     # 1 week moving average
#     df_pre['precipitation_w'] = df_pre[['date', 'precipitation']].rolling(window=7, center=True).mean()
#     df_fire['fire_w'] = df_fire[['date', 'fire']].rolling(window=7, center=True).mean()
#     # 2 month moving average
#     df_pre['precipitation_2m'] = df_pre[['date', 'precipitation']].rolling(window=61, center=True).mean()
#     df_fire['fire_2m'] = df_fire[['date', 'fire']].rolling(window=61, center=True).mean()
#     # take current year days
#     df_pre = df_pre[(df_pre['date'] >= start_year_date.strftime('%Y-%m-%d')) & (df_pre['date'] <= end_date.strftime('%Y-%m-%d'))]
#     df_fire = df_fire[(df_fire['date'] >= start_year_date.strftime('%Y-%m-%d')) & (df_fire['date'] <= end_date.strftime('%Y-%m-%d'))]
#
#     return (json.dumps(serializer(df_pre, df_fire)), 200, headers)
# ```
